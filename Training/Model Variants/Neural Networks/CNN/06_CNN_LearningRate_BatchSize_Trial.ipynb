# %% [markdown]
# # 06 CNN Learning Rate and Batch Size Trial
#
# Two controlled sub-stages: learning rate first while batch size is fixed, then batch size using the selected learning rate.

# %% [markdown]
# ## 1. Package Setup

# %%
# Purpose: Package installs are documented but not run automatically during this static refactor.
# %pip install tensorflow scikit-learn pandas numpy matplotlib seaborn joblib soundfile librosa

# %% [markdown]
# ## 2. Load Cache and Architecture Config

# %%
import os
from pathlib import Path

# Purpose: Mounts Google Drive when this notebook is running in Google Colab.
# Why this exists: the project files, cached MFCC features, manifests, models, figures,
# and metric outputs live in Google Drive during Colab runs. The /content/drive path
# only represents the real MyDrive files after drive.mount("/content/drive") succeeds.
# Important: the project root should be the folder that contains Data, Model Variants,
# and outputs. For this project, that expected Colab folder is the INM701 folder below.
COLAB_DRIVE_MOUNT_POINT = Path("/content/drive")
EXPECTED_COLAB_PROJECT_ROOT = Path("/content/drive/MyDrive/Colab Notebooks/Education/INM701")

try:
    from google.colab import drive

    drive.mount(str(COLAB_DRIVE_MOUNT_POINT))
    print("Google Colab detected. Google Drive mounted.")

    current_project_root = os.environ.get("INTRO_AI_PROJECT_ROOT")
    current_data_dir_exists = bool(current_project_root) and (Path(current_project_root) / "Data").exists()
    expected_data_dir_exists = (EXPECTED_COLAB_PROJECT_ROOT / "Data").exists()

    # Purpose: Keep a valid user-provided project root, but repair stale runtime state
    # if a previous cell pointed INTRO_AI_PROJECT_ROOT somewhere that does not contain Data.
    if current_data_dir_exists:
        print("INTRO_AI_PROJECT_ROOT already points to a folder with Data, so it was kept.")
    elif expected_data_dir_exists:
        os.environ["INTRO_AI_PROJECT_ROOT"] = str(EXPECTED_COLAB_PROJECT_ROOT)
        print("INTRO_AI_PROJECT_ROOT set to the expected INM701 project folder.")
    elif not current_project_root:
        os.environ["INTRO_AI_PROJECT_ROOT"] = str(EXPECTED_COLAB_PROJECT_ROOT)
        print("INTRO_AI_PROJECT_ROOT was not set, so it now points to the expected INM701 folder.")
    else:
        print("INTRO_AI_PROJECT_ROOT was kept, but Data was not found there or in the expected INM701 folder.")
except Exception as exc:
    print("Google Colab Drive mount skipped. This is expected outside Colab.")
    print("Mount skip reason:", exc)

active_project_root = os.environ.get("INTRO_AI_PROJECT_ROOT", "not set")
print("INTRO_AI_PROJECT_ROOT:", active_project_root)
if active_project_root != "not set":
    active_project_root = Path(active_project_root)
    print("Project root exists:", active_project_root.exists())
    print("Expected Data folder:", active_project_root / "Data")
    print("Data folder exists:", (active_project_root / "Data").exists())
# Out:
# Mounted at /content/drive
# Google Colab detected. Google Drive mounted.
# INTRO_AI_PROJECT_ROOT set to the expected INM701 project folder.
# INTRO_AI_PROJECT_ROOT: /content/drive/MyDrive/Colab Notebooks/Education/INM701
# Project root exists: True
# Expected Data folder: /content/drive/MyDrive/Colab Notebooks/Education/INM701/Data
# Data folder exists: True

# %%
# Purpose: Later notebooks load the one CNN-ready cache made by notebook 00. They do not
# rescan folders, regenerate splits, extract MFCCs, fit scalers, or recalculate class weights.
import hashlib
import json
import os
import random
import time
from itertools import product
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score, precision_score, recall_score
from tensorflow.keras.layers import Conv2D, Dense, Dropout, GlobalAveragePooling2D, Input, MaxPooling2D
from tensorflow.keras.models import Sequential

try:
    from IPython.display import display
except Exception:
    display = print

RANDOM_STATE = 42
MAX_EPOCHS = 50
EARLY_STOP_PATIENCE = 7
EARLY_STOP_MIN_DELTA = 1e-4
THRESHOLD = 0.5
CLASS_NAMES = {0: "bona_fide", 1: "synthetic"}
CONFIRMATION_SEEDS = [42, 123, 2026]


def resolve_project_root():
    # Purpose: default path.
    explicit = os.environ.get("INTRO_AI_PROJECT_ROOT")
    if explicit:
        return Path(explicit).expanduser().resolve()
    cwd = Path.cwd().resolve()
    # Purpose: Runs each candidate configuration under the same data split for a fair validation comparison.
    for candidate in [cwd, *cwd.parents]:
        if (candidate / "Model Variants").exists():
            return candidate
        if (candidate / "Training" / "Model Variants").exists():
            return candidate / "Training"
    return Path("/content/drive/MyDrive/Colab Notebooks/Education/INM701")


# Purpose: Centralizes filesystem paths so dataset inputs, caches, figures, models, and metric tables are easy
# Purpose: to trace.
PROJECT_ROOT = resolve_project_root()
OUTPUT_DIR = PROJECT_ROOT / "outputs" / "cnn"
CACHE_DIR = OUTPUT_DIR / "cache"
MANIFESTS_DIR = OUTPUT_DIR / "manifests"
CONFIGS_DIR = OUTPUT_DIR / "configs"
TABLES_DIR = OUTPUT_DIR / "tables"
HISTORIES_DIR = OUTPUT_DIR / "histories"
METRICS_DIR = OUTPUT_DIR / "metrics"
FIGURES_DIR = OUTPUT_DIR / "figures"
MODELS_DIR = OUTPUT_DIR / "models"
PILOT_LEGACY_DIR = OUTPUT_DIR / "pilot_legacy"
# Purpose: Creates each output directory before later cells try to save tables, figures, or models.
for directory in [OUTPUT_DIR, CACHE_DIR, MANIFESTS_DIR, CONFIGS_DIR, TABLES_DIR, HISTORIES_DIR, METRICS_DIR, FIGURES_DIR, MODELS_DIR, PILOT_LEGACY_DIR]:
    directory.mkdir(parents=True, exist_ok=True)


def require_file(path):
    # Purpose: Stops the notebook early with a clear message when a required upstream artifact is missing.
    path = Path(path)
    if not path.exists():
        raise FileNotFoundError(f"Required file not found: {path}")
    return path


def load_json(path):
    # Purpose: Keeps the load_json helper isolated so later notebook cells can call it consistently.
    with open(require_file(path), "r", encoding="utf-8") as f:
        return json.load(f)


def save_json(payload, path):
    # Purpose: Keeps the save_json helper isolated so later notebook cells can call it consistently.
    with open(path, "w", encoding="utf-8") as f:
        json.dump(payload, f, indent=2)




def normalise_handoff_config(config):
    # Purpose: Keeps rebuilt JSON handoffs compatible with the CNN builder.
    normalised = dict(config)
    for key in ["conv_filters", "kernel_size"]:
        value = normalised.get(key, [])
        if isinstance(value, str):
            value = json.loads(value)
        normalised[key] = [int(item) for item in value]
    normalised["dense_units"] = int(normalised["dense_units"])
    normalised["activation"] = str(normalised.get("activation", "relu"))
    normalised["optimizer"] = str(normalised.get("optimizer", "adam"))
    normalised["dropout"] = float(normalised["dropout"])
    normalised["learning_rate"] = float(normalised["learning_rate"])
    normalised["batch_size"] = int(normalised["batch_size"])
    normalised["loss"] = normalised.get("loss", "binary_crossentropy")
    normalised["threshold"] = float(normalised.get("threshold", 0.5))
    return normalised

def first_existing_results_path(candidate_paths):
    # Purpose: Supports the normal result filename and any documented alias without changing
    # where the notebook saves new results. The first existing CSV is used for rebuilding.
    paths = [Path(path) for path in candidate_paths]
    for path in paths:
        if path.exists():
            return path
    return paths[0]


def rebuild_selected_config_from_results(results_path, selected_path, selected_by_stage):
    # Purpose: Rebuilds a missing selected_config JSON from an existing validation-results
    # CSV. This avoids rerunning training just to recreate the JSON handoff file.
    results_path = Path(results_path)
    selected_path = Path(selected_path)
    if not results_path.exists():
        print("Cannot rebuild selected config because result CSV is missing:", results_path)
        return None

    results_df = pd.read_csv(results_path)
    required_columns = {"config_json", "validation_macro_f1", "best_validation_loss"}
    missing_columns = required_columns - set(results_df.columns)
    if missing_columns:
        raise RuntimeError(f"Cannot rebuild {selected_path.name}; missing columns in {results_path.name}: {sorted(missing_columns)}")
    if results_df.empty:
        raise RuntimeError(f"Cannot rebuild {selected_path.name}; result CSV is empty: {results_path}")

    best_row = results_df.sort_values(["validation_macro_f1", "best_validation_loss"], ascending=[False, True]).iloc[0]
    selected = normalise_handoff_config(json.loads(best_row["config_json"]))
    selected.update({
        "selected_by_stage": selected_by_stage,
        "selection_metric": "validation_macro_f1",
        "validation_macro_f1": float(best_row["validation_macro_f1"]),
        "best_validation_loss": float(best_row["best_validation_loss"]),
        "rebuilt_from_results_csv": str(results_path),
    })
    save_json(selected, selected_path)
    print("Rebuilt selected config from existing results:", selected_path)
    return selected


def ensure_selected_config_from_results(selected_path, results_path, selected_by_stage):
    # Purpose: Repairs a missing previous-stage config before this notebook tries to load it.
    # If neither the JSON nor the CSV exists, the later require_file/load_json call will still
    # stop with a clear missing-artifact error.
    selected_path = Path(selected_path)
    results_path = Path(results_path)
    if selected_path.exists():
        return load_json(selected_path)
    if results_path.exists():
        return rebuild_selected_config_from_results(results_path, selected_path, selected_by_stage)
    print("Selected config missing:", selected_path)
    print("Result CSV also missing, so config cannot be rebuilt:", results_path)
    return None


def load_class_weights():
    # Purpose: Keeps the load_class_weights helper isolated so later notebook cells can call it consistently.
    payload = load_json(CONFIGS_DIR / "class_weights.json")
    weights = payload.get("class_weights", payload)
    return {int(label): float(weight) for label, weight in weights.items()}


for required in [
    CACHE_DIR / "X_train.npy",
    CACHE_DIR / "y_train.npy",
    CACHE_DIR / "train_metadata.csv",
    CACHE_DIR / "X_validation.npy",
    CACHE_DIR / "y_validation.npy",
    CACHE_DIR / "validation_metadata.csv",
    CACHE_DIR / "feature_config.json",
    CONFIGS_DIR / "class_weights.json",
]:
    require_file(required)

X_train = np.load(CACHE_DIR / "X_train.npy", mmap_mode="r")[..., np.newaxis]
y_train = np.load(CACHE_DIR / "y_train.npy")
train_metadata = pd.read_csv(CACHE_DIR / "train_metadata.csv")
X_validation = np.load(CACHE_DIR / "X_validation.npy", mmap_mode="r")[..., np.newaxis]
y_validation = np.load(CACHE_DIR / "y_validation.npy")
validation_metadata = pd.read_csv(CACHE_DIR / "validation_metadata.csv")
feature_config = load_json(CACHE_DIR / "feature_config.json")
CLASS_WEIGHTS = load_class_weights()

if len(X_train) != len(y_train) or len(X_train) != len(train_metadata):
    raise RuntimeError("Training cache arrays, labels and metadata are not row-aligned.")
if len(X_validation) != len(y_validation) or len(X_validation) != len(validation_metadata):
    raise RuntimeError("Validation cache arrays, labels and metadata are not row-aligned.")

print("Loaded CNN cache:", CACHE_DIR)
print("X_train shape:", X_train.shape)
print("X_validation shape:", X_validation.shape)

# Purpose: Rebuild the previous selected config from its result CSV if the JSON handoff file is missing.
ensure_selected_config_from_results(
    CONFIGS_DIR / "05_selected_config.json",
    first_existing_results_path([TABLES_DIR / "05_architecture_results.csv", TABLES_DIR / "05_conv_filters_results.csv"]),
    "05_conv_filters",
)
base_config = load_json(CONFIGS_DIR / "05_selected_config.json")
# Out:
# Loaded CNN cache: /content/drive/MyDrive/Colab Notebooks/Education/INM701/outputs/cnn/cache
# X_train shape: (9060, 40, 502, 1)
# X_validation shape: (1942, 40, 502, 1)

# %% [markdown]
# ## 3. Keras Utilities

# %%
# Purpose: Shared CNN utilities for validation-only model selection.
def normalise_config(config):
    # Purpose: Converts JSON/CSV values into the types expected by the CNN builder.
    normalised = dict(config)
    normalised["conv_filters"] = [int(value) for value in normalised["conv_filters"]]
    normalised["kernel_size"] = [int(value) for value in normalised["kernel_size"]]
    normalised["dense_units"] = int(normalised["dense_units"])
    normalised["activation"] = str(normalised.get("activation", "relu"))
    normalised["optimizer"] = str(normalised.get("optimizer", "adam"))
    normalised["dropout"] = float(normalised["dropout"])
    normalised["learning_rate"] = float(normalised["learning_rate"])
    normalised["batch_size"] = int(normalised["batch_size"])
    normalised["loss"] = normalised.get("loss", "binary_crossentropy")
    normalised["threshold"] = float(normalised.get("threshold", THRESHOLD))
    return normalised


def config_json(config):
    # Purpose: Creates a stable representation for deduplication and deterministic seeds.
    return json.dumps(normalise_config(config), sort_keys=True)


def config_key(config):
    return hashlib.sha256(config_json(config).encode("utf-8")).hexdigest()


def seed_from_config(config, base_seed=RANDOM_STATE):
    digest = hashlib.sha256(f"{base_seed}:{config_json(config)}".encode("utf-8")).hexdigest()
    return int(digest[:8], 16) % (2**31 - 1)


def set_global_seed(seed):
    random.seed(int(seed))
    np.random.seed(int(seed))
    tf.keras.utils.set_random_seed(int(seed))
    os.environ["PYTHONHASHSEED"] = str(int(seed))


def make_optimizer(config):
    name = str(config["optimizer"]).lower()
    learning_rate = float(config["learning_rate"])
    if name == "adam":
        return tf.keras.optimizers.Adam(learning_rate=learning_rate)
    if name == "rmsprop":
        return tf.keras.optimizers.RMSprop(learning_rate=learning_rate)
    if name in ["sgd", "sgd_momentum"]:
        return tf.keras.optimizers.SGD(learning_rate=learning_rate, momentum=0.9)
    raise ValueError(f"Unsupported optimizer: {config['optimizer']}")


def build_cnn_model(config, input_shape):
    # Purpose: Learns local patterns from the coefficient-by-time MFCC map.
    config = normalise_config(config)
    model = Sequential(name="mfcc_cnn")
    model.add(Input(shape=tuple(input_shape)))
    for filters in config["conv_filters"]:
        model.add(
            Conv2D(
                filters=filters,
                kernel_size=tuple(config["kernel_size"]),
                padding="same",
                strides=(1, 1),
                activation=config["activation"],
            )
        )
        model.add(MaxPooling2D(pool_size=(2, 2)))
        if config["dropout"] > 0:
            model.add(Dropout(config["dropout"]))
    # Global pooling controls parameter growth when the number of MFCC time frames changes.
    model.add(GlobalAveragePooling2D())
    model.add(Dense(config["dense_units"], activation=config["activation"]))
    if config["dropout"] > 0:
        model.add(Dropout(config["dropout"]))
    model.add(Dense(1, activation="sigmoid"))
    model.compile(loss=config["loss"], optimizer=make_optimizer(config), metrics=["accuracy"])
    return model


def train_and_evaluate_config(config, run_seed, run_name, verbose=0):
    # Purpose: Uses training data for fitting and validation data for selection; never test data.
    config = normalise_config(config)
    tf.keras.backend.clear_session()
    set_global_seed(run_seed)
    model = build_cnn_model(config, X_train.shape[1:])
    callbacks = [
        tf.keras.callbacks.EarlyStopping(
            monitor="val_loss",
            patience=EARLY_STOP_PATIENCE,
            min_delta=EARLY_STOP_MIN_DELTA,
            restore_best_weights=True,
        )
    ]
    start = time.perf_counter()
    history = model.fit(
        X_train,
        y_train,
        validation_data=(X_validation, y_validation),
        epochs=MAX_EPOCHS,
        batch_size=config["batch_size"],
        class_weight=CLASS_WEIGHTS,
        callbacks=callbacks,
        verbose=verbose,
    )
    runtime = time.perf_counter() - start
    probability = model.predict(X_validation, batch_size=config["batch_size"], verbose=0).ravel()
    pred = (probability >= config["threshold"]).astype(int)
    row = {
        "configuration": config,
        "config_json": config_json(config),
        "config_key": config_key(config),
        "seed": int(run_seed),
        "validation_macro_f1": float(f1_score(y_validation, pred, average="macro", zero_division=0)),
        "validation_binary_f1_synthetic": float(f1_score(y_validation, pred, pos_label=1, zero_division=0)),
        "validation_accuracy": float(accuracy_score(y_validation, pred)),
        "validation_precision_synthetic": float(precision_score(y_validation, pred, pos_label=1, zero_division=0)),
        "validation_recall_synthetic": float(recall_score(y_validation, pred, pos_label=1, zero_division=0)),
        "best_validation_loss": float(np.min(history.history["val_loss"])),
        "best_epoch": int(np.argmin(history.history["val_loss"]) + 1),
        "epochs_trained": int(len(history.history["loss"])),
        "runtime_seconds": float(runtime),
        "run_name": run_name,
    }
    history_df = pd.DataFrame(history.history)
    history_df.insert(0, "epoch", np.arange(1, len(history_df) + 1))
    return row, history_df


def flat_result(row, extra=None):
    # Purpose: Makes each CNN configuration readable in CSV result tables.
    extra = extra or {}
    config = normalise_config(row["configuration"])
    flat = dict(extra)
    flat.update({
        "conv_filters": json.dumps(config["conv_filters"]),
        "kernel_size": json.dumps(config["kernel_size"]),
        "dense_units": config["dense_units"],
        "activation": config["activation"],
        "optimizer": config["optimizer"],
        "dropout": config["dropout"],
        "learning_rate": config["learning_rate"],
        "batch_size": config["batch_size"],
        "loss": config["loss"],
        "threshold": config["threshold"],
        "config_json": row["config_json"],
        "config_key": row["config_key"],
        "seed": row["seed"],
        "validation_macro_f1": row["validation_macro_f1"],
        "validation_binary_f1_synthetic": row["validation_binary_f1_synthetic"],
        "validation_accuracy": row["validation_accuracy"],
        "validation_precision_synthetic": row["validation_precision_synthetic"],
        "validation_recall_synthetic": row["validation_recall_synthetic"],
        "best_validation_loss": row["best_validation_loss"],
        "best_epoch": row["best_epoch"],
        "epochs_trained": row["epochs_trained"],
        "runtime_seconds": row["runtime_seconds"],
    })
    return flat


def select_best(rows):
    return max(rows, key=lambda row: (row["validation_macro_f1"], -row["best_validation_loss"]))

# %% [markdown]
# ## 4. Run or Load Two-Stage Trial

# %%
# Purpose: Runs the two-stage learning-rate and batch-size trial when enabled. If the
# selected JSON handoff is missing but the batch-size results already exist, rebuild it
# from validation evidence without retraining.
RUN_LR_BATCH_TRIAL = True
learning_rate_candidates = [0.0003, 0.001, 0.003]
batch_size_candidates = [32, 64, 128]
lr_results_path = TABLES_DIR / "06_learning_rate_results.csv"
batch_results_path = TABLES_DIR / "06_batch_size_results.csv"
lr_histories_path = HISTORIES_DIR / "06_learning_rate_histories.json"
batch_histories_path = HISTORIES_DIR / "06_batch_size_histories.json"
selected_path = CONFIGS_DIR / "06_selected_config.json"

if RUN_LR_BATCH_TRIAL:
    lr_rows = []
    lr_histories = {}
    # Purpose: Tries each learning-rate candidate while holding the previous selected config fixed.
    for lr in learning_rate_candidates:
        config = dict(base_config)
        config["learning_rate"] = lr
        row, history_df = train_and_evaluate_config(config, seed_from_config(config), f"06_lr_{lr}", verbose=2)
        lr_rows.append(row)
        lr_histories[str(lr)] = history_df.to_dict(orient="records")
    pd.DataFrame([flat_result(row, {"stage": "06_learning_rate", "candidate": row["configuration"]["learning_rate"]}) for row in lr_rows]).to_csv(lr_results_path, index=False)
    save_json(lr_histories, lr_histories_path)
    lr_best = select_best(lr_rows)

    batch_rows = []
    batch_histories = {}
    # Purpose: Tries each batch size after selecting the best learning rate from the first stage.
    for batch_size in batch_size_candidates:
        config = dict(lr_best["configuration"])
        config["batch_size"] = batch_size
        row, history_df = train_and_evaluate_config(config, seed_from_config(config), f"06_batch_{batch_size}", verbose=2)
        batch_rows.append(row)
        batch_histories[str(batch_size)] = history_df.to_dict(orient="records")
    pd.DataFrame([flat_result(row, {"stage": "06_batch_size", "candidate": row["configuration"]["batch_size"]}) for row in batch_rows]).to_csv(batch_results_path, index=False)
    save_json(batch_histories, batch_histories_path)

    best = select_best(batch_rows)
    selected = normalise_config(best["configuration"])
    selected.update({"selected_by_stage": "06_learning_rate_batch_size", "selection_metric": "validation_macro_f1", "validation_macro_f1": best["validation_macro_f1"], "best_validation_loss": best["best_validation_loss"]})
    save_json(selected, selected_path)
elif selected_path.exists():
    selected_config = load_json(selected_path)
    print("Loaded selected config:", selected_path)
    if lr_results_path.exists():
        display(pd.read_csv(lr_results_path).sort_values(["validation_macro_f1", "best_validation_loss"], ascending=[False, True]))
    if batch_results_path.exists():
        display(pd.read_csv(batch_results_path).sort_values(["validation_macro_f1", "best_validation_loss"], ascending=[False, True]))
    if not lr_results_path.exists() and not batch_results_path.exists():
        display(pd.DataFrame([selected_config]))
elif batch_results_path.exists():
    rebuild_selected_config_from_results(batch_results_path, selected_path, "06_learning_rate_batch_size")
    if lr_results_path.exists():
        display(pd.read_csv(lr_results_path).sort_values(["validation_macro_f1", "best_validation_loss"], ascending=[False, True]))
    display(pd.read_csv(batch_results_path).sort_values(["validation_macro_f1", "best_validation_loss"], ascending=[False, True]))
else:
    print("RUN_LR_BATCH_TRIAL is False. [RESULT TO BE INSERTED AFTER FINAL RUN]")
    print("Missing selected config:", selected_path)
    print("Missing batch-size result CSV:", batch_results_path)
# Out:
# Epoch 1/50
# 71/71 - 29s - 404ms/step - accuracy: 0.5579 - loss: 0.6810 - val_accuracy: 0.5829 - val_loss: 0.6784
# Epoch 2/50
# 71/71 - 1s - 18ms/step - accuracy: 0.6148 - loss: 0.6321 - val_accuracy: 0.6390 - val_loss: 0.6213
# Epoch 3/50
# 71/71 - 1s - 17ms/step - accuracy: 0.6821 - loss: 0.5674 - val_accuracy: 0.7019 - val_loss: 0.5674
# Epoch 4/50
# 71/71 - 1s - 17ms/step - accuracy: 0.7407 - loss: 0.5063 - val_accuracy: 0.7956 - val_loss: 0.4671
# Epoch 5/50
# 71/71 - 1s - 18ms/step - accuracy: 0.7722 - loss: 0.4684 - val_accuracy: 0.8115 - val_loss: 0.4257
# Epoch 6/50
# 71/71 - 1s - 17ms/step - accuracy: 0.7905 - loss: 0.4395 - val_accuracy: 0.8182 - val_loss: 0.4156
# Epoch 7/50
# 71/71 - 1s - 18ms/step - accuracy: 0.8035 - loss: 0.4119 - val_accuracy: 0.8198 - val_loss: 0.4108
# Epoch 8/50
# 71/71 - 1s - 18ms/step - accuracy: 0.8201 - loss: 0.3844 - val_accuracy: 0.7920 - val_loss: 0.4361
# Epoch 9/50
# 71/71 - 1s - 17ms/step - accuracy: 0.8305 - loss: 0.3630 - val_accuracy: 0.7678 - val_loss: 0.4660
# Epoch 10/50
# 71/71 - 1s - 18ms/step - accuracy: 0.8435 - loss: 0.3357 - val_accuracy: 0.7781 - val_loss: 0.4538
# Epoch 11/50
# 71/71 - 1s - 18ms/step - accuracy: 0.8656 - loss: 0.3176 - val_accuracy: 0.7142 - val_loss: 0.5524
# Epoch 12/50
# 71/71 - 1s - 18ms/step - accuracy: 0.8679 - loss: 0.2994 - val_accuracy: 0.7461 - val_loss: 0.5039
# Epoch 13/50
# 71/71 - 1s - 17ms/step - accuracy: 0.8778 - loss: 0.2841 - val_accuracy: 0.7678 - val_loss: 0.4681
# Epoch 14/50
# 71/71 - 1s - 17ms/step - accuracy: 0.8829 - loss: 0.2750 - val_accuracy: 0.7317 - val_loss: 0.5493
# Epoch 1/50
# 71/71 - 12s - 164ms/step - accuracy: 0.5936 - loss: 0.6717 - val_accuracy: 0.6596 - val_loss: 0.6145
# Epoch 2/50
# 71/71 - 1s - 18ms/step - accuracy: 0.6918 - loss: 0.5593 - val_accuracy: 0.6715 - val_loss: 0.5716
# Epoch 3/50
# 71/71 - 1s - 17ms/step - accuracy: 0.7616 - loss: 0.4768 - val_accuracy: 0.6941 - val_loss: 0.5501
# Epoch 4/50
# 71/71 - 1s - 17ms/step - accuracy: 0.8002 - loss: 0.4167 - val_accuracy: 0.6823 - val_loss: 0.5595
# Epoch 5/50
# 71/71 - 1s - 17ms/step - accuracy: 0.8360 - loss: 0.3492 - val_accuracy: 0.7734 - val_loss: 0.4420
# Epoch 6/50
# 71/71 - 1s - 18ms/step - accuracy: 0.8724 - loss: 0.2873 - val_accuracy: 0.7461 - val_loss: 0.5349
# Epoch 7/50
# 71/71 - 1s - 18ms/step - accuracy: 0.8999 - loss: 0.2370 - val_accuracy: 0.8095 - val_loss: 0.4103
# Epoch 8/50
# 71/71 - 1s - 18ms/step - accuracy: 0.9183 - loss: 0.2012 - val_accuracy: 0.7461 - val_loss: 0.6265
# Epoch 9/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9203 - loss: 0.1896 - val_accuracy: 0.8486 - val_loss: 0.3391
# Epoch 10/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9301 - loss: 0.1686 - val_accuracy: 0.7688 - val_loss: 0.6097
# Epoch 11/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9339 - loss: 0.1614 - val_accuracy: 0.8347 - val_loss: 0.4258
# Epoch 12/50
# 71/71 - 1s - 18ms/step - accuracy: 0.9386 - loss: 0.1480 - val_accuracy: 0.7868 - val_loss: 0.6255
# Epoch 13/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9416 - loss: 0.1445 - val_accuracy: 0.8486 - val_loss: 0.4043
# Epoch 14/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9466 - loss: 0.1309 - val_accuracy: 0.8424 - val_loss: 0.4518
# Epoch 15/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9458 - loss: 0.1287 - val_accuracy: 0.8563 - val_loss: 0.4042
# Epoch 16/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9532 - loss: 0.1149 - val_accuracy: 0.8713 - val_loss: 0.3550
# Epoch 1/50
# 71/71 - 12s - 164ms/step - accuracy: 0.3501 - loss: 0.6988 - val_accuracy: 0.6916 - val_loss: 0.6914
# Epoch 2/50
# 71/71 - 1s - 18ms/step - accuracy: 0.4772 - loss: 0.6932 - val_accuracy: 0.6916 - val_loss: 0.6914
# Epoch 3/50
# 71/71 - 1s - 17ms/step - accuracy: 0.4687 - loss: 0.6932 - val_accuracy: 0.6916 - val_loss: 0.6918
# Epoch 4/50
# 71/71 - 1s - 17ms/step - accuracy: 0.5053 - loss: 0.6932 - val_accuracy: 0.6916 - val_loss: 0.6915
# Epoch 5/50
# 71/71 - 1s - 17ms/step - accuracy: 0.5058 - loss: 0.6932 - val_accuracy: 0.6916 - val_loss: 0.6914
# Epoch 6/50
# 71/71 - 1s - 17ms/step - accuracy: 0.5044 - loss: 0.6932 - val_accuracy: 0.6916 - val_loss: 0.6902
# Epoch 7/50
# 71/71 - 1s - 17ms/step - accuracy: 0.5456 - loss: 0.6736 - val_accuracy: 0.7822 - val_loss: 0.6411
# Epoch 8/50
# 71/71 - 1s - 17ms/step - accuracy: 0.7865 - loss: 0.5054 - val_accuracy: 0.8301 - val_loss: 0.3715
# Epoch 9/50
# 71/71 - 1s - 17ms/step - accuracy: 0.8093 - loss: 0.4107 - val_accuracy: 0.8429 - val_loss: 0.3259
# Epoch 10/50
# 71/71 - 1s - 17ms/step - accuracy: 0.8170 - loss: 0.3817 - val_accuracy: 0.8563 - val_loss: 0.3134
# Epoch 11/50
# 71/71 - 1s - 17ms/step - accuracy: 0.8156 - loss: 0.3824 - val_accuracy: 0.8610 - val_loss: 0.3042
# Epoch 12/50
# 71/71 - 1s - 18ms/step - accuracy: 0.8228 - loss: 0.3737 - val_accuracy: 0.8605 - val_loss: 0.2968
# Epoch 13/50
# 71/71 - 1s - 17ms/step - accuracy: 0.8182 - loss: 0.3745 - val_accuracy: 0.8532 - val_loss: 0.3242
# Epoch 14/50
# 71/71 - 1s - 17ms/step - accuracy: 0.8274 - loss: 0.3608 - val_accuracy: 0.8589 - val_loss: 0.3215
# Epoch 15/50
# 71/71 - 1s - 17ms/step - accuracy: 0.8428 - loss: 0.3420 - val_accuracy: 0.8599 - val_loss: 0.2967
# Epoch 16/50
# 71/71 - 1s - 17ms/step - accuracy: 0.8371 - loss: 0.3378 - val_accuracy: 0.8656 - val_loss: 0.2943
# Epoch 17/50
# 71/71 - 1s - 17ms/step - accuracy: 0.8406 - loss: 0.3381 - val_accuracy: 0.8677 - val_loss: 0.2827
# Epoch 18/50
# 71/71 - 1s - 17ms/step - accuracy: 0.8464 - loss: 0.3322 - val_accuracy: 0.8589 - val_loss: 0.3063
# Epoch 19/50
# 71/71 - 1s - 17ms/step - accuracy: 0.8526 - loss: 0.3248 - val_accuracy: 0.8733 - val_loss: 0.2812
# Epoch 20/50
# 71/71 - 1s - 17ms/step - accuracy: 0.8578 - loss: 0.3163 - val_accuracy: 0.8630 - val_loss: 0.3034
# Epoch 21/50
# 71/71 - 1s - 17ms/step - accuracy: 0.8606 - loss: 0.3104 - val_accuracy: 0.8517 - val_loss: 0.3620
# Epoch 22/50
# 71/71 - 1s - 17ms/step - accuracy: 0.8538 - loss: 0.3155 - val_accuracy: 0.8666 - val_loss: 0.3010
# Epoch 23/50
# 71/71 - 1s - 17ms/step - accuracy: 0.8694 - loss: 0.2942 - val_accuracy: 0.8950 - val_loss: 0.2460
# Epoch 24/50
# 71/71 - 1s - 17ms/step - accuracy: 0.8827 - loss: 0.2690 - val_accuracy: 0.9181 - val_loss: 0.1827
# Epoch 25/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9008 - loss: 0.2358 - val_accuracy: 0.9459 - val_loss: 0.1431
# Epoch 26/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9327 - loss: 0.1728 - val_accuracy: 0.9593 - val_loss: 0.1068
# Epoch 27/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9444 - loss: 0.1448 - val_accuracy: 0.9706 - val_loss: 0.0909
# Epoch 28/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9519 - loss: 0.1340 - val_accuracy: 0.9758 - val_loss: 0.0816
# Epoch 29/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9547 - loss: 0.1261 - val_accuracy: 0.9763 - val_loss: 0.0788
# Epoch 30/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9581 - loss: 0.1153 - val_accuracy: 0.9773 - val_loss: 0.0800
# Epoch 31/50
# 71/71 - 1s - 18ms/step - accuracy: 0.9608 - loss: 0.1090 - val_accuracy: 0.9727 - val_loss: 0.0742
# Epoch 32/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9598 - loss: 0.1105 - val_accuracy: 0.9804 - val_loss: 0.0614
# Epoch 33/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9618 - loss: 0.1053 - val_accuracy: 0.9820 - val_loss: 0.0713
# Epoch 34/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9656 - loss: 0.1005 - val_accuracy: 0.9835 - val_loss: 0.0547
# Epoch 35/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9657 - loss: 0.0950 - val_accuracy: 0.9820 - val_loss: 0.0678
# Epoch 36/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9646 - loss: 0.0967 - val_accuracy: 0.9825 - val_loss: 0.0560
# Epoch 37/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9642 - loss: 0.1004 - val_accuracy: 0.9851 - val_loss: 0.0672
# Epoch 38/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9692 - loss: 0.0906 - val_accuracy: 0.9846 - val_loss: 0.0457
# Epoch 39/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9733 - loss: 0.0767 - val_accuracy: 0.9861 - val_loss: 0.0445
# Epoch 40/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9744 - loss: 0.0735 - val_accuracy: 0.9866 - val_loss: 0.0440
# Epoch 41/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9757 - loss: 0.0776 - val_accuracy: 0.9846 - val_loss: 0.0542
# Epoch 42/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9752 - loss: 0.0752 - val_accuracy: 0.9856 - val_loss: 0.0546
# Epoch 43/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9773 - loss: 0.0729 - val_accuracy: 0.9887 - val_loss: 0.0385
# Epoch 44/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9779 - loss: 0.0659 - val_accuracy: 0.9882 - val_loss: 0.0397
# Epoch 45/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9806 - loss: 0.0589 - val_accuracy: 0.9892 - val_loss: 0.0359
# Epoch 46/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9798 - loss: 0.0641 - val_accuracy: 0.9892 - val_loss: 0.0346
# Epoch 47/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9817 - loss: 0.0586 - val_accuracy: 0.9892 - val_loss: 0.0333
# Epoch 48/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9813 - loss: 0.0549 - val_accuracy: 0.9892 - val_loss: 0.0365
# Epoch 49/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9808 - loss: 0.0540 - val_accuracy: 0.9892 - val_loss: 0.0415
# Epoch 50/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9809 - loss: 0.0600 - val_accuracy: 0.9887 - val_loss: 0.0442
# Epoch 1/50
# 284/284 - 16s - 56ms/step - accuracy: 0.5072 - loss: 0.6966 - val_accuracy: 0.3084 - val_loss: 0.6955
# Epoch 2/50
# 284/284 - 2s - 6ms/step - accuracy: 0.4591 - loss: 0.6934 - val_accuracy: 0.3084 - val_loss: 0.6949
# Epoch 3/50
# 284/284 - 2s - 6ms/step - accuracy: 0.4714 - loss: 0.6934 - val_accuracy: 0.3084 - val_loss: 0.6936
# Epoch 4/50
# 284/284 - 2s - 6ms/step - accuracy: 0.5416 - loss: 0.6934 - val_accuracy: 0.3084 - val_loss: 0.6938
# Epoch 5/50
# 284/284 - 2s - 6ms/step - accuracy: 0.4638 - loss: 0.6933 - val_accuracy: 0.3084 - val_loss: 0.6946
# Epoch 6/50
# 284/284 - 2s - 6ms/step - accuracy: 0.4568 - loss: 0.6933 - val_accuracy: 0.3084 - val_loss: 0.6939
# Epoch 7/50
# 284/284 - 2s - 6ms/step - accuracy: 0.4906 - loss: 0.6933 - val_accuracy: 0.6916 - val_loss: 0.6859
# Epoch 8/50
# 284/284 - 2s - 6ms/step - accuracy: 0.4855 - loss: 0.6938 - val_accuracy: 0.3084 - val_loss: 0.6977
# Epoch 9/50
# 284/284 - 2s - 6ms/step - accuracy: 0.4799 - loss: 0.6935 - val_accuracy: 0.3084 - val_loss: 0.6938
# Epoch 10/50
# 284/284 - 2s - 6ms/step - accuracy: 0.5072 - loss: 0.6932 - val_accuracy: 0.3084 - val_loss: 0.7177
# Epoch 11/50
# 284/284 - 2s - 6ms/step - accuracy: 0.5175 - loss: 0.6939 - val_accuracy: 0.3084 - val_loss: 0.6937
# Epoch 12/50
# 284/284 - 2s - 6ms/step - accuracy: 0.4968 - loss: 0.6934 - val_accuracy: 0.3084 - val_loss: 0.6938
# Epoch 13/50
# 284/284 - 2s - 6ms/step - accuracy: 0.4815 - loss: 0.6934 - val_accuracy: 0.3084 - val_loss: 0.6938
# Epoch 14/50
# 284/284 - 2s - 6ms/step - accuracy: 0.4553 - loss: 0.6934 - val_accuracy: 0.3084 - val_loss: 0.6939
# Epoch 1/50
# 142/142 - 20s - 143ms/step - accuracy: 0.5020 - loss: 0.6973 - val_accuracy: 0.6916 - val_loss: 0.6866
# Epoch 2/50
# 142/142 - 1s - 10ms/step - accuracy: 0.4807 - loss: 0.6935 - val_accuracy: 0.6916 - val_loss: 0.6889
# Epoch 3/50
# 142/142 - 1s - 10ms/step - accuracy: 0.4950 - loss: 0.6933 - val_accuracy: 0.6916 - val_loss: 0.6887
# Epoch 4/50
# 142/142 - 1s - 10ms/step - accuracy: 0.4863 - loss: 0.6934 - val_accuracy: 0.6916 - val_loss: 0.6887
# Epoch 5/50
# 142/142 - 1s - 10ms/step - accuracy: 0.5263 - loss: 0.6934 - val_accuracy: 0.6916 - val_loss: 0.6889
# Epoch 6/50
# 142/142 - 1s - 10ms/step - accuracy: 0.5302 - loss: 0.6933 - val_accuracy: 0.6916 - val_loss: 0.6857
# Epoch 7/50
# 142/142 - 1s - 10ms/step - accuracy: 0.4795 - loss: 0.6934 - val_accuracy: 0.6916 - val_loss: 0.6887
# Epoch 8/50
# 142/142 - 1s - 10ms/step - accuracy: 0.4937 - loss: 0.6931 - val_accuracy: 0.6916 - val_loss: 0.6863
# Epoch 9/50
# 142/142 - 1s - 10ms/step - accuracy: 0.4742 - loss: 0.6934 - val_accuracy: 0.6916 - val_loss: 0.6891
# Epoch 10/50
# 142/142 - 1s - 10ms/step - accuracy: 0.4754 - loss: 0.6933 - val_accuracy: 0.6916 - val_loss: 0.6888
# Epoch 11/50
# 142/142 - 1s - 10ms/step - accuracy: 0.4868 - loss: 0.6933 - val_accuracy: 0.6916 - val_loss: 0.6897
# Epoch 12/50
# 142/142 - 1s - 10ms/step - accuracy: 0.4706 - loss: 0.6933 - val_accuracy: 0.6916 - val_loss: 0.6898
# Epoch 13/50
# 142/142 - 1s - 10ms/step - accuracy: 0.4754 - loss: 0.6933 - val_accuracy: 0.6916 - val_loss: 0.6903
# Epoch 1/50
# 71/71 - 12s - 164ms/step - accuracy: 0.3521 - loss: 0.6988 - val_accuracy: 0.6916 - val_loss: 0.6914
# Epoch 2/50
# 71/71 - 1s - 18ms/step - accuracy: 0.5089 - loss: 0.6932 - val_accuracy: 0.6916 - val_loss: 0.6907
# Epoch 3/50
# 71/71 - 1s - 17ms/step - accuracy: 0.4887 - loss: 0.6932 - val_accuracy: 0.6916 - val_loss: 0.6909
# Epoch 4/50
# 71/71 - 1s - 17ms/step - accuracy: 0.5408 - loss: 0.6934 - val_accuracy: 0.6916 - val_loss: 0.6909
# Epoch 5/50
# 71/71 - 1s - 18ms/step - accuracy: 0.4703 - loss: 0.6933 - val_accuracy: 0.6916 - val_loss: 0.6906
# Epoch 6/50
# 71/71 - 1s - 17ms/step - accuracy: 0.5390 - loss: 0.6932 - val_accuracy: 0.6916 - val_loss: 0.6912
# Epoch 7/50
# 71/71 - 1s - 18ms/step - accuracy: 0.5587 - loss: 0.6929 - val_accuracy: 0.6916 - val_loss: 0.6869
# Epoch 8/50
# 71/71 - 1s - 18ms/step - accuracy: 0.5082 - loss: 0.6933 - val_accuracy: 0.3218 - val_loss: 0.7022
# Epoch 9/50
# 71/71 - 1s - 17ms/step - accuracy: 0.5480 - loss: 0.6603 - val_accuracy: 0.6483 - val_loss: 0.6620
# Epoch 10/50
# 71/71 - 1s - 17ms/step - accuracy: 0.7491 - loss: 0.5418 - val_accuracy: 0.8465 - val_loss: 0.4171
# Epoch 11/50
# 71/71 - 1s - 17ms/step - accuracy: 0.8073 - loss: 0.4569 - val_accuracy: 0.8460 - val_loss: 0.3471
# Epoch 12/50
# 71/71 - 1s - 17ms/step - accuracy: 0.8574 - loss: 0.3497 - val_accuracy: 0.8970 - val_loss: 0.2578
# Epoch 13/50
# 71/71 - 1s - 17ms/step - accuracy: 0.8849 - loss: 0.2827 - val_accuracy: 0.9042 - val_loss: 0.2309
# Epoch 14/50
# 71/71 - 1s - 17ms/step - accuracy: 0.8930 - loss: 0.2594 - val_accuracy: 0.9192 - val_loss: 0.2030
# Epoch 15/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9089 - loss: 0.2334 - val_accuracy: 0.9119 - val_loss: 0.2174
# Epoch 16/50
# 71/71 - 1s - 17ms/step - accuracy: 0.8980 - loss: 0.2403 - val_accuracy: 0.9207 - val_loss: 0.2130
# Epoch 17/50
# 71/71 - 1s - 18ms/step - accuracy: 0.9160 - loss: 0.1997 - val_accuracy: 0.9284 - val_loss: 0.1759
# Epoch 18/50
# 71/71 - 1s - 18ms/step - accuracy: 0.9169 - loss: 0.1997 - val_accuracy: 0.9068 - val_loss: 0.2110
# Epoch 19/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9094 - loss: 0.2082 - val_accuracy: 0.8852 - val_loss: 0.2533
# Epoch 20/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9143 - loss: 0.2008 - val_accuracy: 0.9284 - val_loss: 0.1611
# Epoch 21/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9205 - loss: 0.1864 - val_accuracy: 0.9243 - val_loss: 0.1887
# Epoch 22/50
# 71/71 - 1s - 18ms/step - accuracy: 0.9290 - loss: 0.1752 - val_accuracy: 0.9253 - val_loss: 0.1827
# Epoch 23/50
# 71/71 - 1s - 18ms/step - accuracy: 0.9204 - loss: 0.1882 - val_accuracy: 0.9248 - val_loss: 0.1705
# Epoch 24/50
# 71/71 - 1s - 18ms/step - accuracy: 0.9370 - loss: 0.1553 - val_accuracy: 0.9305 - val_loss: 0.1562
# Epoch 25/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9350 - loss: 0.1595 - val_accuracy: 0.9161 - val_loss: 0.1875
# Epoch 26/50
# 71/71 - 1s - 18ms/step - accuracy: 0.9331 - loss: 0.1577 - val_accuracy: 0.9156 - val_loss: 0.1789
# Epoch 27/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9375 - loss: 0.1543 - val_accuracy: 0.9361 - val_loss: 0.1520
# Epoch 28/50
# 71/71 - 1s - 18ms/step - accuracy: 0.9372 - loss: 0.1494 - val_accuracy: 0.9382 - val_loss: 0.1512
# Epoch 29/50
# 71/71 - 1s - 18ms/step - accuracy: 0.9428 - loss: 0.1398 - val_accuracy: 0.9372 - val_loss: 0.1472
# Epoch 30/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9447 - loss: 0.1342 - val_accuracy: 0.9284 - val_loss: 0.1621
# Epoch 31/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9404 - loss: 0.1439 - val_accuracy: 0.9475 - val_loss: 0.1376
# Epoch 32/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9440 - loss: 0.1339 - val_accuracy: 0.9552 - val_loss: 0.1133
# Epoch 33/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9521 - loss: 0.1196 - val_accuracy: 0.9325 - val_loss: 0.1436
# Epoch 34/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9526 - loss: 0.1193 - val_accuracy: 0.9670 - val_loss: 0.0871
# Epoch 35/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9598 - loss: 0.0971 - val_accuracy: 0.9604 - val_loss: 0.0887
# Epoch 36/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9627 - loss: 0.0985 - val_accuracy: 0.9815 - val_loss: 0.0598
# Epoch 37/50
# 71/71 - 1s - 18ms/step - accuracy: 0.9660 - loss: 0.0868 - val_accuracy: 0.9706 - val_loss: 0.0709
# Epoch 38/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9679 - loss: 0.0816 - val_accuracy: 0.9562 - val_loss: 0.1127
# Epoch 39/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9673 - loss: 0.0860 - val_accuracy: 0.9753 - val_loss: 0.0701
# Epoch 40/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9725 - loss: 0.0765 - val_accuracy: 0.9645 - val_loss: 0.0907
# Epoch 41/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9757 - loss: 0.0696 - val_accuracy: 0.9753 - val_loss: 0.0657
# Epoch 42/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9596 - loss: 0.1096 - val_accuracy: 0.9815 - val_loss: 0.0565
# Epoch 43/50
# 71/71 - 1s - 18ms/step - accuracy: 0.9760 - loss: 0.0656 - val_accuracy: 0.9804 - val_loss: 0.0557
# Epoch 44/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9778 - loss: 0.0631 - val_accuracy: 0.9851 - val_loss: 0.0477
# Epoch 45/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9791 - loss: 0.0601 - val_accuracy: 0.9840 - val_loss: 0.0468
# Epoch 46/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9802 - loss: 0.0564 - val_accuracy: 0.9840 - val_loss: 0.0484
# Epoch 47/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9804 - loss: 0.0542 - val_accuracy: 0.9871 - val_loss: 0.0451
# Epoch 48/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9811 - loss: 0.0497 - val_accuracy: 0.9861 - val_loss: 0.0388
# Epoch 49/50
# 71/71 - 1s - 18ms/step - accuracy: 0.9806 - loss: 0.0517 - val_accuracy: 0.9846 - val_loss: 0.0487
# Epoch 50/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9819 - loss: 0.0509 - val_accuracy: 0.9861 - val_loss: 0.0393
