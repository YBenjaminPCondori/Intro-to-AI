# %% [markdown]
# # CNN Random Search Hyperparameter Optimisation
#
# Derived directly from the uploaded source notebook. Random Search tunes the model using validation F1; the held-out test set is untouched.

# %% [markdown]
# ## 1. Environment Setup
#
# Run this notebook from a clean Google Colab session or locally.

# %% [markdown]
# ## 2. Package Installation

# %% [markdown]
# This cell checks whether the libraries required by the CNN workflow are installed and installs only the missing packages before the remaining audio-processing, analysis, plotting, and modelling steps run.

# %%
# Purpose: Checks whether the libraries required by the CNN workflow are installed and installs
# only the missing packages before the remaining audio-processing, analysis, plotting, and
# modelling steps run.
import importlib.util
import subprocess
import sys

# List the import names and their corresponding installable package names.
required_packages = [
    ("librosa", "librosa"),
    ("soundfile", "soundfile"),
    ("numpy", "numpy"),
    ("pandas", "pandas"),
    ("sklearn", "scikit-learn"),
    ("matplotlib", "matplotlib"),
    ("seaborn", "seaborn"),
    ("joblib", "joblib"),
    ("tensorflow", "tensorflow"),
]

# Install only dependencies that are not already available in the active kernel.
missing = [pip_name for import_name, pip_name in required_packages if importlib.util.find_spec(import_name) is None]
if missing:
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", *missing])
else:
    print("Required packages are already installed.")
# Out:
# Required packages are already installed.

# %% [markdown]
# ## 3. Imports

# %% [markdown]
# This cell imports the standard-library and third-party tools used by the CNN workflow and provides a print-based fallback when the richer notebook display function is unavailable.

# %%
# Purpose: Imports the standard-library and third-party tools used by the CNN workflow and
# provides a print-based fallback when the richer notebook display function is unavailable.
import json
import os
import random
from pathlib import Path

import librosa
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score, precision_score, recall_score
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Activation, Conv2D, Dense, Dropout, Flatten, Input, MaxPooling2D
from tensorflow.keras.models import Sequential

try:
    from IPython.display import display
except Exception:
    display = print

# %% [markdown]
# ## 4. Configuration and Random Seeds

# %% [markdown]
# This cell fixes the available random seeds for reproducibility and defines the shared audio, MFCC, class, sampling, and CNN training settings used later in the notebook.

# %%
# Purpose: Fixes the available random seeds for reproducibility and defines the shared audio,
# MFCC, class, sampling, and CNN training settings used later in the notebook.
# Use a fixed seed so sampling, splitting, and model initialisation can be repeated.
RANDOM_STATE = 42
random.seed(RANDOM_STATE)
np.random.seed(RANDOM_STATE)
tf.keras.utils.set_random_seed(RANDOM_STATE)
os.environ["PYTHONHASHSEED"] = str(RANDOM_STATE)

# Configure the fixed audio representation and MFCC analysis window.
SAMPLE_RATE = 22050
FIXED_DURATION_SECONDS = 5.0
N_MFCC = 40
N_FFT = 1024
HOP_LENGTH = int(round(SAMPLE_RATE * 0.010))
WIN_LENGTH = int(round(SAMPLE_RATE * 0.025))

AUDIO_EXTENSIONS = {".wav", ".flac", ".mp3", ".ogg", ".m4a"}
CLASS_NAMES = {0: "bona_fide", 1: "synthetic"}

# Keep dataset and training limits together so quick runs are easy to configure.
MAX_FILES_PER_CLASS = None  # Set to a small number, such as 40, for a quick check.
EPOCHS = 30
BATCH_SIZE = 128

# %% [markdown]
# ## 5. Dataset Paths

# %% [markdown]
# This cell defines and calls a portable helper that mounts Google Drive when Colab is available and otherwise continues without failing in a local environment.

# %%
# Purpose: Defines and calls a portable helper that mounts Google Drive when Colab is available
# and otherwise continues without failing in a local environment.
# Mount Google Drive when the notebook is running in Colab.
def mount_drive_if_colab(mount_point="/content/drive"):
    try:
        from google.colab import drive
        drive.mount(mount_point)
    except Exception:
        print("Not running in Colab, or Google Drive is already available.")

mount_drive_if_colab()
# Out:
# Mounted at /content/drive

# %% [markdown]
# This cell defines the synthetic and bona-fide dataset paths, creates the output folders required by the CNN workflow, and prints the active locations for confirmation.

# %%
# Purpose: Defines the synthetic and bona-fide dataset paths, creates the output folders
# required by the CNN workflow, and prints the active locations for confirmation.
# Change these paths to match your Google Drive dataset folders.
# Set the shared root used to locate the two audio classes.
PROJECT_ROOT = Path("/content/drive/MyDrive/Colab Notebooks/Education/INM701")
SYNTHETIC_AUDIO_DIR = PROJECT_ROOT / "Datasets" / "MLAAD_10pct"
BONA_FIDE_AUDIO_DIR = PROJECT_ROOT / "Datasets" / "M_AILABS_bona_fide_subset"

# Build a model-specific output hierarchy under the project root.
OUTPUT_DIR = PROJECT_ROOT / "outputs" / "cnn"
FIGURES_DIR = OUTPUT_DIR / "figures"
METRICS_DIR = OUTPUT_DIR / "metrics"
MODELS_DIR = OUTPUT_DIR / "models"
TABLES_DIR = OUTPUT_DIR / "tables"

# Create every output directory before any files are saved.
for directory in [OUTPUT_DIR, FIGURES_DIR, METRICS_DIR, MODELS_DIR, TABLES_DIR]:
    directory.mkdir(parents=True, exist_ok=True)

print("Synthetic audio directory:", SYNTHETIC_AUDIO_DIR)
print("Bona-fide audio directory:", BONA_FIDE_AUDIO_DIR)
print("Output directory:", OUTPUT_DIR)
# Out:
# Synthetic audio directory: /content/drive/MyDrive/Colab Notebooks/Education/INM701/Datasets/MLAAD_10pct
# Bona-fide audio directory: /content/drive/MyDrive/Colab Notebooks/Education/INM701/Datasets/M_AILABS_bona_fide_subset
# Output directory: /content/drive/MyDrive/Colab Notebooks/Education/INM701/outputs/cnn

# %% [markdown]
# ## 6. Dataset Loading / Audio File Scan

# %% [markdown]
# This cell defines a recursive scanner that validates a dataset folder and records each supported audio file's path, class label, inferred language, and size in a Pandas table.

# %%
# Purpose: Defines a recursive scanner that validates a dataset folder and records each
# supported audio file's path, class label, inferred language, and size in a Pandas table.
# Convert the supported files under one class directory into manifest rows.
def scan_audio_files(root_dir, label, class_name):
    root_dir = Path(root_dir)
    if not root_dir.exists():
        raise FileNotFoundError(f"Folder not found: {root_dir}")

    rows = []
    for path in sorted(root_dir.rglob("*")):
        if path.is_file() and path.suffix.lower() in AUDIO_EXTENSIONS:
            rows.append({
                "path": str(path),
                "relative_path": str(path.relative_to(root_dir)),
                "label": label,
                "class_name": class_name,
                "language": path.parent.name,
                "file_size_mb": path.stat().st_size / (1024 * 1024),
            })
    return pd.DataFrame(rows)

# %% [markdown]
# This cell scans both class directories, optionally limits each class for a quick run, combines and reproducibly shuffles the records into one manifest, and displays a short preview.

# %%
# Purpose: Scans both class directories, optionally limits each class for a quick run, combines
# and reproducibly shuffles the records into one manifest, and displays a short preview.
# Scan the synthetic and bona-fide directories separately with their correct labels.
synthetic_manifest = scan_audio_files(SYNTHETIC_AUDIO_DIR, label=1, class_name=CLASS_NAMES[1])
bona_fide_manifest = scan_audio_files(BONA_FIDE_AUDIO_DIR, label=0, class_name=CLASS_NAMES[0])

# Optionally draw a reproducible smaller sample for a quick test run.
if MAX_FILES_PER_CLASS:
    synthetic_manifest = synthetic_manifest.sample(min(MAX_FILES_PER_CLASS, len(synthetic_manifest)), random_state=RANDOM_STATE)
    bona_fide_manifest = bona_fide_manifest.sample(min(MAX_FILES_PER_CLASS, len(bona_fide_manifest)), random_state=RANDOM_STATE)

# Merge both classes into one shuffled manifest for later splitting.
manifest = pd.concat([bona_fide_manifest, synthetic_manifest], ignore_index=True)
manifest = manifest.sample(frac=1.0, random_state=RANDOM_STATE).reset_index(drop=True)

print("Total files:", len(manifest))
display(manifest.head())
# Out:
# Total files: 12944
#                                                 path  \
# 0  /content/drive/MyDrive/Colab Notebooks/Educati...
# 1  /content/drive/MyDrive/Colab Notebooks/Educati...
# 2  /content/drive/MyDrive/Colab Notebooks/Educati...
# 3  /content/drive/MyDrive/Colab Notebooks/Educati...
# 4  /content/drive/MyDrive/Colab Notebooks/Educati...
#
#                                        relative_path  label class_name  \
# 0  fake/en/Llasa-1B-Multilingual/pink_fairy_book_...      1  synthetic
# 1  fake/de/Chatterbox Multilingual/altehaus_009_1...      1  synthetic
# 2  fake/en/Metavoice-1B/northandsouth_38_f000272.wav      1  synthetic
# 3                 en/en/northandsouth_05_f000169.wav      0  bona_fide
# 4                  en/en/poisoned_pen_08_f000016.wav      0  bona_fide
#
#                   language  file_size_mb
# 0    Llasa-1B-Multilingual      0.368462
# 1  Chatterbox Multilingual      0.415565
# 2             Metavoice-1B      0.055557
# 3                       en      0.130991
# 4                       en      0.302805

# %% [markdown]
# ## 7. Dataset Inspection

# %% [markdown]
# This cell summarises the manifest by class and language and displays the overall class counts together with the 20 most frequent class-language combinations.

# %%
# Purpose: Summarises the manifest by class and language and displays the overall class counts
# together with the 20 most frequent class-language combinations.
# Count recordings by class and by class-language combination.
class_summary = manifest.groupby(["label", "class_name"]).size().reset_index(name="files")
language_summary = manifest.groupby(["class_name", "language"]).size().reset_index(name="files")

display(class_summary)
display(language_summary.sort_values("files", ascending=False).head(20))
# Out:
#    label class_name  files
# 0      0  bona_fide   3997
# 1      1  synthetic   8947
#    class_name                 language  files
# 1   bona_fide                       en   3282
# 0   bona_fide                       de    715
# 6   synthetic                 Edge-TTS    407
# 43  synthetic                OmniVoice    402
# 55  synthetic                  VoxCPM2    295
# 9   synthetic              Fish-S2-Pro    288
# 56  synthetic                  Voxtral    283
# 18  synthetic               KugelAudio    214
# 20  synthetic                LEMAS-TTS    195
# 15  synthetic            Kani-TTS-370M    191
# 13  synthetic                  IndicF5    191
# 12  synthetic          Hume TADA-3B-ML    187
# 62  synthetic              griffin_lim    184
# 28  synthetic            MOSS-TTS-1.7B    181
# 11  synthetic           Higgs-Audio-V2    175
# 75  synthetic            zonosTTS-v0.1    172
# 46  synthetic                  OuteTTS    169
# 65  synthetic  minimax_speech-02-turbo    164
# 23  synthetic    Llasa-1B-Multilingual    164
# 14  synthetic            Indri-TTS-0.1    151

# %% [markdown]
# ## 8. Data Quality Checks

# %% [markdown]
# This cell measures missing paths, files absent from disk, duplicate paths, and represented classes, then stops the workflow if both labels are not present or duplicate recordings could compromise the experiment.

# %%
# Purpose: Measures missing paths, files absent from disk, duplicate paths, and represented
# classes, then stops the workflow if both labels are not present or duplicate recordings could
# compromise the experiment.
# Calculate manifest checks before any expensive audio processing begins.
quality_checks = pd.DataFrame([
    {"check": "missing_paths", "value": int(manifest["path"].isna().sum())},
    {"check": "missing_files", "value": int((~manifest["path"].map(lambda p: Path(p).exists())).sum())},
    {"check": "duplicate_paths", "value": int(manifest["path"].duplicated().sum())},
    {"check": "classes_present", "value": ", ".join(map(str, sorted(manifest["label"].unique())))},
])

display(quality_checks)

# Stop early if the manifest does not contain both required target classes.
if set(manifest["label"].unique()) != {0, 1}:
    raise ValueError("Both classes are required: 0=bona-fide and 1=synthetic/deepfake.")
if manifest["path"].duplicated().any():
    raise ValueError("Duplicate audio paths were found. Remove duplicates before training.")
# Out:
#              check value
# 0    missing_paths     0
# 1    missing_files     0
# 2  duplicate_paths     0
# 3  classes_present  0, 1

# %% [markdown]
# ## 9. Audio Preprocessing
#
# Audio is loaded as mono, resampled, padded or truncated, and normalised.

# %% [markdown]
# ## 10. MFCC Feature Extraction

# %% [markdown]
# This cell computes the expected number of time frames, standardises each recording to a fixed duration and amplitude, and extracts a consistently sized two-dimensional MFCC map for CNN input.

# %%
# Purpose: Computes the expected number of time frames, standardises each recording to a fixed
# duration and amplitude, and extracts a consistently sized two-dimensional MFCC map for CNN
# input.
# Derive the fixed MFCC time dimension from the audio and framing settings.
EXPECTED_FRAMES = 1 + max(0, int(SAMPLE_RATE * FIXED_DURATION_SECONDS) - N_FFT) // HOP_LENGTH
print("Expected CNN MFCC map shape:", (N_MFCC, EXPECTED_FRAMES, 1))


# Resample, pad or truncate, and peak-normalise every waveform consistently.
def load_audio_fixed(path):
    audio, _ = librosa.load(path, sr=SAMPLE_RATE, mono=True)
    target_length = int(SAMPLE_RATE * FIXED_DURATION_SECONDS)

    if len(audio) < target_length:
        audio = np.pad(audio, (0, target_length - len(audio)))
    else:
        audio = audio[:target_length]

    peak = np.max(np.abs(audio))
    if peak > 0:
        audio = audio / peak

    return audio.astype(np.float32)


# Transform the standardised waveform into the MFCC representation required downstream.
def extract_mfcc_map(path):
    audio = load_audio_fixed(path)
    mfcc = librosa.feature.mfcc(
        y=audio,
        sr=SAMPLE_RATE,
        n_mfcc=N_MFCC,
        n_fft=N_FFT,
        hop_length=HOP_LENGTH,
        win_length=WIN_LENGTH,
        center=False,
    ).astype(np.float32)

    if mfcc.shape[1] < EXPECTED_FRAMES:
        mfcc = np.pad(mfcc, ((0, 0), (0, EXPECTED_FRAMES - mfcc.shape[1])))
    else:
        mfcc = mfcc[:, :EXPECTED_FRAMES]

    return mfcc
# Out:
# Expected CNN MFCC map shape: (40, 497, 1)

# %% [markdown]
# ## 11. Label Preparation

# %% [markdown]
# This cell states the binary label mapping and displays the number of bona-fide and synthetic recordings so the target variable can be checked before splitting and modelling.

# %%
# Purpose: States the binary label mapping and displays the number of bona-fide and synthetic
# recordings so the target variable can be checked before splitting and modelling.
print("Label meaning: 0 = bona-fide, 1 = synthetic/deepfake")
display(manifest["label"].value_counts().sort_index().rename(index=CLASS_NAMES).to_frame("files"))
# Out:
# Label meaning: 0 = bona-fide, 1 = synthetic/deepfake
#            files
# label
# bona_fide   3997
# synthetic   8947

# %% [markdown]
# ## 12. Train / Validation / Test Split

# %% [markdown]
# This cell creates reproducible stratified training, validation, and test partitions in a 70:15:15 ratio, resets their row indexes, and displays the size and class balance of each split.

# %%
# Purpose: Creates reproducible stratified training, validation, and test partitions in a
# 70:15:15 ratio, resets their row indexes, and displays the size and class balance of each
# split.
# Reserve 30 percent of the manifest before dividing it equally into validation and test data.
train_df, temp_df = train_test_split(
    manifest,
    test_size=0.30,
    random_state=RANDOM_STATE,
    stratify=manifest["label"],
)

# Split the held-out portion equally while preserving the class distribution.
validation_df, test_df = train_test_split(
    temp_df,
    test_size=0.50,
    random_state=RANDOM_STATE,
    stratify=temp_df["label"],
)

train_df = train_df.reset_index(drop=True)
validation_df = validation_df.reset_index(drop=True)
test_df = test_df.reset_index(drop=True)

split_summary = pd.DataFrame({
    "split": ["train", "validation", "test"],
    "rows": [len(train_df), len(validation_df), len(test_df)],
    "bona_fide": [int((train_df["label"] == 0).sum()), int((validation_df["label"] == 0).sum()), int((test_df["label"] == 0).sum())],
    "synthetic": [int((train_df["label"] == 1).sum()), int((validation_df["label"] == 1).sum()), int((test_df["label"] == 1).sum())],
})
display(split_summary)
# Out:
#         split  rows  bona_fide  synthetic
# 0       train  9060       2798       6262
# 1  validation  1942        599       1343
# 2        test  1942        600       1342

# %% [markdown]
# ## 13. CNN MFCC Map Preparation

# %% [markdown]
# This cell computes the expected number of time frames, standardises each recording to a fixed duration and amplitude, and extracts a consistently sized two-dimensional MFCC map for CNN input.

# %%
# Purpose: Computes the expected number of time frames, standardises each recording to a fixed
# duration and amplitude, and extracts a consistently sized two-dimensional MFCC map for CNN
# input.
# Convert a manifest split into aligned model inputs, labels, and retained metadata.
def build_mfcc_map_table(df, split_name):
    maps = []
    labels = []
    kept_rows = []

    for _, row in df.iterrows():
        try:
            maps.append(extract_mfcc_map(row["path"]))
            labels.append(int(row["label"]))
            kept_rows.append(row)
        except Exception as exc:
            print(f"Skipping {row['path']}: {exc}")

    X = np.stack(maps).astype(np.float32)
    X = X[..., np.newaxis]
    y = np.array(labels, dtype=np.int64)
    meta = pd.DataFrame(kept_rows).reset_index(drop=True)
    print(f"{split_name}: {X.shape}")
    return X, y, meta

X_train, y_train, train_meta = build_mfcc_map_table(train_df, "train")
X_validation, y_validation, validation_meta = build_mfcc_map_table(validation_df, "validation")
# Out:
# train: (9060, 40, 497, 1)
# validation: (1942, 40, 497, 1)

# %% [markdown]
# ## 14. Train-only MFCC Map Standardisation

# %% [markdown]
# This cell calculates MFCC-map normalisation statistics from the training split only and applies them to both the training and validation tensors before reporting the CNN input shape.

# %%
# Purpose: Calculates MFCC-map normalisation statistics from the training split only and applies
# them to both the training and validation tensors before reporting the CNN input shape.
# Estimate normalisation statistics from the training tensor only.
mfcc_mean = X_train.mean(axis=(0, 2), keepdims=True)
mfcc_std = X_train.std(axis=(0, 2), keepdims=True) + 1e-6

X_train_scaled = (X_train - mfcc_mean) / mfcc_std
X_validation_scaled = (X_validation - mfcc_mean) / mfcc_std

print("MFCC map standardisation fitted on training data only.")
print("CNN input shape:", X_train_scaled.shape[1:])
# Out:
# MFCC map standardisation fitted on training data only.
# CNN input shape: (40, 497, 1)

# %% [markdown]
# ## 15. CNN Model Definition

# %% [markdown]
# This cell constructs and summarises an example CNN with two convolution and pooling stages, dropout regularisation, a dense hidden layer, and a sigmoid output for binary classification.

# %%
# Purpose: Constructs and summarises an example CNN with two convolution and pooling stages,
# dropout regularisation, a dense hidden layer, and a sigmoid output for binary classification.
# Construct a representative estimator so its architecture or configuration can be inspected.
example_model = Sequential()
example_model.add(Input(shape=X_train_scaled.shape[1:]))
example_model.add(Conv2D(32, kernel_size=(3, 3), strides=1, padding="same"))
example_model.add(Activation("relu"))
example_model.add(MaxPooling2D(pool_size=(2, 2)))
example_model.add(Dropout(0.30))
example_model.add(Conv2D(64, kernel_size=(3, 3), strides=1, padding="same"))
example_model.add(Activation("relu"))
example_model.add(MaxPooling2D(pool_size=(2, 2)))
example_model.add(Dropout(0.30))
example_model.add(Flatten())
example_model.add(Dense(64, activation="relu"))
example_model.add(Dense(1, activation="sigmoid"))

example_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
example_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 40, 497, 32)    │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 40, 497, 32)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 20, 248, 32)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 20, 248, 32)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 20, 248, 64)    │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 20, 248, 64)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 10, 124, 64)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 10, 124, 64)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 79360)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │     5,079,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,097,985 (19.45 MB)
#  Trainable params: 5,097,985 (19.45 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## 16. Training

# %% [markdown]
# This cell documents that model fitting happens in the following validation experiment and that early stopping uses validation loss while restoring the best recorded epoch.

# %%
# Purpose: Documents that model fitting happens in the following validation experiment and that
# early stopping uses validation loss while restoring the best recorded epoch.
# The model is trained in the validation experiment loop below.
# Early stopping watches validation loss and restores the best validation epoch.

# %% [markdown]
# ## 17. Random Search Hyperparameter Optimisation

# %% [markdown]
# This cell trains the candidate CNN architectures with early stopping and best-checkpoint saving, measures their validation performance, ranks them by F1 score, and reloads the selected model.

# %%
# Purpose: Tune the uploaded CNN using reproducible Random Search and validation F1.
# The held-out test split is never used during this search.
OPTIMISATION_DIR = OUTPUT_DIR / "optimisation"
OPTIMISATION_DIR.mkdir(parents=True, exist_ok=True)
RANDOM_SEARCH_TRIALS = 12
SEARCH_SPACE = {'filters': [[16, 32], [32, 64], [64, 128], [32, 64, 128]], 'kernel_size': [[3, 3], [5, 3]], 'dense_units': [32, 64, 128], 'dropout': [0.2, 0.3, 0.4, 0.5], 'learning_rate': [0.0001, 0.0003, 0.001, 0.003], 'batch_size': [32, 64, 128]}

def build_model(config):
    """Build the CNN architecture from one hyperparameter configuration."""
    model = Sequential()
    model.add(Input(shape=X_train_scaled.shape[1:]))
    kernel_size = tuple(config["kernel_size"])
    for filters in config["filters"]:
        model.add(Conv2D(int(filters), kernel_size=kernel_size, strides=1, padding="same"))
        model.add(Activation("relu"))
        model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Dropout(float(config["dropout"])))
    model.add(Flatten())
    model.add(Dense(int(config["dense_units"]), activation="relu"))
    model.add(Dropout(float(config["dropout"])))
    model.add(Dense(1, activation="sigmoid"))
    optimizer = tf.keras.optimizers.Adam(learning_rate=float(config["learning_rate"]))
    model.compile(loss="binary_crossentropy", optimizer=optimizer, metrics=["accuracy"])
    return model

def all_configurations(space):
    """Expand the discrete search space into unique configurations for sampling."""
    keys = list(space)
    configs = [{}]
    for key in keys:
        configs = [{**cfg, key: value} for cfg in configs for value in space[key]]
    return configs

rng = random.Random(RANDOM_STATE)
all_configs = all_configurations(SEARCH_SPACE)
trial_configs = rng.sample(all_configs, k=min(RANDOM_SEARCH_TRIALS, len(all_configs)))
results = []

for trial_number, config in enumerate(trial_configs, start=1):
    print(f"\nRandom Search trial {trial_number}/{len(trial_configs)}: {config}")
    tf.keras.backend.clear_session()
    tf.keras.utils.set_random_seed(RANDOM_STATE)
    model = build_model(config)
    callbacks = [tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True)]
    history = model.fit(
        X_train_scaled, y_train,
        validation_data=(X_validation_scaled, y_validation),
        epochs=EPOCHS,
        batch_size=int(config["batch_size"]),
        callbacks=callbacks,
        verbose=2,
    )
    probability = model.predict(X_validation_scaled, batch_size=int(config["batch_size"])).ravel()
    pred = (probability >= 0.5).astype(int)
    results.append({
        "trial": trial_number,
        "config": config,
        "accuracy": float(accuracy_score(y_validation, pred)),
        "precision": float(precision_score(y_validation, pred, zero_division=0)),
        "recall": float(recall_score(y_validation, pred, zero_division=0)),
        "f1": float(f1_score(y_validation, pred, zero_division=0)),
        "best_val_loss": float(np.min(history.history["val_loss"])),
        "best_epoch": int(np.argmin(history.history["val_loss"]) + 1),
        "epochs_trained": int(len(history.history["loss"])),
    })

results_df = pd.DataFrame([{"trial": r["trial"], **r["config"], "accuracy": r["accuracy"], "precision": r["precision"], "recall": r["recall"], "f1": r["f1"], "best_val_loss": r["best_val_loss"], "best_epoch": r["best_epoch"]} for r in results]).sort_values("f1", ascending=False)
display(results_df)
best = max(results, key=lambda r: (r["f1"], -r["best_val_loss"]))
best_payload = {"method": "random_search", "model": 'CNN', "validation_f1": best["f1"], "validation_accuracy": best["accuracy"], "best_val_loss": best["best_val_loss"], "config": best["config"]}

results_df.to_csv(OPTIMISATION_DIR / "random_search_results.csv", index=False)
with open(OPTIMISATION_DIR / "random_search_best.json", "w", encoding="utf-8") as f:
    json.dump(best_payload, f, indent=2)
print("Best Random Search configuration:", best_payload)
print("Saved:", OPTIMISATION_DIR / "random_search_best.json")
# Out:
# Random Search trial 1/12: {'filters': [16, 32], 'kernel_size': [5, 3], 'dense_units': 64, 'dropout': 0.5, 'learning_rate': 0.0001, 'batch_size': 32}
# Epoch 1/30
# 284/284 - 13s - 46ms/step - accuracy: 0.8936 - loss: 0.2823 - val_accuracy: 0.9526 - val_loss: 0.1974
# Epoch 2/30
# 284/284 - 3s - 11ms/step - accuracy: 0.9450 - loss: 0.1854 - val_accuracy: 0.9629 - val_loss: 0.1481
# Epoch 3/30
# 284/284 - 3s - 11ms/step - accuracy: 0.9553 - loss: 0.1581 - val_accuracy: 0.9665 - val_loss: 0.1388
# Epoch 4/30
# 284/284 - 3s - 11ms/step - accuracy: 0.9604 - loss: 0.1397 - val_accuracy: 0.9706 - val_loss: 0.1256
# Epoch 5/30
# 284/284 - 3s - 11ms/step - accuracy: 0.9634 - loss: 0.1304 - val_accuracy: 0.9722 - val_loss: 0.1271
# Epoch 6/30
# 284/284 - 3s - 11ms/step - accuracy: 0.9688 - loss: 0.1117 - val_accuracy: 0.9737 - val_loss: 0.1201
# Epoch 7/30
# 284/284 - 3s - 11ms/step - accuracy: 0.9702 - loss: 0.1072 - val_accuracy: 0.9696 - val_loss: 0.1430
# Epoch 8/30
# 284/284 - 3s - 11ms/step - accuracy: 0.9712 - loss: 0.0999 - val_accuracy: 0.9737 - val_loss: 0.1180
# Epoch 9/30
# 284/284 - 3s - 11ms/step - accuracy: 0.9735 - loss: 0.0904 - val_accuracy: 0.9784 - val_loss: 0.0967
# Epoch 10/30
# 284/284 - 3s - 11ms/step - accuracy: 0.9759 - loss: 0.0817 - val_accuracy: 0.9784 - val_loss: 0.1049
# Epoch 11/30
# 284/284 - 3s - 11ms/step - accuracy: 0.9774 - loss: 0.0778 - val_accuracy: 0.9784 - val_loss: 0.0891
# Epoch 12/30
# 284/284 - 3s - 11ms/step - accuracy: 0.9776 - loss: 0.0688 - val_accuracy: 0.9784 - val_loss: 0.0897
# Epoch 13/30
# 284/284 - 3s - 11ms/step - accuracy: 0.9779 - loss: 0.0654 - val_accuracy: 0.9789 - val_loss: 0.0871
# Epoch 14/30
# 284/284 - 3s - 11ms/step - accuracy: 0.9800 - loss: 0.0597 - val_accuracy: 0.9779 - val_loss: 0.0929
# Epoch 15/30
# 284/284 - 3s - 11ms/step - accuracy: 0.9792 - loss: 0.0576 - val_accuracy: 0.9794 - val_loss: 0.0963
# Epoch 16/30
# 284/284 - 3s - 11ms/step - accuracy: 0.9802 - loss: 0.0527 - val_accuracy: 0.9809 - val_loss: 0.0818
# Epoch 17/30
# 284/284 - 3s - 11ms/step - accuracy: 0.9815 - loss: 0.0528 - val_accuracy: 0.9804 - val_loss: 0.0826
# Epoch 18/30
# 284/284 - 3s - 11ms/step - accuracy: 0.9805 - loss: 0.0485 - val_accuracy: 0.9804 - val_loss: 0.0763
# Epoch 19/30
# 284/284 - 3s - 11ms/step - accuracy: 0.9809 - loss: 0.0453 - val_accuracy: 0.9804 - val_loss: 0.0772
# Epoch 20/30
# 284/284 - 3s - 11ms/step - accuracy: 0.9822 - loss: 0.0449 - val_accuracy: 0.9804 - val_loss: 0.0752
# Epoch 21/30
# 284/284 - 3s - 11ms/step - accuracy: 0.9821 - loss: 0.0407 - val_accuracy: 0.9804 - val_loss: 0.0638
# Epoch 22/30
# 284/284 - 3s - 11ms/step - accuracy: 0.9833 - loss: 0.0383 - val_accuracy: 0.9804 - val_loss: 0.0755
# Epoch 23/30
# 284/284 - 3s - 11ms/step - accuracy: 0.9840 - loss: 0.0337 - val_accuracy: 0.9799 - val_loss: 0.0780
# Epoch 24/30
# 284/284 - 3s - 11ms/step - accuracy: 0.9839 - loss: 0.0372 - val_accuracy: 0.9804 - val_loss: 0.0600
# Epoch 25/30
# 284/284 - 3s - 11ms/step - accuracy: 0.9827 - loss: 0.0354 - val_accuracy: 0.9809 - val_loss: 0.0696
# Epoch 26/30
# 284/284 - 3s - 11ms/step - accuracy: 0.9843 - loss: 0.0329 - val_accuracy: 0.9815 - val_loss: 0.0622
# Epoch 27/30
# 284/284 - 3s - 11ms/step - accuracy: 0.9847 - loss: 0.0294 - val_accuracy: 0.9804 - val_loss: 0.0670
# Epoch 28/30
# 284/284 - 3s - 11ms/step - accuracy: 0.9849 - loss: 0.0298 - val_accuracy: 0.9820 - val_loss: 0.0582
# Epoch 29/30
# 284/284 - 3s - 11ms/step - accuracy: 0.9859 - loss: 0.0282 - val_accuracy: 0.9820 - val_loss: 0.0636
# Epoch 30/30
# 284/284 - 3s - 11ms/step - accuracy: 0.9868 - loss: 0.0281 - val_accuracy: 0.9861 - val_loss: 0.0588
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
#
# Random Search trial 2/12: {'filters': [16, 32], 'kernel_size': [3, 3], 'dense_units': 64, 'dropout': 0.2, 'learning_rate': 0.0003, 'batch_size': 32}
# Epoch 1/30
# 284/284 - 12s - 43ms/step - accuracy: 0.9374 - loss: 0.1927 - val_accuracy: 0.9701 - val_loss: 0.1078
# Epoch 2/30
# 284/284 - 3s - 11ms/step - accuracy: 0.9701 - loss: 0.1038 - val_accuracy: 0.9784 - val_loss: 0.0839
# Epoch 3/30
# 284/284 - 3s - 11ms/step - accuracy: 0.9779 - loss: 0.0683 - val_accuracy: 0.9789 - val_loss: 0.0772
# Epoch 4/30
# 284/284 - 3s - 11ms/step - accuracy: 0.9805 - loss: 0.0526 - val_accuracy: 0.9789 - val_loss: 0.0763
# Epoch 5/30
# 284/284 - 3s - 11ms/step - accuracy: 0.9830 - loss: 0.0425 - val_accuracy: 0.9820 - val_loss: 0.0626
# Epoch 6/30
# 284/284 - 3s - 11ms/step - accuracy: 0.9885 - loss: 0.0260 - val_accuracy: 0.9784 - val_loss: 0.0836
# Epoch 7/30
# 284/284 - 3s - 10ms/step - accuracy: 0.9918 - loss: 0.0215 - val_accuracy: 0.9809 - val_loss: 0.0735
# Epoch 8/30
# 284/284 - 3s - 10ms/step - accuracy: 0.9943 - loss: 0.0169 - val_accuracy: 0.9799 - val_loss: 0.0903
# Epoch 9/30
# 284/284 - 3s - 10ms/step - accuracy: 0.9947 - loss: 0.0152 - val_accuracy: 0.9846 - val_loss: 0.0633
# Epoch 10/30
# 284/284 - 3s - 11ms/step - accuracy: 0.9955 - loss: 0.0141 - val_accuracy: 0.9840 - val_loss: 0.0687
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
#
# Random Search trial 3/12: {'filters': [32, 64], 'kernel_size': [5, 3], 'dense_units': 128, 'dropout': 0.4, 'learning_rate': 0.003, 'batch_size': 128}
# Epoch 1/30
# 71/71 - 25s - 352ms/step - accuracy: 0.6606 - loss: 2.0986 - val_accuracy: 0.6916 - val_loss: 0.6406
# Epoch 2/30
# 71/71 - 5s - 73ms/step - accuracy: 0.6912 - loss: 0.6299 - val_accuracy: 0.6916 - val_loss: 0.6195
# Epoch 3/30
# 71/71 - 5s - 74ms/step - accuracy: 0.6912 - loss: 0.6241 - val_accuracy: 0.6916 - val_loss: 0.6184
# Epoch 4/30
# 71/71 - 5s - 74ms/step - accuracy: 0.6912 - loss: 0.6231 - val_accuracy: 0.6916 - val_loss: 0.6184
# Epoch 5/30
# 71/71 - 5s - 73ms/step - accuracy: 0.6912 - loss: 0.6222 - val_accuracy: 0.6916 - val_loss: 0.6181
# Epoch 6/30
# 71/71 - 5s - 74ms/step - accuracy: 0.6912 - loss: 0.6214 - val_accuracy: 0.6916 - val_loss: 0.6181
# Epoch 7/30
# 71/71 - 5s - 74ms/step - accuracy: 0.6912 - loss: 0.6211 - val_accuracy: 0.6916 - val_loss: 0.6181
# Epoch 8/30
# 71/71 - 5s - 74ms/step - accuracy: 0.6912 - loss: 0.6212 - val_accuracy: 0.6916 - val_loss: 0.6181
# Epoch 9/30
# 71/71 - 5s - 74ms/step - accuracy: 0.6912 - loss: 0.6205 - val_accuracy: 0.6916 - val_loss: 0.6180
# Epoch 10/30
# 71/71 - 5s - 74ms/step - accuracy: 0.6912 - loss: 0.6189 - val_accuracy: 0.6916 - val_loss: 0.6179
# Epoch 11/30
# 71/71 - 5s - 74ms/step - accuracy: 0.6912 - loss: 0.6197 - val_accuracy: 0.6916 - val_loss: 0.6179
# Epoch 12/30
# 71/71 - 5s - 74ms/step - accuracy: 0.6912 - loss: 0.6208 - val_accuracy: 0.6916 - val_loss: 0.6180
# Epoch 13/30
# 71/71 - 5s - 74ms/step - accuracy: 0.6912 - loss: 0.6197 - val_accuracy: 0.6916 - val_loss: 0.6179
# Epoch 14/30
# 71/71 - 5s - 74ms/step - accuracy: 0.6912 - loss: 0.6191 - val_accuracy: 0.6916 - val_loss: 0.6179
# Epoch 15/30
# 71/71 - 5s - 74ms/step - accuracy: 0.6912 - loss: 0.6197 - val_accuracy: 0.6916 - val_loss: 0.6179
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step
#
# Random Search trial 4/12: {'filters': [32, 64], 'kernel_size': [5, 3], 'dense_units': 64, 'dropout': 0.3, 'learning_rate': 0.003, 'batch_size': 32}
# Epoch 1/30
# 284/284 - 16s - 58ms/step - accuracy: 0.6904 - loss: 0.6986 - val_accuracy: 0.6916 - val_loss: 0.6186
# Epoch 2/30
# 284/284 - 6s - 21ms/step - accuracy: 0.6912 - loss: 0.6199 - val_accuracy: 0.6916 - val_loss: 0.6188
# Epoch 3/30
# 284/284 - 6s - 21ms/step - accuracy: 0.6912 - loss: 0.6194 - val_accuracy: 0.6916 - val_loss: 0.6187
# Epoch 4/30
# 284/284 - 6s - 21ms/step - accuracy: 0.6912 - loss: 0.6188 - val_accuracy: 0.6916 - val_loss: 0.6188
# Epoch 5/30
# 284/284 - 6s - 21ms/step - accuracy: 0.6912 - loss: 0.6194 - val_accuracy: 0.6916 - val_loss: 0.6186
# Epoch 6/30
# 284/284 - 6s - 21ms/step - accuracy: 0.6912 - loss: 0.6191 - val_accuracy: 0.6916 - val_loss: 0.6187
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
#
# Random Search trial 5/12: {'filters': [32, 64], 'kernel_size': [5, 3], 'dense_units': 32, 'dropout': 0.4, 'learning_rate': 0.0001, 'batch_size': 64}
# Epoch 1/30
# 142/142 - 17s - 121ms/step - accuracy: 0.8287 - loss: 0.3736 - val_accuracy: 0.9686 - val_loss: 0.2353
# Epoch 2/30
# 142/142 - 5s - 38ms/step - accuracy: 0.8991 - loss: 0.2883 - val_accuracy: 0.9681 - val_loss: 0.1981
# Epoch 3/30
# 142/142 - 5s - 39ms/step - accuracy: 0.9224 - loss: 0.2392 - val_accuracy: 0.9691 - val_loss: 0.1769
# Epoch 4/30
# 142/142 - 5s - 39ms/step - accuracy: 0.9287 - loss: 0.2268 - val_accuracy: 0.9701 - val_loss: 0.1680
# Epoch 5/30
# 142/142 - 5s - 39ms/step - accuracy: 0.9343 - loss: 0.2122 - val_accuracy: 0.9701 - val_loss: 0.1469
# Epoch 6/30
# 142/142 - 5s - 39ms/step - accuracy: 0.9389 - loss: 0.1953 - val_accuracy: 0.9634 - val_loss: 0.1648
# Epoch 7/30
# 142/142 - 5s - 39ms/step - accuracy: 0.9488 - loss: 0.1766 - val_accuracy: 0.9727 - val_loss: 0.1319
# Epoch 8/30
# 142/142 - 5s - 38ms/step - accuracy: 0.9479 - loss: 0.1717 - val_accuracy: 0.9753 - val_loss: 0.1307
# Epoch 9/30
# 142/142 - 5s - 39ms/step - accuracy: 0.9509 - loss: 0.1721 - val_accuracy: 0.9732 - val_loss: 0.1188
# Epoch 10/30
# 142/142 - 5s - 38ms/step - accuracy: 0.9586 - loss: 0.1537 - val_accuracy: 0.9758 - val_loss: 0.1168
# Epoch 11/30
# 142/142 - 5s - 38ms/step - accuracy: 0.9568 - loss: 0.1568 - val_accuracy: 0.9794 - val_loss: 0.1020
# Epoch 12/30
# 142/142 - 5s - 39ms/step - accuracy: 0.9608 - loss: 0.1467 - val_accuracy: 0.9804 - val_loss: 0.1002
# Epoch 13/30
# 142/142 - 5s - 38ms/step - accuracy: 0.9656 - loss: 0.1392 - val_accuracy: 0.9804 - val_loss: 0.1022
# Epoch 14/30
# 142/142 - 5s - 38ms/step - accuracy: 0.9669 - loss: 0.1328 - val_accuracy: 0.9779 - val_loss: 0.0944
# Epoch 15/30
# 142/142 - 5s - 38ms/step - accuracy: 0.9660 - loss: 0.1338 - val_accuracy: 0.9794 - val_loss: 0.0989
# Epoch 16/30
# 142/142 - 5s - 38ms/step - accuracy: 0.9712 - loss: 0.1251 - val_accuracy: 0.9804 - val_loss: 0.0889
# Epoch 17/30
# 142/142 - 5s - 38ms/step - accuracy: 0.9706 - loss: 0.1241 - val_accuracy: 0.9815 - val_loss: 0.0827
# Epoch 18/30
# 142/142 - 5s - 38ms/step - accuracy: 0.9701 - loss: 0.1250 - val_accuracy: 0.9820 - val_loss: 0.0837
# Epoch 19/30
# 142/142 - 5s - 38ms/step - accuracy: 0.9754 - loss: 0.1163 - val_accuracy: 0.9815 - val_loss: 0.0785
# Epoch 20/30
# 142/142 - 5s - 38ms/step - accuracy: 0.9708 - loss: 0.1178 - val_accuracy: 0.9815 - val_loss: 0.0771
# Epoch 21/30
# 142/142 - 5s - 38ms/step - accuracy: 0.9758 - loss: 0.1107 - val_accuracy: 0.9820 - val_loss: 0.0757
# Epoch 22/30
# 142/142 - 5s - 38ms/step - accuracy: 0.9736 - loss: 0.1107 - val_accuracy: 0.9825 - val_loss: 0.0744
# Epoch 23/30
# 142/142 - 5s - 39ms/step - accuracy: 0.9770 - loss: 0.1055 - val_accuracy: 0.9851 - val_loss: 0.0700
# Epoch 24/30
# 142/142 - 5s - 38ms/step - accuracy: 0.9764 - loss: 0.1061 - val_accuracy: 0.9830 - val_loss: 0.0714
# Epoch 25/30
# 142/142 - 5s - 38ms/step - accuracy: 0.9786 - loss: 0.1060 - val_accuracy: 0.9830 - val_loss: 0.0690
# Epoch 26/30
# 142/142 - 5s - 38ms/step - accuracy: 0.9787 - loss: 0.1055 - val_accuracy: 0.9830 - val_loss: 0.0659
# Epoch 27/30
# 142/142 - 5s - 38ms/step - accuracy: 0.9808 - loss: 0.0994 - val_accuracy: 0.9840 - val_loss: 0.0628
# Epoch 28/30
# 142/142 - 5s - 38ms/step - accuracy: 0.9804 - loss: 0.1009 - val_accuracy: 0.9835 - val_loss: 0.0694
# Epoch 29/30
# 142/142 - 5s - 38ms/step - accuracy: 0.9798 - loss: 0.1003 - val_accuracy: 0.9830 - val_loss: 0.0633
# Epoch 30/30
# 142/142 - 5s - 38ms/step - accuracy: 0.9791 - loss: 0.0983 - val_accuracy: 0.9825 - val_loss: 0.0636
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
#
# Random Search trial 6/12: {'filters': [16, 32], 'kernel_size': [5, 3], 'dense_units': 128, 'dropout': 0.5, 'learning_rate': 0.003, 'batch_size': 32}
# Epoch 1/30
# 284/284 - 11s - 39ms/step - accuracy: 0.8653 - loss: 0.4394 - val_accuracy: 0.9794 - val_loss: 0.0932
# Epoch 2/30
# 284/284 - 3s - 12ms/step - accuracy: 0.9725 - loss: 0.1097 - val_accuracy: 0.9835 - val_loss: 0.0770
# Epoch 3/30
# 284/284 - 3s - 12ms/step - accuracy: 0.9790 - loss: 0.0834 - val_accuracy: 0.9835 - val_loss: 0.0775
# Epoch 4/30
# 284/284 - 3s - 12ms/step - accuracy: 0.9800 - loss: 0.0743 - val_accuracy: 0.9856 - val_loss: 0.0756
# Epoch 5/30
# 284/284 - 3s - 12ms/step - accuracy: 0.9817 - loss: 0.0689 - val_accuracy: 0.9846 - val_loss: 0.0678
# Epoch 6/30
# 284/284 - 3s - 12ms/step - accuracy: 0.9817 - loss: 0.0683 - val_accuracy: 0.9846 - val_loss: 0.0616
# Epoch 7/30
# 284/284 - 3s - 12ms/step - accuracy: 0.9832 - loss: 0.0578 - val_accuracy: 0.9856 - val_loss: 0.0692
# Epoch 8/30
# 284/284 - 3s - 12ms/step - accuracy: 0.9837 - loss: 0.0557 - val_accuracy: 0.9851 - val_loss: 0.0690
# Epoch 9/30
# 284/284 - 3s - 12ms/step - accuracy: 0.9857 - loss: 0.0494 - val_accuracy: 0.9846 - val_loss: 0.0757
# Epoch 10/30
# 284/284 - 3s - 12ms/step - accuracy: 0.9841 - loss: 0.0518 - val_accuracy: 0.9840 - val_loss: 0.0740
# Epoch 11/30
# 284/284 - 3s - 12ms/step - accuracy: 0.9841 - loss: 0.0530 - val_accuracy: 0.9887 - val_loss: 0.0521
# Epoch 12/30
# 284/284 - 3s - 12ms/step - accuracy: 0.9865 - loss: 0.0452 - val_accuracy: 0.9861 - val_loss: 0.0574
# Epoch 13/30
# 284/284 - 3s - 12ms/step - accuracy: 0.9863 - loss: 0.0431 - val_accuracy: 0.9876 - val_loss: 0.0565
# Epoch 14/30
# 284/284 - 3s - 12ms/step - accuracy: 0.9875 - loss: 0.0421 - val_accuracy: 0.9840 - val_loss: 0.0631
# Epoch 15/30
# 284/284 - 3s - 12ms/step - accuracy: 0.9871 - loss: 0.0430 - val_accuracy: 0.9851 - val_loss: 0.0712
# Epoch 16/30
# 284/284 - 3s - 12ms/step - accuracy: 0.9869 - loss: 0.0409 - val_accuracy: 0.9866 - val_loss: 0.0582
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
#
# Random Search trial 7/12: {'filters': [16, 32], 'kernel_size': [5, 3], 'dense_units': 64, 'dropout': 0.3, 'learning_rate': 0.0003, 'batch_size': 128}
# Epoch 1/30
# 71/71 - 17s - 235ms/step - accuracy: 0.8254 - loss: 0.4033 - val_accuracy: 0.9403 - val_loss: 0.2290
# Epoch 2/30
# 71/71 - 3s - 40ms/step - accuracy: 0.9342 - loss: 0.2173 - val_accuracy: 0.9629 - val_loss: 0.1560
# Epoch 3/30
# 71/71 - 3s - 40ms/step - accuracy: 0.9470 - loss: 0.1671 - val_accuracy: 0.9686 - val_loss: 0.1183
# Epoch 4/30
# 71/71 - 3s - 40ms/step - accuracy: 0.9488 - loss: 0.1507 - val_accuracy: 0.9737 - val_loss: 0.1112
# Epoch 5/30
# 71/71 - 3s - 40ms/step - accuracy: 0.9561 - loss: 0.1284 - val_accuracy: 0.9748 - val_loss: 0.0954
# Epoch 6/30
# 71/71 - 5s - 73ms/step - accuracy: 0.9618 - loss: 0.1137 - val_accuracy: 0.9753 - val_loss: 0.0909
# Epoch 7/30
# 71/71 - 3s - 40ms/step - accuracy: 0.9647 - loss: 0.1018 - val_accuracy: 0.9773 - val_loss: 0.0842
# Epoch 8/30
# 71/71 - 3s - 40ms/step - accuracy: 0.9678 - loss: 0.0943 - val_accuracy: 0.9768 - val_loss: 0.0787
# Epoch 9/30
# 71/71 - 3s - 41ms/step - accuracy: 0.9708 - loss: 0.0854 - val_accuracy: 0.9784 - val_loss: 0.0748
# Epoch 10/30
# 71/71 - 3s - 41ms/step - accuracy: 0.9734 - loss: 0.0765 - val_accuracy: 0.9768 - val_loss: 0.0696
# Epoch 11/30
# 71/71 - 3s - 40ms/step - accuracy: 0.9755 - loss: 0.0746 - val_accuracy: 0.9773 - val_loss: 0.0736
# Epoch 12/30
# 71/71 - 3s - 40ms/step - accuracy: 0.9724 - loss: 0.0721 - val_accuracy: 0.9789 - val_loss: 0.0676
# Epoch 13/30
# 71/71 - 3s - 40ms/step - accuracy: 0.9778 - loss: 0.0621 - val_accuracy: 0.9784 - val_loss: 0.0624
# Epoch 14/30
# 71/71 - 3s - 40ms/step - accuracy: 0.9795 - loss: 0.0625 - val_accuracy: 0.9773 - val_loss: 0.0780
# Epoch 15/30
# 71/71 - 3s - 40ms/step - accuracy: 0.9778 - loss: 0.0596 - val_accuracy: 0.9815 - val_loss: 0.0637
# Epoch 16/30
# 71/71 - 3s - 40ms/step - accuracy: 0.9812 - loss: 0.0588 - val_accuracy: 0.9794 - val_loss: 0.0595
# Epoch 17/30
# 71/71 - 3s - 40ms/step - accuracy: 0.9852 - loss: 0.0481 - val_accuracy: 0.9820 - val_loss: 0.0605
# Epoch 18/30
# 71/71 - 3s - 40ms/step - accuracy: 0.9838 - loss: 0.0484 - val_accuracy: 0.9820 - val_loss: 0.0600
# Epoch 19/30
# 71/71 - 3s - 40ms/step - accuracy: 0.9866 - loss: 0.0444 - val_accuracy: 0.9835 - val_loss: 0.0603
# Epoch 20/30
# 71/71 - 3s - 40ms/step - accuracy: 0.9857 - loss: 0.0425 - val_accuracy: 0.9830 - val_loss: 0.0569
# Epoch 21/30
# 71/71 - 3s - 40ms/step - accuracy: 0.9868 - loss: 0.0452 - val_accuracy: 0.9815 - val_loss: 0.0608
# Epoch 22/30
# 71/71 - 3s - 40ms/step - accuracy: 0.9853 - loss: 0.0456 - val_accuracy: 0.9840 - val_loss: 0.0583
# Epoch 23/30
# 71/71 - 3s - 40ms/step - accuracy: 0.9875 - loss: 0.0430 - val_accuracy: 0.9804 - val_loss: 0.0659
# Epoch 24/30
# 71/71 - 3s - 40ms/step - accuracy: 0.9852 - loss: 0.0439 - val_accuracy: 0.9851 - val_loss: 0.0568
# Epoch 25/30
# 71/71 - 3s - 39ms/step - accuracy: 0.9870 - loss: 0.0408 - val_accuracy: 0.9835 - val_loss: 0.0626
# Epoch 26/30
# 71/71 - 3s - 39ms/step - accuracy: 0.9872 - loss: 0.0405 - val_accuracy: 0.9840 - val_loss: 0.0633
# Epoch 27/30
# 71/71 - 3s - 40ms/step - accuracy: 0.9894 - loss: 0.0380 - val_accuracy: 0.9835 - val_loss: 0.0681
# Epoch 28/30
# 71/71 - 3s - 40ms/step - accuracy: 0.9900 - loss: 0.0378 - val_accuracy: 0.9825 - val_loss: 0.0697
# Epoch 29/30
# 71/71 - 3s - 40ms/step - accuracy: 0.9917 - loss: 0.0330 - val_accuracy: 0.9820 - val_loss: 0.0771
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step
#
# Random Search trial 8/12: {'filters': [32, 64, 128], 'kernel_size': [5, 3], 'dense_units': 128, 'dropout': 0.3, 'learning_rate': 0.0001, 'batch_size': 32}
# Epoch 1/30
# 284/284 - 21s - 73ms/step - accuracy: 0.9109 - loss: 0.2496 - val_accuracy: 0.9655 - val_loss: 0.1583
# Epoch 2/30
# 284/284 - 9s - 31ms/step - accuracy: 0.9611 - loss: 0.1472 - val_accuracy: 0.9748 - val_loss: 0.1256
# Epoch 3/30
# 284/284 - 9s - 31ms/step - accuracy: 0.9700 - loss: 0.1139 - val_accuracy: 0.9773 - val_loss: 0.1177
# Epoch 4/30
# 284/284 - 9s - 31ms/step - accuracy: 0.9756 - loss: 0.0934 - val_accuracy: 0.9799 - val_loss: 0.1078
# Epoch 5/30
# 284/284 - 9s - 31ms/step - accuracy: 0.9799 - loss: 0.0795 - val_accuracy: 0.9809 - val_loss: 0.0895
# Epoch 6/30
# 284/284 - 9s - 31ms/step - accuracy: 0.9807 - loss: 0.0667 - val_accuracy: 0.9799 - val_loss: 0.0936
# Epoch 7/30
# 284/284 - 9s - 31ms/step - accuracy: 0.9828 - loss: 0.0578 - val_accuracy: 0.9815 - val_loss: 0.0847
# Epoch 8/30
# 284/284 - 9s - 31ms/step - accuracy: 0.9826 - loss: 0.0496 - val_accuracy: 0.9851 - val_loss: 0.0605
# Epoch 9/30
# 284/284 - 9s - 31ms/step - accuracy: 0.9852 - loss: 0.0430 - val_accuracy: 0.9887 - val_loss: 0.0574
# Epoch 10/30
# 284/284 - 9s - 31ms/step - accuracy: 0.9866 - loss: 0.0390 - val_accuracy: 0.9882 - val_loss: 0.0634
# Epoch 11/30
# 284/284 - 9s - 31ms/step - accuracy: 0.9880 - loss: 0.0347 - val_accuracy: 0.9887 - val_loss: 0.0490
# Epoch 12/30
# 284/284 - 9s - 31ms/step - accuracy: 0.9871 - loss: 0.0319 - val_accuracy: 0.9902 - val_loss: 0.0524
# Epoch 13/30
# 284/284 - 9s - 31ms/step - accuracy: 0.9900 - loss: 0.0278 - val_accuracy: 0.9902 - val_loss: 0.0457
# Epoch 14/30
# 284/284 - 9s - 31ms/step - accuracy: 0.9913 - loss: 0.0219 - val_accuracy: 0.9907 - val_loss: 0.0491
# Epoch 15/30
# 284/284 - 9s - 31ms/step - accuracy: 0.9919 - loss: 0.0209 - val_accuracy: 0.9912 - val_loss: 0.0450
# Epoch 16/30
# 284/284 - 9s - 31ms/step - accuracy: 0.9929 - loss: 0.0176 - val_accuracy: 0.9918 - val_loss: 0.0466
# Epoch 17/30
# 284/284 - 9s - 31ms/step - accuracy: 0.9944 - loss: 0.0161 - val_accuracy: 0.9907 - val_loss: 0.0469
# Epoch 18/30
# 284/284 - 9s - 31ms/step - accuracy: 0.9939 - loss: 0.0160 - val_accuracy: 0.9912 - val_loss: 0.0515
# Epoch 19/30
# 284/284 - 9s - 31ms/step - accuracy: 0.9950 - loss: 0.0145 - val_accuracy: 0.9912 - val_loss: 0.0491
# Epoch 20/30
# 284/284 - 9s - 31ms/step - accuracy: 0.9948 - loss: 0.0134 - val_accuracy: 0.9907 - val_loss: 0.0548
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
#
# Random Search trial 9/12: {'filters': [16, 32], 'kernel_size': [5, 3], 'dense_units': 32, 'dropout': 0.4, 'learning_rate': 0.003, 'batch_size': 64}
# Epoch 1/30
# 142/142 - 13s - 89ms/step - accuracy: 0.8306 - loss: 0.4587 - val_accuracy: 0.9660 - val_loss: 0.2619
# Epoch 2/30
# 142/142 - 3s - 20ms/step - accuracy: 0.9187 - loss: 0.2813 - val_accuracy: 0.9706 - val_loss: 0.2115
# Epoch 3/30
# 142/142 - 3s - 20ms/step - accuracy: 0.9579 - loss: 0.2019 - val_accuracy: 0.9799 - val_loss: 0.1487
# Epoch 4/30
# 142/142 - 3s - 20ms/step - accuracy: 0.9581 - loss: 0.1706 - val_accuracy: 0.9815 - val_loss: 0.1233
# Epoch 5/30
# 142/142 - 3s - 20ms/step - accuracy: 0.9617 - loss: 0.1462 - val_accuracy: 0.9779 - val_loss: 0.1140
# Epoch 6/30
# 142/142 - 3s - 20ms/step - accuracy: 0.9632 - loss: 0.1316 - val_accuracy: 0.9825 - val_loss: 0.1096
# Epoch 7/30
# 142/142 - 3s - 20ms/step - accuracy: 0.9637 - loss: 0.1282 - val_accuracy: 0.9820 - val_loss: 0.1058
# Epoch 8/30
# 142/142 - 3s - 20ms/step - accuracy: 0.9652 - loss: 0.1198 - val_accuracy: 0.9712 - val_loss: 0.1133
# Epoch 9/30
# 142/142 - 3s - 20ms/step - accuracy: 0.9634 - loss: 0.1209 - val_accuracy: 0.9809 - val_loss: 0.0927
# Epoch 10/30
# 142/142 - 3s - 20ms/step - accuracy: 0.9662 - loss: 0.1139 - val_accuracy: 0.9830 - val_loss: 0.0859
# Epoch 11/30
# 142/142 - 3s - 20ms/step - accuracy: 0.9652 - loss: 0.1174 - val_accuracy: 0.9660 - val_loss: 0.1125
# Epoch 12/30
# 142/142 - 3s - 20ms/step - accuracy: 0.9685 - loss: 0.1067 - val_accuracy: 0.9825 - val_loss: 0.0763
# Epoch 13/30
# 142/142 - 3s - 20ms/step - accuracy: 0.9705 - loss: 0.1053 - val_accuracy: 0.9701 - val_loss: 0.1006
# Epoch 14/30
# 142/142 - 3s - 20ms/step - accuracy: 0.9658 - loss: 0.1114 - val_accuracy: 0.9727 - val_loss: 0.0999
# Epoch 15/30
# 142/142 - 3s - 20ms/step - accuracy: 0.9710 - loss: 0.1012 - val_accuracy: 0.9830 - val_loss: 0.0781
# Epoch 16/30
# 142/142 - 3s - 20ms/step - accuracy: 0.9650 - loss: 0.1141 - val_accuracy: 0.9686 - val_loss: 0.1065
# Epoch 17/30
# 142/142 - 3s - 20ms/step - accuracy: 0.9655 - loss: 0.1127 - val_accuracy: 0.9882 - val_loss: 0.0965
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step
#
# Random Search trial 10/12: {'filters': [32, 64, 128], 'kernel_size': [3, 3], 'dense_units': 32, 'dropout': 0.2, 'learning_rate': 0.0001, 'batch_size': 32}
# Epoch 1/30
# 284/284 - 21s - 75ms/step - accuracy: 0.9115 - loss: 0.2591 - val_accuracy: 0.9593 - val_loss: 0.1518
# Epoch 2/30
# 284/284 - 6s - 23ms/step - accuracy: 0.9578 - loss: 0.1562 - val_accuracy: 0.9732 - val_loss: 0.1172
# Epoch 3/30
# 284/284 - 7s - 23ms/step - accuracy: 0.9663 - loss: 0.1214 - val_accuracy: 0.9743 - val_loss: 0.1105
# Epoch 4/30
# 284/284 - 7s - 23ms/step - accuracy: 0.9724 - loss: 0.1032 - val_accuracy: 0.9763 - val_loss: 0.0923
# Epoch 5/30
# 284/284 - 7s - 23ms/step - accuracy: 0.9741 - loss: 0.0875 - val_accuracy: 0.9784 - val_loss: 0.0836
# Epoch 6/30
# 284/284 - 7s - 23ms/step - accuracy: 0.9784 - loss: 0.0773 - val_accuracy: 0.9779 - val_loss: 0.0792
# Epoch 7/30
# 284/284 - 6s - 23ms/step - accuracy: 0.9795 - loss: 0.0685 - val_accuracy: 0.9768 - val_loss: 0.0866
# Epoch 8/30
# 284/284 - 6s - 23ms/step - accuracy: 0.9823 - loss: 0.0571 - val_accuracy: 0.9789 - val_loss: 0.0795
# Epoch 9/30
# 284/284 - 6s - 23ms/step - accuracy: 0.9848 - loss: 0.0501 - val_accuracy: 0.9809 - val_loss: 0.0699
# Epoch 10/30
# 284/284 - 6s - 23ms/step - accuracy: 0.9852 - loss: 0.0424 - val_accuracy: 0.9809 - val_loss: 0.0656
# Epoch 11/30
# 284/284 - 6s - 23ms/step - accuracy: 0.9857 - loss: 0.0386 - val_accuracy: 0.9825 - val_loss: 0.0623
# Epoch 12/30
# 284/284 - 6s - 23ms/step - accuracy: 0.9874 - loss: 0.0345 - val_accuracy: 0.9809 - val_loss: 0.0630
# Epoch 13/30
# 284/284 - 6s - 23ms/step - accuracy: 0.9905 - loss: 0.0271 - val_accuracy: 0.9820 - val_loss: 0.0662
# Epoch 14/30
# 284/284 - 6s - 23ms/step - accuracy: 0.9907 - loss: 0.0268 - val_accuracy: 0.9851 - val_loss: 0.0502
# Epoch 15/30
# 284/284 - 6s - 23ms/step - accuracy: 0.9912 - loss: 0.0235 - val_accuracy: 0.9876 - val_loss: 0.0522
# Epoch 16/30
# 284/284 - 6s - 23ms/step - accuracy: 0.9919 - loss: 0.0202 - val_accuracy: 0.9882 - val_loss: 0.0509
# Epoch 17/30
# 284/284 - 6s - 23ms/step - accuracy: 0.9936 - loss: 0.0178 - val_accuracy: 0.9856 - val_loss: 0.0520
# Epoch 18/30
# 284/284 - 6s - 23ms/step - accuracy: 0.9942 - loss: 0.0157 - val_accuracy: 0.9866 - val_loss: 0.0520
# Epoch 19/30
# 284/284 - 6s - 23ms/step - accuracy: 0.9933 - loss: 0.0174 - val_accuracy: 0.9897 - val_loss: 0.0542
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
#
# Random Search trial 11/12: {'filters': [16, 32], 'kernel_size': [3, 3], 'dense_units': 64, 'dropout': 0.3, 'learning_rate': 0.0003, 'batch_size': 128}
# Epoch 1/30
# 71/71 - 16s - 232ms/step - accuracy: 0.8661 - loss: 0.3416 - val_accuracy: 0.9557 - val_loss: 0.1770
# Epoch 2/30
# 71/71 - 3s - 35ms/step - accuracy: 0.9542 - loss: 0.1711 - val_accuracy: 0.9696 - val_loss: 0.1244
# Epoch 3/30
# 71/71 - 3s - 35ms/step - accuracy: 0.9628 - loss: 0.1324 - val_accuracy: 0.9763 - val_loss: 0.1031
# Epoch 4/30
# 71/71 - 3s - 36ms/step - accuracy: 0.9661 - loss: 0.1137 - val_accuracy: 0.9773 - val_loss: 0.0922
# Epoch 5/30
# 71/71 - 3s - 36ms/step - accuracy: 0.9680 - loss: 0.1074 - val_accuracy: 0.9763 - val_loss: 0.0900
# Epoch 6/30
# 71/71 - 3s - 36ms/step - accuracy: 0.9754 - loss: 0.0790 - val_accuracy: 0.9763 - val_loss: 0.0783
# Epoch 7/30
# 71/71 - 3s - 36ms/step - accuracy: 0.9747 - loss: 0.0772 - val_accuracy: 0.9773 - val_loss: 0.0752
# Epoch 8/30
# 71/71 - 3s - 36ms/step - accuracy: 0.9798 - loss: 0.0609 - val_accuracy: 0.9784 - val_loss: 0.0733
# Epoch 9/30
# 71/71 - 3s - 36ms/step - accuracy: 0.9768 - loss: 0.0641 - val_accuracy: 0.9768 - val_loss: 0.0742
# Epoch 10/30
# 71/71 - 3s - 36ms/step - accuracy: 0.9791 - loss: 0.0561 - val_accuracy: 0.9779 - val_loss: 0.0693
# Epoch 11/30
# 71/71 - 3s - 36ms/step - accuracy: 0.9805 - loss: 0.0514 - val_accuracy: 0.9753 - val_loss: 0.0731
# Epoch 12/30
# 71/71 - 3s - 36ms/step - accuracy: 0.9837 - loss: 0.0461 - val_accuracy: 0.9799 - val_loss: 0.0779
# Epoch 13/30
# 71/71 - 3s - 36ms/step - accuracy: 0.9821 - loss: 0.0463 - val_accuracy: 0.9804 - val_loss: 0.0649
# Epoch 14/30
# 71/71 - 3s - 36ms/step - accuracy: 0.9839 - loss: 0.0408 - val_accuracy: 0.9794 - val_loss: 0.0671
# Epoch 15/30
# 71/71 - 3s - 36ms/step - accuracy: 0.9853 - loss: 0.0366 - val_accuracy: 0.9773 - val_loss: 0.0710
# Epoch 16/30
# 71/71 - 3s - 35ms/step - accuracy: 0.9882 - loss: 0.0321 - val_accuracy: 0.9763 - val_loss: 0.0719
# Epoch 17/30
# 71/71 - 3s - 35ms/step - accuracy: 0.9870 - loss: 0.0327 - val_accuracy: 0.9815 - val_loss: 0.0685
# Epoch 18/30
# 71/71 - 3s - 35ms/step - accuracy: 0.9858 - loss: 0.0336 - val_accuracy: 0.9789 - val_loss: 0.0706
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
#
# Random Search trial 12/12: {'filters': [16, 32], 'kernel_size': [3, 3], 'dense_units': 64, 'dropout': 0.3, 'learning_rate': 0.0001, 'batch_size': 64}
# Epoch 1/30
# 142/142 - 15s - 104ms/step - accuracy: 0.8965 - loss: 0.2874 - val_accuracy: 0.9501 - val_loss: 0.1735
# Epoch 2/30
# 142/142 - 3s - 19ms/step - accuracy: 0.9534 - loss: 0.1714 - val_accuracy: 0.9593 - val_loss: 0.1449
# Epoch 3/30
# 142/142 - 3s - 19ms/step - accuracy: 0.9623 - loss: 0.1332 - val_accuracy: 0.9604 - val_loss: 0.1221
# Epoch 4/30
# 142/142 - 3s - 19ms/step - accuracy: 0.9645 - loss: 0.1168 - val_accuracy: 0.9660 - val_loss: 0.1091
# Epoch 5/30
# 142/142 - 3s - 19ms/step - accuracy: 0.9698 - loss: 0.1065 - val_accuracy: 0.9686 - val_loss: 0.0998
# Epoch 6/30
# 142/142 - 3s - 19ms/step - accuracy: 0.9726 - loss: 0.0931 - val_accuracy: 0.9655 - val_loss: 0.1083
# Epoch 7/30
# 142/142 - 3s - 19ms/step - accuracy: 0.9724 - loss: 0.0878 - val_accuracy: 0.9717 - val_loss: 0.0974
# Epoch 8/30
# 142/142 - 3s - 19ms/step - accuracy: 0.9754 - loss: 0.0792 - val_accuracy: 0.9763 - val_loss: 0.0831
# Epoch 9/30
# 142/142 - 3s - 19ms/step - accuracy: 0.9754 - loss: 0.0777 - val_accuracy: 0.9768 - val_loss: 0.0798
# Epoch 10/30
# 142/142 - 3s - 19ms/step - accuracy: 0.9774 - loss: 0.0691 - val_accuracy: 0.9773 - val_loss: 0.0798
# Epoch 11/30
# 142/142 - 3s - 19ms/step - accuracy: 0.9787 - loss: 0.0632 - val_accuracy: 0.9779 - val_loss: 0.0768
# Epoch 12/30
# 142/142 - 3s - 19ms/step - accuracy: 0.9784 - loss: 0.0612 - val_accuracy: 0.9784 - val_loss: 0.0736
# Epoch 13/30
# 142/142 - 3s - 19ms/step - accuracy: 0.9795 - loss: 0.0565 - val_accuracy: 0.9773 - val_loss: 0.0791
# Epoch 14/30
# 142/142 - 3s - 20ms/step - accuracy: 0.9800 - loss: 0.0529 - val_accuracy: 0.9753 - val_loss: 0.0730
# Epoch 15/30
# 142/142 - 3s - 19ms/step - accuracy: 0.9833 - loss: 0.0462 - val_accuracy: 0.9753 - val_loss: 0.0740
# Epoch 16/30
# 142/142 - 3s - 19ms/step - accuracy: 0.9826 - loss: 0.0443 - val_accuracy: 0.9758 - val_loss: 0.0699
# Epoch 17/30
# 142/142 - 3s - 19ms/step - accuracy: 0.9852 - loss: 0.0395 - val_accuracy: 0.9789 - val_loss: 0.0710
# Epoch 18/30
# 142/142 - 3s - 19ms/step - accuracy: 0.9845 - loss: 0.0393 - val_accuracy: 0.9779 - val_loss: 0.0694
# Epoch 19/30
# 142/142 - 3s - 19ms/step - accuracy: 0.9851 - loss: 0.0384 - val_accuracy: 0.9753 - val_loss: 0.0775
# Epoch 20/30
# 142/142 - 3s - 19ms/step - accuracy: 0.9852 - loss: 0.0359 - val_accuracy: 0.9768 - val_loss: 0.0702
# Epoch 21/30
# 142/142 - 3s - 19ms/step - accuracy: 0.9852 - loss: 0.0360 - val_accuracy: 0.9763 - val_loss: 0.0706
# Epoch 22/30
# 142/142 - 3s - 19ms/step - accuracy: 0.9864 - loss: 0.0322 - val_accuracy: 0.9794 - val_loss: 0.0687
# Epoch 23/30
# 142/142 - 3s - 20ms/step - accuracy: 0.9876 - loss: 0.0295 - val_accuracy: 0.9768 - val_loss: 0.0754
# Epoch 24/30
# 142/142 - 3s - 20ms/step - accuracy: 0.9894 - loss: 0.0253 - val_accuracy: 0.9804 - val_loss: 0.0697
# Epoch 25/30
# 142/142 - 3s - 19ms/step - accuracy: 0.9896 - loss: 0.0260 - val_accuracy: 0.9768 - val_loss: 0.0740
# Epoch 26/30
# 142/142 - 3s - 19ms/step - accuracy: 0.9882 - loss: 0.0273 - val_accuracy: 0.9804 - val_loss: 0.0735
# Epoch 27/30
# 142/142 - 3s - 19ms/step - accuracy: 0.9885 - loss: 0.0272 - val_accuracy: 0.9773 - val_loss: 0.0743
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step
#     trial        filters kernel_size  dense_units  dropout  learning_rate  \
# 7       8  [32, 64, 128]      [5, 3]          128      0.3         0.0001
# 5       6       [16, 32]      [5, 3]          128      0.5         0.0030
# 6       7       [16, 32]      [5, 3]           64      0.3         0.0003
# 9      10  [32, 64, 128]      [3, 3]           32      0.2         0.0001
# 4       5       [32, 64]      [5, 3]           32      0.4         0.0001
# 8       9       [16, 32]      [5, 3]           32      0.4         0.0030
# 0       1       [16, 32]      [5, 3]           64      0.5         0.0001
# 1       2       [16, 32]      [3, 3]           64      0.2         0.0003
# 10     11       [16, 32]      [3, 3]           64      0.3         0.0003
# 11     12       [16, 32]      [3, 3]           64      0.3         0.0001
# 3       4       [32, 64]      [5, 3]           64      0.3         0.0030
# 2       3       [32, 64]      [5, 3]          128      0.4         0.0030
#
#     batch_size  accuracy  precision    recall        f1  best_val_loss  \
# 7           32  0.991246   0.997001  0.990320  0.993650       0.045019
# 5           32  0.988671   0.991078  0.992554  0.991815       0.052092
# 6          128  0.985067   0.993243  0.985108  0.989159       0.056751
# 9           32  0.985067   0.996974  0.981385  0.989118       0.050167
# 4           64  0.984037   0.996218  0.980640  0.988368       0.062780
# 8           64  0.982492   0.997719  0.976917  0.987208       0.076333
# 0           32  0.981977   0.989521  0.984363  0.986935       0.058198
# 1           32  0.981977   0.991729  0.982130  0.986906       0.062575
# 10         128  0.980433   0.987304  0.984363  0.985831       0.064853
# 11          64  0.979403   0.985831  0.984363  0.985097       0.068714
# 3           32  0.691555   0.691555  1.000000  0.817656       0.618595
# 2          128  0.691555   0.691555  1.000000  0.817656       0.617875
#
#     best_epoch
# 7           15
# 5           11
# 6           24
# 9           14
# 4           27
# 8           12
# 0           28
# 1            5
# 10          13
# 11          22
# 3            1
# 2           10
# Best Random Search configuration: {'method': 'random_search', 'model': 'CNN', 'validation_f1': 0.9936496077698916, 'validation_accuracy': 0.9912461380020597, 'best_val_loss': 0.045018840581178665, 'config': {'filters': [32, 64, 128], 'kernel_size': [5, 3], 'dense_units': 128, 'dropout': 0.3, 'learning_rate': 0.0001, 'batch_size': 32}}
# Saved: /content/drive/MyDrive/Colab Notebooks/Education/INM701/outputs/cnn/optimisation/random_search_best.json

# %% [markdown]
# ## Test Set Deliberately Unused
#
# Random Search performs model selection using validation data only. Do not evaluate the test set in this notebook.

# %% [markdown]
# ## 21. Reproducibility Checks

# %% [markdown]
# This cell displays a compact reproducibility record for the CNN workflow, including the stratified split, train-only preprocessing, test-set isolation, label mapping, dependency design, and random seed.

# %%
# Purpose: Displays a compact reproducibility record for the CNN workflow, including the
# stratified split, train-only preprocessing, test-set isolation, label mapping, dependency
# design, and random seed.
# Collect the main reproducibility and leakage-prevention properties for display.
checks = {
    "self_contained": True,
    "external_helper_file_required": False,
    "custom_helper_imports": False,
    "split": "70/15/15 stratified by class label",
    "scaler_fitted_on": "training split only",
    "test_used_for_model_selection": False,
    "label_mapping": CLASS_NAMES,
    "random_state": RANDOM_STATE,
}

display(pd.DataFrame(list(checks.items()), columns=["check", "value"]))
# Out:
#                            check                               value
# 0                 self_contained                                True
# 1  external_helper_file_required                               False
# 2          custom_helper_imports                               False
# 3                          split  70/15/15 stratified by class label
# 4               scaler_fitted_on                 training split only
# 5  test_used_for_model_selection                               False
# 6                  label_mapping    {0: 'bona_fide', 1: 'synthetic'}
# 7                   random_state                                  42
