# %% [markdown]
# # 03 CNN Dense Units Trial
#
# Controlled screening: change only `dense_units`; all inherited settings remain fixed. Adam remains fixed so the experiment focuses on CNN capacity rather than optimiser choice.

# %% [markdown]
# ## 1. Package Setup

# %%
# Purpose: Package installs are documented but not run automatically during this static refactor.
# %pip install tensorflow scikit-learn pandas numpy matplotlib seaborn joblib soundfile librosa

# %% [markdown]
# ## 2. Load Cache and Previous Config

# %%
import os
from pathlib import Path

# Purpose: Mounts Google Drive when this notebook is running in Google Colab.
# Why this exists: the project files, cached MFCC features, manifests, models, figures,
# and metric outputs live in Google Drive during Colab runs. The /content/drive path
# only represents the real MyDrive files after drive.mount("/content/drive") succeeds.
# Important: the project root should be the folder that contains Data, Model Variants,
# and outputs. For this project, that expected Colab folder is the INM701 folder below.
COLAB_DRIVE_MOUNT_POINT = Path("/content/drive")
EXPECTED_COLAB_PROJECT_ROOT = Path("/content/drive/MyDrive/Colab Notebooks/Education/INM701")

try:
    from google.colab import drive

    drive.mount(str(COLAB_DRIVE_MOUNT_POINT))
    print("Google Colab detected. Google Drive mounted.")

    current_project_root = os.environ.get("INTRO_AI_PROJECT_ROOT")
    current_data_dir_exists = bool(current_project_root) and (Path(current_project_root) / "Data").exists()
    expected_data_dir_exists = (EXPECTED_COLAB_PROJECT_ROOT / "Data").exists()

    # Purpose: Keep a valid user-provided project root, but repair stale runtime state
    # if a previous cell pointed INTRO_AI_PROJECT_ROOT somewhere that does not contain Data.
    if current_data_dir_exists:
        print("INTRO_AI_PROJECT_ROOT already points to a folder with Data, so it was kept.")
    elif expected_data_dir_exists:
        os.environ["INTRO_AI_PROJECT_ROOT"] = str(EXPECTED_COLAB_PROJECT_ROOT)
        print("INTRO_AI_PROJECT_ROOT set to the expected INM701 project folder.")
    elif not current_project_root:
        os.environ["INTRO_AI_PROJECT_ROOT"] = str(EXPECTED_COLAB_PROJECT_ROOT)
        print("INTRO_AI_PROJECT_ROOT was not set, so it now points to the expected INM701 folder.")
    else:
        print("INTRO_AI_PROJECT_ROOT was kept, but Data was not found there or in the expected INM701 folder.")
except Exception as exc:
    print("Google Colab Drive mount skipped. This is expected outside Colab.")
    print("Mount skip reason:", exc)

active_project_root = os.environ.get("INTRO_AI_PROJECT_ROOT", "not set")
print("INTRO_AI_PROJECT_ROOT:", active_project_root)
if active_project_root != "not set":
    active_project_root = Path(active_project_root)
    print("Project root exists:", active_project_root.exists())
    print("Expected Data folder:", active_project_root / "Data")
    print("Data folder exists:", (active_project_root / "Data").exists())
# Out:
# Mounted at /content/drive
# Google Colab detected. Google Drive mounted.
# INTRO_AI_PROJECT_ROOT set to the expected INM701 project folder.
# INTRO_AI_PROJECT_ROOT: /content/drive/MyDrive/Colab Notebooks/Education/INM701
# Project root exists: True
# Expected Data folder: /content/drive/MyDrive/Colab Notebooks/Education/INM701/Data
# Data folder exists: True

# %%
# Purpose: Later notebooks load the one CNN-ready cache made by notebook 00. They do not
# rescan folders, regenerate splits, extract MFCCs, fit scalers, or recalculate class weights.
import hashlib
import json
import os
import random
import time
from itertools import product
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score, precision_score, recall_score
from tensorflow.keras.layers import Conv2D, Dense, Dropout, GlobalAveragePooling2D, Input, MaxPooling2D
from tensorflow.keras.models import Sequential

try:
    from IPython.display import display
except Exception:
    display = print

RANDOM_STATE = 42
MAX_EPOCHS = 50
EARLY_STOP_PATIENCE = 7
EARLY_STOP_MIN_DELTA = 1e-4
THRESHOLD = 0.5
CLASS_NAMES = {0: "bona_fide", 1: "synthetic"}
CONFIRMATION_SEEDS = [42, 123, 2026]


def resolve_project_root():
    # Purpose: default path.
    explicit = os.environ.get("INTRO_AI_PROJECT_ROOT")
    if explicit:
        return Path(explicit).expanduser().resolve()
    cwd = Path.cwd().resolve()
    # Purpose: Runs each candidate configuration under the same data split for a fair validation comparison.
    for candidate in [cwd, *cwd.parents]:
        if (candidate / "Model Variants").exists():
            return candidate
        if (candidate / "Training" / "Model Variants").exists():
            return candidate / "Training"
    return Path("/content/drive/MyDrive/Colab Notebooks/Education/INM701")


# Purpose: Centralizes filesystem paths so dataset inputs, caches, figures, models, and metric tables are easy
# Purpose: to trace.
PROJECT_ROOT = resolve_project_root()
OUTPUT_DIR = PROJECT_ROOT / "outputs" / "cnn"
CACHE_DIR = OUTPUT_DIR / "cache"
MANIFESTS_DIR = OUTPUT_DIR / "manifests"
CONFIGS_DIR = OUTPUT_DIR / "configs"
TABLES_DIR = OUTPUT_DIR / "tables"
HISTORIES_DIR = OUTPUT_DIR / "histories"
METRICS_DIR = OUTPUT_DIR / "metrics"
FIGURES_DIR = OUTPUT_DIR / "figures"
MODELS_DIR = OUTPUT_DIR / "models"
PILOT_LEGACY_DIR = OUTPUT_DIR / "pilot_legacy"
# Purpose: Creates each output directory before later cells try to save tables, figures, or models.
for directory in [OUTPUT_DIR, CACHE_DIR, MANIFESTS_DIR, CONFIGS_DIR, TABLES_DIR, HISTORIES_DIR, METRICS_DIR, FIGURES_DIR, MODELS_DIR, PILOT_LEGACY_DIR]:
    directory.mkdir(parents=True, exist_ok=True)


def require_file(path):
    # Purpose: Stops the notebook early with a clear message when a required upstream artifact is missing.
    path = Path(path)
    if not path.exists():
        raise FileNotFoundError(f"Required file not found: {path}")
    return path


def load_json(path):
    # Purpose: Keeps the load_json helper isolated so later notebook cells can call it consistently.
    with open(require_file(path), "r", encoding="utf-8") as f:
        return json.load(f)


def save_json(payload, path):
    # Purpose: Keeps the save_json helper isolated so later notebook cells can call it consistently.
    with open(path, "w", encoding="utf-8") as f:
        json.dump(payload, f, indent=2)




def normalise_handoff_config(config):
    # Purpose: Keeps rebuilt JSON handoffs compatible with the CNN builder.
    normalised = dict(config)
    for key in ["conv_filters", "kernel_size"]:
        value = normalised.get(key, [])
        if isinstance(value, str):
            value = json.loads(value)
        normalised[key] = [int(item) for item in value]
    normalised["dense_units"] = int(normalised["dense_units"])
    normalised["activation"] = str(normalised.get("activation", "relu"))
    normalised["optimizer"] = str(normalised.get("optimizer", "adam"))
    normalised["dropout"] = float(normalised["dropout"])
    normalised["learning_rate"] = float(normalised["learning_rate"])
    normalised["batch_size"] = int(normalised["batch_size"])
    normalised["loss"] = normalised.get("loss", "binary_crossentropy")
    normalised["threshold"] = float(normalised.get("threshold", 0.5))
    return normalised

def first_existing_results_path(candidate_paths):
    # Purpose: Supports the normal result filename and any documented alias without changing
    # where the notebook saves new results. The first existing CSV is used for rebuilding.
    paths = [Path(path) for path in candidate_paths]
    for path in paths:
        if path.exists():
            return path
    return paths[0]


def rebuild_selected_config_from_results(results_path, selected_path, selected_by_stage):
    # Purpose: Rebuilds a missing selected_config JSON from an existing validation-results
    # CSV. This avoids rerunning training just to recreate the JSON handoff file.
    results_path = Path(results_path)
    selected_path = Path(selected_path)
    if not results_path.exists():
        print("Cannot rebuild selected config because result CSV is missing:", results_path)
        return None

    results_df = pd.read_csv(results_path)
    required_columns = {"config_json", "validation_macro_f1", "best_validation_loss"}
    missing_columns = required_columns - set(results_df.columns)
    if missing_columns:
        raise RuntimeError(f"Cannot rebuild {selected_path.name}; missing columns in {results_path.name}: {sorted(missing_columns)}")
    if results_df.empty:
        raise RuntimeError(f"Cannot rebuild {selected_path.name}; result CSV is empty: {results_path}")

    best_row = results_df.sort_values(["validation_macro_f1", "best_validation_loss"], ascending=[False, True]).iloc[0]
    selected = normalise_handoff_config(json.loads(best_row["config_json"]))
    selected.update({
        "selected_by_stage": selected_by_stage,
        "selection_metric": "validation_macro_f1",
        "validation_macro_f1": float(best_row["validation_macro_f1"]),
        "best_validation_loss": float(best_row["best_validation_loss"]),
        "rebuilt_from_results_csv": str(results_path),
    })
    save_json(selected, selected_path)
    print("Rebuilt selected config from existing results:", selected_path)
    return selected


def ensure_selected_config_from_results(selected_path, results_path, selected_by_stage):
    # Purpose: Repairs a missing previous-stage config before this notebook tries to load it.
    # If neither the JSON nor the CSV exists, the later require_file/load_json call will still
    # stop with a clear missing-artifact error.
    selected_path = Path(selected_path)
    results_path = Path(results_path)
    if selected_path.exists():
        return load_json(selected_path)
    if results_path.exists():
        return rebuild_selected_config_from_results(results_path, selected_path, selected_by_stage)
    print("Selected config missing:", selected_path)
    print("Result CSV also missing, so config cannot be rebuilt:", results_path)
    return None


def load_class_weights():
    # Purpose: Keeps the load_class_weights helper isolated so later notebook cells can call it consistently.
    payload = load_json(CONFIGS_DIR / "class_weights.json")
    weights = payload.get("class_weights", payload)
    return {int(label): float(weight) for label, weight in weights.items()}


for required in [
    CACHE_DIR / "X_train.npy",
    CACHE_DIR / "y_train.npy",
    CACHE_DIR / "train_metadata.csv",
    CACHE_DIR / "X_validation.npy",
    CACHE_DIR / "y_validation.npy",
    CACHE_DIR / "validation_metadata.csv",
    CACHE_DIR / "feature_config.json",
    CONFIGS_DIR / "class_weights.json",
]:
    require_file(required)

X_train = np.load(CACHE_DIR / "X_train.npy", mmap_mode="r")[..., np.newaxis]
y_train = np.load(CACHE_DIR / "y_train.npy")
train_metadata = pd.read_csv(CACHE_DIR / "train_metadata.csv")
X_validation = np.load(CACHE_DIR / "X_validation.npy", mmap_mode="r")[..., np.newaxis]
y_validation = np.load(CACHE_DIR / "y_validation.npy")
validation_metadata = pd.read_csv(CACHE_DIR / "validation_metadata.csv")
feature_config = load_json(CACHE_DIR / "feature_config.json")
CLASS_WEIGHTS = load_class_weights()

if len(X_train) != len(y_train) or len(X_train) != len(train_metadata):
    raise RuntimeError("Training cache arrays, labels and metadata are not row-aligned.")
if len(X_validation) != len(y_validation) or len(X_validation) != len(validation_metadata):
    raise RuntimeError("Validation cache arrays, labels and metadata are not row-aligned.")

print("Loaded CNN cache:", CACHE_DIR)
print("X_train shape:", X_train.shape)
print("X_validation shape:", X_validation.shape)

# Purpose: Rebuild the previous selected config from its result CSV if the JSON handoff file is missing.
ensure_selected_config_from_results(CONFIGS_DIR / "02_selected_config.json", TABLES_DIR / "02_kernel_size_results.csv", "02_kernel_size")
base_config = load_json(CONFIGS_DIR / "02_selected_config.json")
print("Loaded previous config:", "02_selected_config.json")
# Out:
# Loaded CNN cache: /content/drive/MyDrive/Colab Notebooks/Education/INM701/outputs/cnn/cache
# X_train shape: (9060, 40, 502, 1)
# X_validation shape: (1942, 40, 502, 1)
# Loaded previous config: 02_selected_config.json

# %% [markdown]
# ## 3. Keras Utilities

# %%
# Purpose: Shared CNN utilities for validation-only model selection.
def normalise_config(config):
    # Purpose: Converts JSON/CSV values into the types expected by the CNN builder.
    normalised = dict(config)
    normalised["conv_filters"] = [int(value) for value in normalised["conv_filters"]]
    normalised["kernel_size"] = [int(value) for value in normalised["kernel_size"]]
    normalised["dense_units"] = int(normalised["dense_units"])
    normalised["activation"] = str(normalised.get("activation", "relu"))
    normalised["optimizer"] = str(normalised.get("optimizer", "adam"))
    normalised["dropout"] = float(normalised["dropout"])
    normalised["learning_rate"] = float(normalised["learning_rate"])
    normalised["batch_size"] = int(normalised["batch_size"])
    normalised["loss"] = normalised.get("loss", "binary_crossentropy")
    normalised["threshold"] = float(normalised.get("threshold", THRESHOLD))
    return normalised


def config_json(config):
    # Purpose: Creates a stable representation for deduplication and deterministic seeds.
    return json.dumps(normalise_config(config), sort_keys=True)


def config_key(config):
    return hashlib.sha256(config_json(config).encode("utf-8")).hexdigest()


def seed_from_config(config, base_seed=RANDOM_STATE):
    digest = hashlib.sha256(f"{base_seed}:{config_json(config)}".encode("utf-8")).hexdigest()
    return int(digest[:8], 16) % (2**31 - 1)


def set_global_seed(seed):
    random.seed(int(seed))
    np.random.seed(int(seed))
    tf.keras.utils.set_random_seed(int(seed))
    os.environ["PYTHONHASHSEED"] = str(int(seed))


def make_optimizer(config):
    name = str(config["optimizer"]).lower()
    learning_rate = float(config["learning_rate"])
    if name == "adam":
        return tf.keras.optimizers.Adam(learning_rate=learning_rate)
    if name == "rmsprop":
        return tf.keras.optimizers.RMSprop(learning_rate=learning_rate)
    if name in ["sgd", "sgd_momentum"]:
        return tf.keras.optimizers.SGD(learning_rate=learning_rate, momentum=0.9)
    raise ValueError(f"Unsupported optimizer: {config['optimizer']}")


def build_cnn_model(config, input_shape):
    # Purpose: Learns local patterns from the coefficient-by-time MFCC map.
    config = normalise_config(config)
    model = Sequential(name="mfcc_cnn")
    model.add(Input(shape=tuple(input_shape)))
    for filters in config["conv_filters"]:
        model.add(
            Conv2D(
                filters=filters,
                kernel_size=tuple(config["kernel_size"]),
                padding="same",
                strides=(1, 1),
                activation=config["activation"],
            )
        )
        model.add(MaxPooling2D(pool_size=(2, 2)))
        if config["dropout"] > 0:
            model.add(Dropout(config["dropout"]))
    # Global pooling controls parameter growth when the number of MFCC time frames changes.
    model.add(GlobalAveragePooling2D())
    model.add(Dense(config["dense_units"], activation=config["activation"]))
    if config["dropout"] > 0:
        model.add(Dropout(config["dropout"]))
    model.add(Dense(1, activation="sigmoid"))
    model.compile(loss=config["loss"], optimizer=make_optimizer(config), metrics=["accuracy"])
    return model


def train_and_evaluate_config(config, run_seed, run_name, verbose=0):
    # Purpose: Uses training data for fitting and validation data for selection; never test data.
    config = normalise_config(config)
    tf.keras.backend.clear_session()
    set_global_seed(run_seed)
    model = build_cnn_model(config, X_train.shape[1:])
    callbacks = [
        tf.keras.callbacks.EarlyStopping(
            monitor="val_loss",
            patience=EARLY_STOP_PATIENCE,
            min_delta=EARLY_STOP_MIN_DELTA,
            restore_best_weights=True,
        )
    ]
    start = time.perf_counter()
    history = model.fit(
        X_train,
        y_train,
        validation_data=(X_validation, y_validation),
        epochs=MAX_EPOCHS,
        batch_size=config["batch_size"],
        class_weight=CLASS_WEIGHTS,
        callbacks=callbacks,
        verbose=verbose,
    )
    runtime = time.perf_counter() - start
    probability = model.predict(X_validation, batch_size=config["batch_size"], verbose=0).ravel()
    pred = (probability >= config["threshold"]).astype(int)
    row = {
        "configuration": config,
        "config_json": config_json(config),
        "config_key": config_key(config),
        "seed": int(run_seed),
        "validation_macro_f1": float(f1_score(y_validation, pred, average="macro", zero_division=0)),
        "validation_binary_f1_synthetic": float(f1_score(y_validation, pred, pos_label=1, zero_division=0)),
        "validation_accuracy": float(accuracy_score(y_validation, pred)),
        "validation_precision_synthetic": float(precision_score(y_validation, pred, pos_label=1, zero_division=0)),
        "validation_recall_synthetic": float(recall_score(y_validation, pred, pos_label=1, zero_division=0)),
        "best_validation_loss": float(np.min(history.history["val_loss"])),
        "best_epoch": int(np.argmin(history.history["val_loss"]) + 1),
        "epochs_trained": int(len(history.history["loss"])),
        "runtime_seconds": float(runtime),
        "run_name": run_name,
    }
    history_df = pd.DataFrame(history.history)
    history_df.insert(0, "epoch", np.arange(1, len(history_df) + 1))
    return row, history_df


def flat_result(row, extra=None):
    # Purpose: Makes each CNN configuration readable in CSV result tables.
    extra = extra or {}
    config = normalise_config(row["configuration"])
    flat = dict(extra)
    flat.update({
        "conv_filters": json.dumps(config["conv_filters"]),
        "kernel_size": json.dumps(config["kernel_size"]),
        "dense_units": config["dense_units"],
        "activation": config["activation"],
        "optimizer": config["optimizer"],
        "dropout": config["dropout"],
        "learning_rate": config["learning_rate"],
        "batch_size": config["batch_size"],
        "loss": config["loss"],
        "threshold": config["threshold"],
        "config_json": row["config_json"],
        "config_key": row["config_key"],
        "seed": row["seed"],
        "validation_macro_f1": row["validation_macro_f1"],
        "validation_binary_f1_synthetic": row["validation_binary_f1_synthetic"],
        "validation_accuracy": row["validation_accuracy"],
        "validation_precision_synthetic": row["validation_precision_synthetic"],
        "validation_recall_synthetic": row["validation_recall_synthetic"],
        "best_validation_loss": row["best_validation_loss"],
        "best_epoch": row["best_epoch"],
        "epochs_trained": row["epochs_trained"],
        "runtime_seconds": row["runtime_seconds"],
    })
    return flat


def select_best(rows):
    return max(rows, key=lambda row: (row["validation_macro_f1"], -row["best_validation_loss"]))


def _controlled_candidate_label(value):
    # Purpose: Keeps list-valued candidates readable and stable in CSV outputs.
    if isinstance(value, (list, tuple, dict)):
        return json.dumps(value, sort_keys=True)
    return value


def run_controlled_trial(stage_name, varied_key, candidate_configs, results_path, histories_path, selected_path):
    # Purpose: Runs one controlled validation trial and writes the next-stage JSON handoff.
    if not candidate_configs:
        raise ValueError(f"No candidate configurations were provided for {stage_name}.")

    rows = []
    histories = {}
    total = len(candidate_configs)

    for index, raw_config in enumerate(candidate_configs, start=1):
        config = normalise_config(raw_config)
        candidate = _controlled_candidate_label(config[varied_key])
        run_name = f"{stage_name}_{index:02d}"
        print(f"Running {run_name} ({index}/{total}) with {varied_key}={candidate}")

        row, history_df = train_and_evaluate_config(
            config,
            run_seed=seed_from_config(config),
            run_name=run_name,
            verbose=2,
        )
        rows.append(row)
        histories[run_name] = history_df.to_dict(orient="records")

        partial_results = pd.DataFrame(
            [
                flat_result(
                    trial_row,
                    {
                        "stage": stage_name,
                        "candidate": _controlled_candidate_label(trial_row["configuration"][varied_key]),
                    },
                )
                for trial_row in rows
            ]
        )
        partial_results.to_csv(results_path, index=False)
        save_json(histories, histories_path)

    results_df = pd.DataFrame(
        [
            flat_result(
                trial_row,
                {
                    "stage": stage_name,
                    "candidate": _controlled_candidate_label(trial_row["configuration"][varied_key]),
                },
            )
            for trial_row in rows
        ]
    ).sort_values(["validation_macro_f1", "best_validation_loss"], ascending=[False, True])

    best = select_best(rows)
    selected = normalise_config(best["configuration"])
    selected.update(
        {
            "selected_by_stage": stage_name,
            "selection_metric": "validation_macro_f1",
            "varied_key": varied_key,
            "selected_candidate": _controlled_candidate_label(selected[varied_key]),
            "validation_macro_f1": float(best["validation_macro_f1"]),
            "best_validation_loss": float(best["best_validation_loss"]),
            "config_key": best["config_key"],
            "seed": int(best["seed"]),
        }
    )
    save_json(selected, selected_path)

    display(results_df)
    print("Saved results:", results_path)
    print("Saved histories:", histories_path)
    print("Saved selected config:", selected_path)
    return results_df

# %% [markdown]
# ## 4. Candidate Dense-Layer Sizes

# %%
# Purpose: Changes only the capacity after global pooling.
VARIED_KEY = "dense_units"
candidate_values = [32, 64, 128]
candidate_configs = []
for value in candidate_values:
    config = dict(base_config)
    config[VARIED_KEY] = value
    candidate_configs.append(normalise_config(config))
display(pd.DataFrame(candidate_configs))
# Out:
#   conv_filters kernel_size  dense_units activation optimizer  dropout  \
# 0     [32, 64]      [5, 3]           32       relu      adam      0.3
# 1     [32, 64]      [5, 3]           64       relu      adam      0.3
# 2     [32, 64]      [5, 3]          128       relu      adam      0.3
#
#    learning_rate  batch_size                 loss  threshold  \
# 0          0.001         128  binary_crossentropy        0.5
# 1          0.001         128  binary_crossentropy        0.5
# 2          0.001         128  binary_crossentropy        0.5
#
#   selected_by_stage     selection_metric   varied_key selected_candidate  \
# 0    02_kernel_size  validation_macro_f1  kernel_size             [5, 3]
# 1    02_kernel_size  validation_macro_f1  kernel_size             [5, 3]
# 2    02_kernel_size  validation_macro_f1  kernel_size             [5, 3]
#
#    validation_macro_f1  best_validation_loss  \
# 0             0.901892              0.207033
# 1             0.901892              0.207033
# 2             0.901892              0.207033
#
#                                           config_key        seed
# 0  80eb9d21fc8db19dc7f2fa54c612ac29ba3834af42ab3c...  2052321002
# 1  80eb9d21fc8db19dc7f2fa54c612ac29ba3834af42ab3c...  2052321002
# 2  80eb9d21fc8db19dc7f2fa54c612ac29ba3834af42ab3c...  2052321002

# %% [markdown]
# ## 5. Run or Load Results

# %%
# Purpose: Runs or reloads the controlled dense-units trial.
RUN_DENSE_UNITS_TRIAL = True
results_path = TABLES_DIR / "03_dense_units_results.csv"
histories_path = HISTORIES_DIR / "03_dense_units_histories.json"
selected_path = CONFIGS_DIR / "03_selected_config.json"
if RUN_DENSE_UNITS_TRIAL:
    run_controlled_trial("03_dense_units", VARIED_KEY, candidate_configs, results_path, histories_path, selected_path)
elif selected_path.exists():
    selected_config = load_json(selected_path)
    display(pd.read_csv(results_path).sort_values(["validation_macro_f1", "best_validation_loss"], ascending=[False, True]) if results_path.exists() else pd.DataFrame([selected_config]))
elif results_path.exists():
    rebuild_selected_config_from_results(results_path, selected_path, "03_dense_units")
    display(pd.read_csv(results_path).sort_values(["validation_macro_f1", "best_validation_loss"], ascending=[False, True]))
else:
    print("RUN_DENSE_UNITS_TRIAL is False. [RESULT TO BE INSERTED AFTER FINAL RUN]")
# Out:
# Running 03_dense_units_01 (1/3) with dense_units=32
# Epoch 1/50
# 71/71 - 28s - 399ms/step - accuracy: 0.5634 - loss: 0.6767 - val_accuracy: 0.5891 - val_loss: 0.6767
# Epoch 2/50
# 71/71 - 5s - 70ms/step - accuracy: 0.6334 - loss: 0.6304 - val_accuracy: 0.6432 - val_loss: 0.6275
# Epoch 3/50
# 71/71 - 5s - 70ms/step - accuracy: 0.6883 - loss: 0.5729 - val_accuracy: 0.6761 - val_loss: 0.5911
# Epoch 4/50
# 71/71 - 5s - 70ms/step - accuracy: 0.7328 - loss: 0.5265 - val_accuracy: 0.7533 - val_loss: 0.5088
# Epoch 5/50
# 71/71 - 5s - 71ms/step - accuracy: 0.7583 - loss: 0.4879 - val_accuracy: 0.7904 - val_loss: 0.4602
# Epoch 6/50
# 71/71 - 5s - 71ms/step - accuracy: 0.7833 - loss: 0.4571 - val_accuracy: 0.7868 - val_loss: 0.4617
# Epoch 7/50
# 71/71 - 5s - 72ms/step - accuracy: 0.7977 - loss: 0.4339 - val_accuracy: 0.8172 - val_loss: 0.4145
# Epoch 8/50
# 71/71 - 5s - 72ms/step - accuracy: 0.8109 - loss: 0.4069 - val_accuracy: 0.8208 - val_loss: 0.3977
# Epoch 9/50
# 71/71 - 5s - 72ms/step - accuracy: 0.8237 - loss: 0.3795 - val_accuracy: 0.8110 - val_loss: 0.4121
# Epoch 10/50
# 71/71 - 5s - 73ms/step - accuracy: 0.8325 - loss: 0.3600 - val_accuracy: 0.7853 - val_loss: 0.4414
# Epoch 11/50
# 71/71 - 5s - 73ms/step - accuracy: 0.8415 - loss: 0.3506 - val_accuracy: 0.8239 - val_loss: 0.3893
# Epoch 12/50
# 71/71 - 5s - 74ms/step - accuracy: 0.8522 - loss: 0.3284 - val_accuracy: 0.7997 - val_loss: 0.4220
# Epoch 13/50
# 71/71 - 5s - 75ms/step - accuracy: 0.8587 - loss: 0.3162 - val_accuracy: 0.8553 - val_loss: 0.3389
# Epoch 14/50
# 71/71 - 5s - 75ms/step - accuracy: 0.8693 - loss: 0.2967 - val_accuracy: 0.8399 - val_loss: 0.3474
# Epoch 15/50
# 71/71 - 5s - 76ms/step - accuracy: 0.8745 - loss: 0.2884 - val_accuracy: 0.8527 - val_loss: 0.3290
# Epoch 16/50
# 71/71 - 5s - 76ms/step - accuracy: 0.8794 - loss: 0.2767 - val_accuracy: 0.8723 - val_loss: 0.2967
# Epoch 17/50
# 71/71 - 5s - 77ms/step - accuracy: 0.8897 - loss: 0.2566 - val_accuracy: 0.8913 - val_loss: 0.2642
# Epoch 18/50
# 71/71 - 6s - 78ms/step - accuracy: 0.8947 - loss: 0.2487 - val_accuracy: 0.8363 - val_loss: 0.3522
# Epoch 19/50
# 71/71 - 6s - 79ms/step - accuracy: 0.8996 - loss: 0.2382 - val_accuracy: 0.8702 - val_loss: 0.2960
# Epoch 20/50
# 71/71 - 6s - 80ms/step - accuracy: 0.8951 - loss: 0.2441 - val_accuracy: 0.8986 - val_loss: 0.2462
# Epoch 21/50
# 71/71 - 6s - 81ms/step - accuracy: 0.9082 - loss: 0.2228 - val_accuracy: 0.8980 - val_loss: 0.2441
# Epoch 22/50
# 71/71 - 6s - 80ms/step - accuracy: 0.9137 - loss: 0.2147 - val_accuracy: 0.9063 - val_loss: 0.2320
# Epoch 23/50
# 71/71 - 6s - 79ms/step - accuracy: 0.9093 - loss: 0.2214 - val_accuracy: 0.8898 - val_loss: 0.2564
# Epoch 24/50
# 71/71 - 6s - 78ms/step - accuracy: 0.9108 - loss: 0.2177 - val_accuracy: 0.8738 - val_loss: 0.2853
# Epoch 25/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9169 - loss: 0.2050 - val_accuracy: 0.9001 - val_loss: 0.2390
# Epoch 26/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9205 - loss: 0.1984 - val_accuracy: 0.9083 - val_loss: 0.2181
# Epoch 27/50
# 71/71 - 5s - 76ms/step - accuracy: 0.9249 - loss: 0.1860 - val_accuracy: 0.9104 - val_loss: 0.2178
# Epoch 28/50
# 71/71 - 5s - 76ms/step - accuracy: 0.9264 - loss: 0.1876 - val_accuracy: 0.9053 - val_loss: 0.2291
# Epoch 29/50
# 71/71 - 5s - 76ms/step - accuracy: 0.9288 - loss: 0.1806 - val_accuracy: 0.9063 - val_loss: 0.2239
# Epoch 30/50
# 71/71 - 5s - 76ms/step - accuracy: 0.9297 - loss: 0.1765 - val_accuracy: 0.9150 - val_loss: 0.2081
# Epoch 31/50
# 71/71 - 5s - 76ms/step - accuracy: 0.9292 - loss: 0.1780 - val_accuracy: 0.9192 - val_loss: 0.2009
# Epoch 32/50
# 71/71 - 5s - 76ms/step - accuracy: 0.9331 - loss: 0.1712 - val_accuracy: 0.9212 - val_loss: 0.1921
# Epoch 33/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9333 - loss: 0.1664 - val_accuracy: 0.9243 - val_loss: 0.1930
# Epoch 34/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9373 - loss: 0.1613 - val_accuracy: 0.9320 - val_loss: 0.1765
# Epoch 35/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9390 - loss: 0.1600 - val_accuracy: 0.9217 - val_loss: 0.1919
# Epoch 36/50
# 71/71 - 6s - 78ms/step - accuracy: 0.9380 - loss: 0.1550 - val_accuracy: 0.9320 - val_loss: 0.1703
# Epoch 37/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9381 - loss: 0.1548 - val_accuracy: 0.9248 - val_loss: 0.1862
# Epoch 38/50
# 71/71 - 6s - 77ms/step - accuracy: 0.9418 - loss: 0.1477 - val_accuracy: 0.9310 - val_loss: 0.1717
# Epoch 39/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9416 - loss: 0.1504 - val_accuracy: 0.9186 - val_loss: 0.1967
# Epoch 40/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9379 - loss: 0.1583 - val_accuracy: 0.9387 - val_loss: 0.1548
# Epoch 41/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9434 - loss: 0.1455 - val_accuracy: 0.9300 - val_loss: 0.1743
# Epoch 42/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9418 - loss: 0.1449 - val_accuracy: 0.9253 - val_loss: 0.1817
# Epoch 43/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9455 - loss: 0.1441 - val_accuracy: 0.9501 - val_loss: 0.1352
# Epoch 44/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9429 - loss: 0.1411 - val_accuracy: 0.9325 - val_loss: 0.1701
# Epoch 45/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9407 - loss: 0.1452 - val_accuracy: 0.9480 - val_loss: 0.1369
# Epoch 46/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9432 - loss: 0.1449 - val_accuracy: 0.9351 - val_loss: 0.1580
# Epoch 47/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9456 - loss: 0.1345 - val_accuracy: 0.9408 - val_loss: 0.1492
# Epoch 48/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9422 - loss: 0.1423 - val_accuracy: 0.9269 - val_loss: 0.1749
# Epoch 49/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9462 - loss: 0.1314 - val_accuracy: 0.9439 - val_loss: 0.1384
# Epoch 50/50
# 71/71 - 5s - 76ms/step - accuracy: 0.9485 - loss: 0.1329 - val_accuracy: 0.9408 - val_loss: 0.1483
# Running 03_dense_units_02 (2/3) with dense_units=64
# Epoch 1/50
# 71/71 - 13s - 188ms/step - accuracy: 0.5605 - loss: 0.6759 - val_accuracy: 0.6014 - val_loss: 0.6535
# Epoch 2/50
# 71/71 - 5s - 76ms/step - accuracy: 0.6152 - loss: 0.6321 - val_accuracy: 0.6447 - val_loss: 0.6095
# Epoch 3/50
# 71/71 - 6s - 77ms/step - accuracy: 0.6629 - loss: 0.5826 - val_accuracy: 0.6416 - val_loss: 0.6027
# Epoch 4/50
# 71/71 - 6s - 79ms/step - accuracy: 0.7171 - loss: 0.5276 - val_accuracy: 0.7302 - val_loss: 0.5185
# Epoch 5/50
# 71/71 - 6s - 80ms/step - accuracy: 0.7619 - loss: 0.4790 - val_accuracy: 0.7472 - val_loss: 0.4961
# Epoch 6/50
# 71/71 - 6s - 80ms/step - accuracy: 0.7825 - loss: 0.4480 - val_accuracy: 0.7358 - val_loss: 0.5058
# Epoch 7/50
# 71/71 - 6s - 79ms/step - accuracy: 0.7901 - loss: 0.4234 - val_accuracy: 0.7992 - val_loss: 0.4156
# Epoch 8/50
# 71/71 - 6s - 78ms/step - accuracy: 0.8068 - loss: 0.3952 - val_accuracy: 0.7915 - val_loss: 0.4207
# Epoch 9/50
# 71/71 - 6s - 78ms/step - accuracy: 0.8208 - loss: 0.3779 - val_accuracy: 0.7564 - val_loss: 0.4633
# Epoch 10/50
# 71/71 - 5s - 77ms/step - accuracy: 0.8321 - loss: 0.3561 - val_accuracy: 0.7729 - val_loss: 0.4520
# Epoch 11/50
# 71/71 - 5s - 77ms/step - accuracy: 0.8480 - loss: 0.3354 - val_accuracy: 0.7884 - val_loss: 0.4215
# Epoch 12/50
# 71/71 - 5s - 76ms/step - accuracy: 0.8511 - loss: 0.3232 - val_accuracy: 0.7791 - val_loss: 0.4394
# Epoch 13/50
# 71/71 - 5s - 76ms/step - accuracy: 0.8588 - loss: 0.3047 - val_accuracy: 0.8157 - val_loss: 0.3897
# Epoch 14/50
# 71/71 - 5s - 76ms/step - accuracy: 0.8706 - loss: 0.2893 - val_accuracy: 0.8105 - val_loss: 0.3985
# Epoch 15/50
# 71/71 - 5s - 76ms/step - accuracy: 0.8745 - loss: 0.2847 - val_accuracy: 0.8383 - val_loss: 0.3484
# Epoch 16/50
# 71/71 - 5s - 76ms/step - accuracy: 0.8816 - loss: 0.2686 - val_accuracy: 0.8151 - val_loss: 0.3934
# Epoch 17/50
# 71/71 - 5s - 76ms/step - accuracy: 0.8917 - loss: 0.2565 - val_accuracy: 0.8157 - val_loss: 0.3918
# Epoch 18/50
# 71/71 - 5s - 76ms/step - accuracy: 0.8954 - loss: 0.2452 - val_accuracy: 0.8568 - val_loss: 0.3193
# Epoch 19/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9004 - loss: 0.2373 - val_accuracy: 0.8599 - val_loss: 0.3102
# Epoch 20/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9015 - loss: 0.2355 - val_accuracy: 0.8496 - val_loss: 0.3327
# Epoch 21/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9010 - loss: 0.2293 - val_accuracy: 0.8465 - val_loss: 0.3358
# Epoch 22/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9128 - loss: 0.2173 - val_accuracy: 0.8584 - val_loss: 0.3176
# Epoch 23/50
# 71/71 - 6s - 77ms/step - accuracy: 0.9138 - loss: 0.2114 - val_accuracy: 0.8811 - val_loss: 0.2726
# Epoch 24/50
# 71/71 - 6s - 77ms/step - accuracy: 0.9148 - loss: 0.2090 - val_accuracy: 0.8522 - val_loss: 0.3292
# Epoch 25/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9191 - loss: 0.2027 - val_accuracy: 0.8867 - val_loss: 0.2552
# Epoch 26/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9191 - loss: 0.1981 - val_accuracy: 0.8816 - val_loss: 0.2593
# Epoch 27/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9240 - loss: 0.1936 - val_accuracy: 0.8728 - val_loss: 0.2830
# Epoch 28/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9216 - loss: 0.1883 - val_accuracy: 0.8594 - val_loss: 0.3127
# Epoch 29/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9249 - loss: 0.1849 - val_accuracy: 0.8939 - val_loss: 0.2413
# Epoch 30/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9260 - loss: 0.1829 - val_accuracy: 0.8950 - val_loss: 0.2377
# Epoch 31/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9331 - loss: 0.1704 - val_accuracy: 0.8929 - val_loss: 0.2460
# Epoch 32/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9313 - loss: 0.1722 - val_accuracy: 0.8872 - val_loss: 0.2593
# Epoch 33/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9326 - loss: 0.1679 - val_accuracy: 0.9016 - val_loss: 0.2326
# Epoch 34/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9301 - loss: 0.1698 - val_accuracy: 0.9053 - val_loss: 0.2250
# Epoch 35/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9393 - loss: 0.1570 - val_accuracy: 0.9197 - val_loss: 0.1943
# Epoch 36/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9396 - loss: 0.1535 - val_accuracy: 0.9264 - val_loss: 0.1779
# Epoch 37/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9338 - loss: 0.1620 - val_accuracy: 0.9192 - val_loss: 0.1926
# Epoch 38/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9354 - loss: 0.1575 - val_accuracy: 0.8919 - val_loss: 0.2452
# Epoch 39/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9379 - loss: 0.1524 - val_accuracy: 0.9063 - val_loss: 0.2135
# Epoch 40/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9397 - loss: 0.1479 - val_accuracy: 0.9176 - val_loss: 0.1959
# Epoch 41/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9400 - loss: 0.1471 - val_accuracy: 0.8950 - val_loss: 0.2451
# Epoch 42/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9430 - loss: 0.1407 - val_accuracy: 0.9264 - val_loss: 0.1786
# Epoch 43/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9434 - loss: 0.1369 - val_accuracy: 0.9320 - val_loss: 0.1739
# Epoch 44/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9409 - loss: 0.1459 - val_accuracy: 0.9274 - val_loss: 0.1823
# Epoch 45/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9474 - loss: 0.1326 - val_accuracy: 0.9166 - val_loss: 0.1998
# Epoch 46/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9470 - loss: 0.1331 - val_accuracy: 0.9181 - val_loss: 0.1932
# Epoch 47/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9481 - loss: 0.1268 - val_accuracy: 0.9279 - val_loss: 0.1744
# Epoch 48/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9438 - loss: 0.1316 - val_accuracy: 0.9022 - val_loss: 0.2279
# Epoch 49/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9435 - loss: 0.1344 - val_accuracy: 0.9331 - val_loss: 0.1588
# Epoch 50/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9518 - loss: 0.1241 - val_accuracy: 0.9130 - val_loss: 0.2059
# Running 03_dense_units_03 (3/3) with dense_units=128
# Epoch 1/50
# 71/71 - 13s - 185ms/step - accuracy: 0.5581 - loss: 0.6762 - val_accuracy: 0.6226 - val_loss: 0.6410
# Epoch 2/50
# 71/71 - 5s - 76ms/step - accuracy: 0.6562 - loss: 0.6126 - val_accuracy: 0.7497 - val_loss: 0.5019
# Epoch 3/50
# 71/71 - 5s - 77ms/step - accuracy: 0.7265 - loss: 0.5353 - val_accuracy: 0.8059 - val_loss: 0.4327
# Epoch 4/50
# 71/71 - 6s - 78ms/step - accuracy: 0.7678 - loss: 0.4752 - val_accuracy: 0.8388 - val_loss: 0.3885
# Epoch 5/50
# 71/71 - 6s - 79ms/step - accuracy: 0.7939 - loss: 0.4336 - val_accuracy: 0.8507 - val_loss: 0.3565
# Epoch 6/50
# 71/71 - 6s - 79ms/step - accuracy: 0.8093 - loss: 0.4057 - val_accuracy: 0.8615 - val_loss: 0.3341
# Epoch 7/50
# 71/71 - 6s - 79ms/step - accuracy: 0.8254 - loss: 0.3756 - val_accuracy: 0.8687 - val_loss: 0.3121
# Epoch 8/50
# 71/71 - 6s - 78ms/step - accuracy: 0.8375 - loss: 0.3515 - val_accuracy: 0.8795 - val_loss: 0.2940
# Epoch 9/50
# 71/71 - 6s - 78ms/step - accuracy: 0.8498 - loss: 0.3304 - val_accuracy: 0.8811 - val_loss: 0.2892
# Epoch 10/50
# 71/71 - 5s - 77ms/step - accuracy: 0.8630 - loss: 0.3077 - val_accuracy: 0.8883 - val_loss: 0.2721
# Epoch 11/50
# 71/71 - 5s - 77ms/step - accuracy: 0.8682 - loss: 0.2909 - val_accuracy: 0.8877 - val_loss: 0.2690
# Epoch 12/50
# 71/71 - 5s - 76ms/step - accuracy: 0.8740 - loss: 0.2777 - val_accuracy: 0.8908 - val_loss: 0.2593
# Epoch 13/50
# 71/71 - 5s - 76ms/step - accuracy: 0.8817 - loss: 0.2629 - val_accuracy: 0.8991 - val_loss: 0.2444
# Epoch 14/50
# 71/71 - 5s - 76ms/step - accuracy: 0.8911 - loss: 0.2502 - val_accuracy: 0.9083 - val_loss: 0.2196
# Epoch 15/50
# 71/71 - 5s - 76ms/step - accuracy: 0.8933 - loss: 0.2417 - val_accuracy: 0.9063 - val_loss: 0.2241
# Epoch 16/50
# 71/71 - 5s - 76ms/step - accuracy: 0.9004 - loss: 0.2298 - val_accuracy: 0.9114 - val_loss: 0.2065
# Epoch 17/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9007 - loss: 0.2249 - val_accuracy: 0.9181 - val_loss: 0.1985
# Epoch 18/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9095 - loss: 0.2121 - val_accuracy: 0.9119 - val_loss: 0.2077
# Epoch 19/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9100 - loss: 0.2096 - val_accuracy: 0.9351 - val_loss: 0.1762
# Epoch 20/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9143 - loss: 0.2007 - val_accuracy: 0.9387 - val_loss: 0.1739
# Epoch 21/50
# 71/71 - 6s - 78ms/step - accuracy: 0.9178 - loss: 0.1907 - val_accuracy: 0.9279 - val_loss: 0.1811
# Epoch 22/50
# 71/71 - 6s - 77ms/step - accuracy: 0.9202 - loss: 0.1893 - val_accuracy: 0.9408 - val_loss: 0.1597
# Epoch 23/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9249 - loss: 0.1810 - val_accuracy: 0.9310 - val_loss: 0.1699
# Epoch 24/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9235 - loss: 0.1817 - val_accuracy: 0.9408 - val_loss: 0.1555
# Epoch 25/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9319 - loss: 0.1697 - val_accuracy: 0.9454 - val_loss: 0.1495
# Epoch 26/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9278 - loss: 0.1745 - val_accuracy: 0.9470 - val_loss: 0.1466
# Epoch 27/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9308 - loss: 0.1676 - val_accuracy: 0.9495 - val_loss: 0.1389
# Epoch 28/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9371 - loss: 0.1563 - val_accuracy: 0.9475 - val_loss: 0.1429
# Epoch 29/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9363 - loss: 0.1568 - val_accuracy: 0.9470 - val_loss: 0.1421
# Epoch 30/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9396 - loss: 0.1513 - val_accuracy: 0.9511 - val_loss: 0.1346
# Epoch 31/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9348 - loss: 0.1532 - val_accuracy: 0.9521 - val_loss: 0.1293
# Epoch 32/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9393 - loss: 0.1502 - val_accuracy: 0.9418 - val_loss: 0.1445
# Epoch 33/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9391 - loss: 0.1452 - val_accuracy: 0.9475 - val_loss: 0.1338
# Epoch 34/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9357 - loss: 0.1505 - val_accuracy: 0.9573 - val_loss: 0.1192
# Epoch 35/50
# 71/71 - 5s - 76ms/step - accuracy: 0.9454 - loss: 0.1369 - val_accuracy: 0.9511 - val_loss: 0.1317
# Epoch 36/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9456 - loss: 0.1356 - val_accuracy: 0.9537 - val_loss: 0.1266
# Epoch 37/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9451 - loss: 0.1334 - val_accuracy: 0.9552 - val_loss: 0.1204
# Epoch 38/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9465 - loss: 0.1323 - val_accuracy: 0.9542 - val_loss: 0.1245
# Epoch 39/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9470 - loss: 0.1266 - val_accuracy: 0.9573 - val_loss: 0.1210
# Epoch 40/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9472 - loss: 0.1273 - val_accuracy: 0.9557 - val_loss: 0.1180
# Epoch 41/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9491 - loss: 0.1275 - val_accuracy: 0.9562 - val_loss: 0.1201
# Epoch 42/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9496 - loss: 0.1218 - val_accuracy: 0.9567 - val_loss: 0.1168
# Epoch 43/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9532 - loss: 0.1124 - val_accuracy: 0.9573 - val_loss: 0.1214
# Epoch 44/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9494 - loss: 0.1240 - val_accuracy: 0.9511 - val_loss: 0.1320
# Epoch 45/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9586 - loss: 0.1069 - val_accuracy: 0.9619 - val_loss: 0.1076
# Epoch 46/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9530 - loss: 0.1160 - val_accuracy: 0.9598 - val_loss: 0.1087
# Epoch 47/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9561 - loss: 0.1073 - val_accuracy: 0.9660 - val_loss: 0.0975
# Epoch 48/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9576 - loss: 0.1073 - val_accuracy: 0.9609 - val_loss: 0.1094
# Epoch 49/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9587 - loss: 0.1016 - val_accuracy: 0.9593 - val_loss: 0.1113
# Epoch 50/50
# 71/71 - 5s - 77ms/step - accuracy: 0.9600 - loss: 0.0991 - val_accuracy: 0.9640 - val_loss: 0.0986
#             stage  candidate conv_filters kernel_size  dense_units activation  \
# 2  03_dense_units        128     [32, 64]      [5, 3]          128       relu
# 0  03_dense_units         32     [32, 64]      [5, 3]           32       relu
# 1  03_dense_units         64     [32, 64]      [5, 3]           64       relu
#
#   optimizer  dropout  learning_rate  batch_size  ...        seed  \
# 2      adam      0.3          0.001         128  ...  1090814782
# 0      adam      0.3          0.001         128  ...  1443486380
# 1      adam      0.3          0.001         128  ...  1791181635
#
#    validation_macro_f1 validation_binary_f1_synthetic validation_accuracy  \
# 2             0.960805                       0.975094            0.966014
# 0             0.943048                       0.963019            0.950051
# 1             0.925241                       0.949416            0.933059
#
#    validation_precision_synthetic  validation_recall_synthetic  \
# 2                        0.988523                     0.962025
# 0                        0.986719                     0.940432
# 1                        0.994295                     0.908414
#
#    best_validation_loss  best_epoch  epochs_trained  runtime_seconds
# 2              0.097529          47              50       282.920620
# 0              0.135188          43              50       306.927319
# 1              0.158776          49              50       283.141945
#
# [3 rows x 24 columns]
# Saved results: /content/drive/MyDrive/Colab Notebooks/Education/INM701/outputs/cnn/tables/03_dense_units_results.csv
# Saved histories: /content/drive/MyDrive/Colab Notebooks/Education/INM701/outputs/cnn/histories/03_dense_units_histories.json
# Saved selected config: /content/drive/MyDrive/Colab Notebooks/Education/INM701/outputs/cnn/configs/03_selected_config.json
