# %% [markdown]
# # 05 MLP Architecture Trial
#
# Controlled hyperparameter screening. Change only `hidden_units`; all inherited settings remain fixed. Only hidden-layer architecture changes.

# %% [markdown]
# ## 1. Package Setup

# %%
# Purpose: Package installs are documented but not run automatically during this static refactor.
# %pip install tensorflow scikit-learn pandas numpy matplotlib seaborn joblib soundfile librosa

# %% [markdown]
# ## 2. Load Cache and Previous Config

# %%
import os
from pathlib import Path

# Purpose: Mounts Google Drive when this notebook is running in Google Colab.
# Why this exists: the project files, cached MFCC features, manifests, models, figures,
# and metric outputs live in Google Drive during Colab runs. The /content/drive path
# only represents the real MyDrive files after drive.mount("/content/drive") succeeds.
# Important: the project root should be the folder that contains Data, Model Variants,
# and outputs. For this project, that expected Colab folder is the INM701 folder below.
COLAB_DRIVE_MOUNT_POINT = Path("/content/drive")
EXPECTED_COLAB_PROJECT_ROOT = Path("/content/drive/MyDrive/Colab Notebooks/Education/INM701")

try:
    from google.colab import drive

    drive.mount(str(COLAB_DRIVE_MOUNT_POINT))
    print("Google Colab detected. Google Drive mounted.")

    current_project_root = os.environ.get("INTRO_AI_PROJECT_ROOT")
    current_data_dir_exists = bool(current_project_root) and (Path(current_project_root) / "Data").exists()
    expected_data_dir_exists = (EXPECTED_COLAB_PROJECT_ROOT / "Data").exists()

    # Purpose: Keep a valid user-provided project root, but repair stale runtime state
    # if a previous cell pointed INTRO_AI_PROJECT_ROOT somewhere that does not contain Data.
    if current_data_dir_exists:
        print("INTRO_AI_PROJECT_ROOT already points to a folder with Data, so it was kept.")
    elif expected_data_dir_exists:
        os.environ["INTRO_AI_PROJECT_ROOT"] = str(EXPECTED_COLAB_PROJECT_ROOT)
        print("INTRO_AI_PROJECT_ROOT set to the expected INM701 project folder.")
    elif not current_project_root:
        os.environ["INTRO_AI_PROJECT_ROOT"] = str(EXPECTED_COLAB_PROJECT_ROOT)
        print("INTRO_AI_PROJECT_ROOT was not set, so it now points to the expected INM701 folder.")
    else:
        print("INTRO_AI_PROJECT_ROOT was kept, but Data was not found there or in the expected INM701 folder.")
except Exception as exc:
    print("Google Colab Drive mount skipped. This is expected outside Colab.")
    print("Mount skip reason:", exc)

active_project_root = os.environ.get("INTRO_AI_PROJECT_ROOT", "not set")
print("INTRO_AI_PROJECT_ROOT:", active_project_root)
if active_project_root != "not set":
    active_project_root = Path(active_project_root)
    print("Project root exists:", active_project_root.exists())
    print("Expected Data folder:", active_project_root / "Data")
    print("Data folder exists:", (active_project_root / "Data").exists())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Google Colab detected. Google Drive mounted.
# INTRO_AI_PROJECT_ROOT already points to a folder with Data, so it was kept.
# INTRO_AI_PROJECT_ROOT: /content/drive/MyDrive/Colab Notebooks/Education/INM701
# Project root exists: True
# Expected Data folder: /content/drive/MyDrive/Colab Notebooks/Education/INM701/Data
# Data folder exists: True

# %%
# Purpose: Later notebooks load the one MLP-ready cache made by notebook 00. They do not
# rescan folders, regenerate splits, extract MFCCs, fit scalers, or recalculate class weights.
import hashlib
import json
import os
import random
import time
from itertools import product
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score, precision_score, recall_score
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.models import Sequential

try:
    from IPython.display import display
except Exception:
    display = print

RANDOM_STATE = 42
MAX_EPOCHS = 50
EARLY_STOP_PATIENCE = 7
EARLY_STOP_MIN_DELTA = 1e-4
THRESHOLD = 0.5
CLASS_NAMES = {0: "bona_fide", 1: "synthetic"}
CONFIRMATION_SEEDS = [42, 123, 2026]


def resolve_project_root():
    # Purpose: default path.
    explicit = os.environ.get("INTRO_AI_PROJECT_ROOT")
    if explicit:
        return Path(explicit).expanduser().resolve()
    cwd = Path.cwd().resolve()
    # Purpose: Runs each candidate configuration under the same data split for a fair validation comparison.
    for candidate in [cwd, *cwd.parents]:
        if (candidate / "Model Variants").exists():
            return candidate
        if (candidate / "Training" / "Model Variants").exists():
            return candidate / "Training"
    return Path("/content/drive/MyDrive/Colab Notebooks/Education/INM701")


# Purpose: Centralizes filesystem paths so dataset inputs, caches, figures, models, and metric tables are easy
# Purpose: to trace.
PROJECT_ROOT = resolve_project_root()
OUTPUT_DIR = PROJECT_ROOT / "outputs" / "mlp"
CACHE_DIR = OUTPUT_DIR / "cache"
MANIFESTS_DIR = OUTPUT_DIR / "manifests"
CONFIGS_DIR = OUTPUT_DIR / "configs"
TABLES_DIR = OUTPUT_DIR / "tables"
HISTORIES_DIR = OUTPUT_DIR / "histories"
METRICS_DIR = OUTPUT_DIR / "metrics"
FIGURES_DIR = OUTPUT_DIR / "figures"
MODELS_DIR = OUTPUT_DIR / "models"
PILOT_LEGACY_DIR = OUTPUT_DIR / "pilot_legacy"
# Purpose: Creates each output directory before later cells try to save tables, figures, or models.
for directory in [OUTPUT_DIR, CACHE_DIR, MANIFESTS_DIR, CONFIGS_DIR, TABLES_DIR, HISTORIES_DIR, METRICS_DIR, FIGURES_DIR, MODELS_DIR, PILOT_LEGACY_DIR]:
    directory.mkdir(parents=True, exist_ok=True)


def require_file(path):
    # Purpose: Stops the notebook early with a clear message when a required upstream artifact is missing.
    path = Path(path)
    if not path.exists():
        raise FileNotFoundError(f"Required file not found: {path}")
    return path


def load_json(path):
    # Purpose: Keeps the load_json helper isolated so later notebook cells can call it consistently.
    with open(require_file(path), "r", encoding="utf-8") as f:
        return json.load(f)


def save_json(payload, path):
    # Purpose: Keeps the save_json helper isolated so later notebook cells can call it consistently.
    with open(path, "w", encoding="utf-8") as f:
        json.dump(payload, f, indent=2)




def normalise_handoff_config(config):
    # Purpose: Normalises a config loaded from a JSON string or CSV row before it is reused
    # by the next notebook in the MLP chain. This keeps rebuilt handoff files compatible
    # with configs produced by a full training run.
    normalised = dict(config)
    hidden_units = normalised.get("hidden_units", [])
    if isinstance(hidden_units, str):
        hidden_units = json.loads(hidden_units)
    normalised["hidden_units"] = [int(value) for value in hidden_units]
    normalised["activation"] = str(normalised["activation"])
    normalised["optimizer"] = str(normalised["optimizer"])
    normalised["dropout"] = float(normalised["dropout"])
    normalised["learning_rate"] = float(normalised["learning_rate"])
    normalised["batch_size"] = int(normalised["batch_size"])
    normalised["loss"] = normalised.get("loss", "binary_crossentropy")
    normalised["threshold"] = float(normalised.get("threshold", THRESHOLD))
    return normalised


def first_existing_results_path(candidate_paths):
    # Purpose: Supports the normal result filename and any documented alias without changing
    # where the notebook saves new results. The first existing CSV is used for rebuilding.
    paths = [Path(path) for path in candidate_paths]
    for path in paths:
        if path.exists():
            return path
    return paths[0]


def rebuild_selected_config_from_results(results_path, selected_path, selected_by_stage):
    # Purpose: Rebuilds a missing selected_config JSON from an existing validation-results
    # CSV. This avoids rerunning training just to recreate the JSON handoff file.
    results_path = Path(results_path)
    selected_path = Path(selected_path)
    if not results_path.exists():
        print("Cannot rebuild selected config because result CSV is missing:", results_path)
        return None

    results_df = pd.read_csv(results_path)
    required_columns = {"config_json", "validation_macro_f1", "best_validation_loss"}
    missing_columns = required_columns - set(results_df.columns)
    if missing_columns:
        raise RuntimeError(f"Cannot rebuild {selected_path.name}; missing columns in {results_path.name}: {sorted(missing_columns)}")
    if results_df.empty:
        raise RuntimeError(f"Cannot rebuild {selected_path.name}; result CSV is empty: {results_path}")

    best_row = results_df.sort_values(["validation_macro_f1", "best_validation_loss"], ascending=[False, True]).iloc[0]
    selected = normalise_handoff_config(json.loads(best_row["config_json"]))
    selected.update({
        "selected_by_stage": selected_by_stage,
        "selection_metric": "validation_macro_f1",
        "validation_macro_f1": float(best_row["validation_macro_f1"]),
        "best_validation_loss": float(best_row["best_validation_loss"]),
        "rebuilt_from_results_csv": str(results_path),
    })
    save_json(selected, selected_path)
    print("Rebuilt selected config from existing results:", selected_path)
    return selected


def ensure_selected_config_from_results(selected_path, results_path, selected_by_stage):
    # Purpose: Repairs a missing previous-stage config before this notebook tries to load it.
    # If neither the JSON nor the CSV exists, the later require_file/load_json call will still
    # stop with a clear missing-artifact error.
    selected_path = Path(selected_path)
    results_path = Path(results_path)
    if selected_path.exists():
        return load_json(selected_path)
    if results_path.exists():
        return rebuild_selected_config_from_results(results_path, selected_path, selected_by_stage)
    print("Selected config missing:", selected_path)
    print("Result CSV also missing, so config cannot be rebuilt:", results_path)
    return None


def load_class_weights():
    # Purpose: Keeps the load_class_weights helper isolated so later notebook cells can call it consistently.
    payload = load_json(CONFIGS_DIR / "class_weights.json")
    weights = payload.get("class_weights", payload)
    return {int(label): float(weight) for label, weight in weights.items()}


for required in [
    CACHE_DIR / "X_train.npy",
    CACHE_DIR / "y_train.npy",
    CACHE_DIR / "train_metadata.csv",
    CACHE_DIR / "X_validation.npy",
    CACHE_DIR / "y_validation.npy",
    CACHE_DIR / "validation_metadata.csv",
    CACHE_DIR / "feature_config.json",
    CONFIGS_DIR / "class_weights.json",
]:
    require_file(required)

X_train = np.load(CACHE_DIR / "X_train.npy")
y_train = np.load(CACHE_DIR / "y_train.npy")
train_metadata = pd.read_csv(CACHE_DIR / "train_metadata.csv")
X_validation = np.load(CACHE_DIR / "X_validation.npy")
y_validation = np.load(CACHE_DIR / "y_validation.npy")
validation_metadata = pd.read_csv(CACHE_DIR / "validation_metadata.csv")
feature_config = load_json(CACHE_DIR / "feature_config.json")
CLASS_WEIGHTS = load_class_weights()

if len(X_train) != len(y_train) or len(X_train) != len(train_metadata):
    raise RuntimeError("Training cache arrays, labels and metadata are not row-aligned.")
if len(X_validation) != len(y_validation) or len(X_validation) != len(validation_metadata):
    raise RuntimeError("Validation cache arrays, labels and metadata are not row-aligned.")

print("Loaded MLP cache:", CACHE_DIR)
print("X_train shape:", X_train.shape)
print("X_validation shape:", X_validation.shape)

# Purpose: Rebuild the previous selected config from its result CSV if the JSON handoff file is missing.
ensure_selected_config_from_results(CONFIGS_DIR / "04_selected_config.json", TABLES_DIR / "04_dropout_results.csv", "04_dropout")
base_config = load_json(CONFIGS_DIR / "04_selected_config.json")
print("Loaded previous config:", "04_selected_config.json")
# Out:
# Loaded MLP cache: /content/drive/MyDrive/Colab Notebooks/Education/INM701/outputs/mlp/cache
# X_train shape: (9060, 80)
# X_validation shape: (1942, 80)
# Loaded previous config: 04_selected_config.json

# %% [markdown]
# ## 3. Keras Utilities

# %%
# Purpose: Shared beginner-readable Keras utilities for validation-only model selection.
def normalise_config(config):
    # Purpose: Keeps the normalise_config helper isolated so later notebook cells can call it consistently.
    normalised = dict(config)
    normalised["hidden_units"] = [int(value) for value in normalised["hidden_units"]]
    normalised["activation"] = str(normalised["activation"])
    normalised["optimizer"] = str(normalised["optimizer"])
    normalised["dropout"] = float(normalised["dropout"])
    normalised["learning_rate"] = float(normalised["learning_rate"])
    normalised["batch_size"] = int(normalised["batch_size"])
    normalised["loss"] = normalised.get("loss", "binary_crossentropy")
    normalised["threshold"] = float(normalised.get("threshold", THRESHOLD))
    return normalised


def config_json(config):
    # Purpose: Keeps the config_json helper isolated so later notebook cells can call it consistently.
    return json.dumps(normalise_config(config), sort_keys=True)


def config_key(config):
    # Purpose: Keeps the config_key helper isolated so later notebook cells can call it consistently.
    return hashlib.sha256(config_json(config).encode("utf-8")).hexdigest()


def seed_from_config(config, base_seed=RANDOM_STATE):
    # Purpose: Keeps the seed_from_config helper isolated so later notebook cells can call it consistently.
    digest = hashlib.sha256(f"{base_seed}:{config_json(config)}".encode("utf-8")).hexdigest()
    return int(digest[:8], 16) % (2**31 - 1)


def set_global_seed(seed):
    # Purpose: Keeps the set_global_seed helper isolated so later notebook cells can call it consistently.
    random.seed(int(seed))
    np.random.seed(int(seed))
    tf.keras.utils.set_random_seed(int(seed))
    os.environ["PYTHONHASHSEED"] = str(int(seed))


def make_optimizer(config):
    # Purpose: Keeps the make_optimizer helper isolated so later notebook cells can call it consistently.
    name = str(config["optimizer"]).lower()
    lr = float(config["learning_rate"])
    if name == "adam":
        return tf.keras.optimizers.Adam(learning_rate=lr)
    if name == "rmsprop":
        return tf.keras.optimizers.RMSprop(learning_rate=lr)
    if name in ["sgd", "sgd_momentum"]:
        return tf.keras.optimizers.SGD(learning_rate=lr, momentum=0.9)
    raise ValueError(f"Unsupported optimizer: {config['optimizer']}")


def build_mlp_model(config, input_dim):
    # Purpose: Constructs the MLP architecture for the current experiment configuration.
    config = normalise_config(config)
    model = Sequential()
    model.add(Input(shape=(input_dim,)))
    # Purpose: Iterates over this collection to build the next table, feature set, or experiment result
    # Purpose: consistently.
    for units in config["hidden_units"]:
        model.add(Dense(units, activation=config["activation"]))
        if config["dropout"] > 0:
            model.add(Dropout(config["dropout"]))
    model.add(Dense(1, activation="sigmoid"))
    model.compile(loss=config["loss"], optimizer=make_optimizer(config), metrics=["accuracy"])
    return model


def train_and_evaluate_config(config, run_seed, run_name, verbose=0):
    # Purpose: consistently.
    config = normalise_config(config)
    tf.keras.backend.clear_session()
    set_global_seed(run_seed)
    model = build_mlp_model(config, X_train.shape[1])
    callbacks = [
        tf.keras.callbacks.EarlyStopping(
            monitor="val_loss",
            patience=EARLY_STOP_PATIENCE,
            min_delta=EARLY_STOP_MIN_DELTA,
            restore_best_weights=True,
        )
    ]
    start = time.perf_counter()
    history = model.fit(
        X_train,
        y_train,
        validation_data=(X_validation, y_validation),
        epochs=MAX_EPOCHS,
        batch_size=config["batch_size"],
        class_weight=CLASS_WEIGHTS,
        callbacks=callbacks,
        verbose=verbose,
    )
    runtime = time.perf_counter() - start
    probability = model.predict(X_validation, batch_size=config["batch_size"], verbose=0).ravel()
    pred = (probability >= config["threshold"]).astype(int)
    row = {
        "configuration": config,
        "config_json": config_json(config),
        "config_key": config_key(config),
        "seed": int(run_seed),
        "validation_macro_f1": float(f1_score(y_validation, pred, average="macro", zero_division=0)),
        "validation_binary_f1_synthetic": float(f1_score(y_validation, pred, pos_label=1, zero_division=0)),
        "validation_accuracy": float(accuracy_score(y_validation, pred)),
        "validation_precision_synthetic": float(precision_score(y_validation, pred, pos_label=1, zero_division=0)),
        "validation_recall_synthetic": float(recall_score(y_validation, pred, pos_label=1, zero_division=0)),
        "best_validation_loss": float(np.min(history.history["val_loss"])),
        "best_epoch": int(np.argmin(history.history["val_loss"]) + 1),
        "epochs_trained": int(len(history.history["loss"])),
        "runtime_seconds": float(runtime),
        "run_name": run_name,
    }
    history_df = pd.DataFrame(history.history)
    history_df.insert(0, "epoch", np.arange(1, len(history_df) + 1))
    return row, history_df


def flat_result(row, extra=None):
    # Purpose: Keeps the flat_result helper isolated so later notebook cells can call it consistently.
    extra = extra or {}
    config = normalise_config(row["configuration"])
    flat = dict(extra)
    flat.update({
        "hidden_units": json.dumps(config["hidden_units"]),
        "activation": config["activation"],
        "optimizer": config["optimizer"],
        "dropout": config["dropout"],
        "learning_rate": config["learning_rate"],
        "batch_size": config["batch_size"],
        "loss": config["loss"],
        "threshold": config["threshold"],
        "config_json": row["config_json"],
        "config_key": row["config_key"],
        "seed": row["seed"],
        "validation_macro_f1": row["validation_macro_f1"],
        "validation_binary_f1_synthetic": row["validation_binary_f1_synthetic"],
        "validation_accuracy": row["validation_accuracy"],
        "validation_precision_synthetic": row["validation_precision_synthetic"],
        "validation_recall_synthetic": row["validation_recall_synthetic"],
        "best_validation_loss": row["best_validation_loss"],
        "best_epoch": row["best_epoch"],
        "epochs_trained": row["epochs_trained"],
        "runtime_seconds": row["runtime_seconds"],
    })
    return flat


def select_best(rows):
    # Purpose: Keeps the select_best helper isolated so later notebook cells can call it consistently.
    return max(rows, key=lambda row: (row["validation_macro_f1"], -row["best_validation_loss"]))


def run_controlled_trial(stage_name, varied_key, candidate_configs, results_path, histories_path, selected_path):
    # Purpose: Keeps the run_controlled_trial helper isolated so later notebook cells can call it consistently.
    rows = []
    histories = {}
    # Purpose: Iterates over this collection to build the next table, feature set, or experiment result
    # Purpose: consistently.
    for number, config in enumerate(candidate_configs, start=1):
        config = normalise_config(config)
        value = config[varied_key]
        print(f"{stage_name} candidate {number}/{len(candidate_configs)}:", value)
        row, history_df = train_and_evaluate_config(config, seed_from_config(config), f"{stage_name}_{number:02d}", verbose=2)
        rows.append(row)
        histories[str(value)] = history_df.to_dict(orient="records")
        # Purpose: Saves the generated artifacts so later notebooks, reports, or reruns can inspect the same
        # Purpose: outputs.
        pd.DataFrame([flat_result(item, {"stage": stage_name, "candidate": str(item["configuration"][varied_key])}) for item in rows]).to_csv(results_path, index=False)
        save_json(histories, histories_path)
    best = select_best(rows)
    selected = normalise_config(best["configuration"])
    selected.update({
        "selected_by_stage": stage_name,
        "selection_metric": "validation_macro_f1",
        "validation_macro_f1": best["validation_macro_f1"],
        "best_validation_loss": best["best_validation_loss"],
    })
    save_json(selected, selected_path)
    display(pd.read_csv(results_path).sort_values("validation_macro_f1", ascending=False))
    print("Saved selected config:", selected_path)

# %% [markdown]
# ## 4. Candidate Configurations

# %%
# Purpose: 4. Candidate Configurations.
VARIED_KEY = "hidden_units"
candidate_values = [[64], [128], [64, 32], [128, 64], [256, 128], [256, 128, 64]]
candidate_configs = []
# Purpose: Runs the controlled trial once for each candidate value of the tested hyperparameter.
for value in candidate_values:
    config = dict(base_config)
    config[VARIED_KEY] = value
    candidate_configs.append(normalise_config(config))
display(pd.DataFrame(candidate_configs))
# Out:
#      hidden_units activation optimizer  dropout  learning_rate  batch_size  \
# 0            [64]        elu   rmsprop      0.1          0.001         128
# 1           [128]        elu   rmsprop      0.1          0.001         128
# 2        [64, 32]        elu   rmsprop      0.1          0.001         128
# 3       [128, 64]        elu   rmsprop      0.1          0.001         128
# 4      [256, 128]        elu   rmsprop      0.1          0.001         128
# 5  [256, 128, 64]        elu   rmsprop      0.1          0.001         128
#
#                   loss  threshold selected_by_stage     selection_metric  \
# 0  binary_crossentropy        0.5        04_dropout  validation_macro_f1
# 1  binary_crossentropy        0.5        04_dropout  validation_macro_f1
# 2  binary_crossentropy        0.5        04_dropout  validation_macro_f1
# 3  binary_crossentropy        0.5        04_dropout  validation_macro_f1
# 4  binary_crossentropy        0.5        04_dropout  validation_macro_f1
# 5  binary_crossentropy        0.5        04_dropout  validation_macro_f1
#
#    validation_macro_f1  best_validation_loss
# 0             0.966449              0.070958
# 1             0.966449              0.070958
# 2             0.966449              0.070958
# 3             0.966449              0.070958
# 4             0.966449              0.070958
# 5             0.966449              0.070958

# %% [markdown]
# ## 5. Run or Load Results

# %%
# Purpose: Runs the trial when enabled, otherwise repairs or displays the selected config
# handoff from existing validation results without retraining.
RUN_ARCHITECTURE_TRIAL = True
results_path = TABLES_DIR / "05_architecture_results.csv"
histories_path = HISTORIES_DIR / "05_architecture_histories.json"
selected_path = CONFIGS_DIR / "05_selected_config.json"
rebuild_results_path = first_existing_results_path([TABLES_DIR / "05_architecture_results.csv", TABLES_DIR / "05_hidden_units_results.csv"])

if RUN_ARCHITECTURE_TRIAL:
    run_controlled_trial("05_hidden_units", VARIED_KEY, candidate_configs, results_path, histories_path, selected_path)
elif selected_path.exists():
    selected_config = load_json(selected_path)
    print("Loaded selected config:", selected_path)
    if rebuild_results_path.exists():
        display(pd.read_csv(rebuild_results_path).sort_values(["validation_macro_f1", "best_validation_loss"], ascending=[False, True]))
    else:
        display(pd.DataFrame([selected_config]))
elif rebuild_results_path.exists():
    rebuild_selected_config_from_results(rebuild_results_path, selected_path, "05_hidden_units")
    display(pd.read_csv(rebuild_results_path).sort_values(["validation_macro_f1", "best_validation_loss"], ascending=[False, True]))
else:
    print("RUN_ARCHITECTURE_TRIAL is False. [RESULT TO BE INSERTED AFTER FINAL RUN]")
    print("Missing selected config:", selected_path)
    print("Missing result CSV:", rebuild_results_path)
# Out:
# 05_hidden_units candidate 1/6: [64]
# Epoch 1/50
# 71/71 - 1s - 17ms/step - accuracy: 0.7998 - loss: 0.4081 - val_accuracy: 0.8661 - val_loss: 0.3194
# Epoch 2/50
# 71/71 - 0s - 5ms/step - accuracy: 0.8825 - loss: 0.2604 - val_accuracy: 0.8836 - val_loss: 0.2510
# Epoch 3/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9045 - loss: 0.2165 - val_accuracy: 0.9058 - val_loss: 0.2119
# Epoch 4/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9199 - loss: 0.1912 - val_accuracy: 0.9176 - val_loss: 0.1904
# Epoch 5/50
# 71/71 - 1s - 9ms/step - accuracy: 0.9251 - loss: 0.1739 - val_accuracy: 0.9248 - val_loss: 0.1779
# Epoch 6/50
# 71/71 - 1s - 8ms/step - accuracy: 0.9288 - loss: 0.1623 - val_accuracy: 0.9289 - val_loss: 0.1689
# Epoch 7/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9347 - loss: 0.1535 - val_accuracy: 0.9300 - val_loss: 0.1610
# Epoch 8/50
# 71/71 - 0s - 7ms/step - accuracy: 0.9365 - loss: 0.1454 - val_accuracy: 0.9331 - val_loss: 0.1542
# Epoch 9/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9423 - loss: 0.1377 - val_accuracy: 0.9377 - val_loss: 0.1473
# Epoch 10/50
# 71/71 - 0s - 7ms/step - accuracy: 0.9415 - loss: 0.1331 - val_accuracy: 0.9403 - val_loss: 0.1428
# Epoch 11/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9468 - loss: 0.1263 - val_accuracy: 0.9398 - val_loss: 0.1412
# Epoch 12/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9465 - loss: 0.1214 - val_accuracy: 0.9392 - val_loss: 0.1370
# Epoch 13/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9496 - loss: 0.1171 - val_accuracy: 0.9439 - val_loss: 0.1341
# Epoch 14/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9501 - loss: 0.1154 - val_accuracy: 0.9434 - val_loss: 0.1306
# Epoch 15/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9515 - loss: 0.1104 - val_accuracy: 0.9459 - val_loss: 0.1261
# Epoch 16/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9529 - loss: 0.1081 - val_accuracy: 0.9470 - val_loss: 0.1260
# Epoch 17/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9552 - loss: 0.1046 - val_accuracy: 0.9470 - val_loss: 0.1237
# Epoch 18/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9581 - loss: 0.1016 - val_accuracy: 0.9490 - val_loss: 0.1197
# Epoch 19/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9586 - loss: 0.0978 - val_accuracy: 0.9511 - val_loss: 0.1202
# Epoch 20/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9611 - loss: 0.0941 - val_accuracy: 0.9501 - val_loss: 0.1143
# Epoch 21/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9609 - loss: 0.0928 - val_accuracy: 0.9537 - val_loss: 0.1154
# Epoch 22/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9603 - loss: 0.0919 - val_accuracy: 0.9526 - val_loss: 0.1146
# Epoch 23/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9635 - loss: 0.0861 - val_accuracy: 0.9531 - val_loss: 0.1084
# Epoch 24/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9628 - loss: 0.0879 - val_accuracy: 0.9537 - val_loss: 0.1097
# Epoch 25/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9641 - loss: 0.0859 - val_accuracy: 0.9552 - val_loss: 0.1062
# Epoch 26/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9649 - loss: 0.0819 - val_accuracy: 0.9562 - val_loss: 0.1032
# Epoch 27/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9678 - loss: 0.0815 - val_accuracy: 0.9547 - val_loss: 0.1030
# Epoch 28/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9672 - loss: 0.0782 - val_accuracy: 0.9598 - val_loss: 0.0993
# Epoch 29/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9691 - loss: 0.0764 - val_accuracy: 0.9588 - val_loss: 0.1022
# Epoch 30/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9685 - loss: 0.0759 - val_accuracy: 0.9567 - val_loss: 0.1019
# Epoch 31/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9691 - loss: 0.0737 - val_accuracy: 0.9567 - val_loss: 0.1006
# Epoch 32/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9714 - loss: 0.0730 - val_accuracy: 0.9609 - val_loss: 0.0965
# Epoch 33/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9701 - loss: 0.0735 - val_accuracy: 0.9619 - val_loss: 0.0961
# Epoch 34/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9709 - loss: 0.0707 - val_accuracy: 0.9629 - val_loss: 0.0964
# Epoch 35/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9728 - loss: 0.0686 - val_accuracy: 0.9624 - val_loss: 0.0949
# Epoch 36/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9738 - loss: 0.0669 - val_accuracy: 0.9624 - val_loss: 0.0937
# Epoch 37/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9734 - loss: 0.0684 - val_accuracy: 0.9634 - val_loss: 0.0910
# Epoch 38/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9747 - loss: 0.0643 - val_accuracy: 0.9645 - val_loss: 0.0913
# Epoch 39/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9744 - loss: 0.0640 - val_accuracy: 0.9634 - val_loss: 0.0928
# Epoch 40/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9753 - loss: 0.0639 - val_accuracy: 0.9624 - val_loss: 0.0893
# Epoch 41/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9752 - loss: 0.0631 - val_accuracy: 0.9640 - val_loss: 0.0905
# Epoch 42/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9758 - loss: 0.0594 - val_accuracy: 0.9640 - val_loss: 0.0908
# Epoch 43/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9762 - loss: 0.0602 - val_accuracy: 0.9624 - val_loss: 0.0868
# Epoch 44/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9743 - loss: 0.0597 - val_accuracy: 0.9645 - val_loss: 0.0870
# Epoch 45/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9757 - loss: 0.0594 - val_accuracy: 0.9619 - val_loss: 0.0893
# Epoch 46/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9763 - loss: 0.0569 - val_accuracy: 0.9629 - val_loss: 0.0860
# Epoch 47/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9791 - loss: 0.0555 - val_accuracy: 0.9624 - val_loss: 0.0885
# Epoch 48/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9773 - loss: 0.0564 - val_accuracy: 0.9629 - val_loss: 0.0863
# Epoch 49/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9780 - loss: 0.0547 - val_accuracy: 0.9640 - val_loss: 0.0840
# Epoch 50/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9768 - loss: 0.0564 - val_accuracy: 0.9634 - val_loss: 0.0866
# 05_hidden_units candidate 2/6: [128]
# Epoch 1/50
# 71/71 - 1s - 21ms/step - accuracy: 0.8286 - loss: 0.3496 - val_accuracy: 0.8610 - val_loss: 0.2959
# Epoch 2/50
# 71/71 - 0s - 6ms/step - accuracy: 0.8949 - loss: 0.2343 - val_accuracy: 0.8965 - val_loss: 0.2340
# Epoch 3/50
# 71/71 - 1s - 7ms/step - accuracy: 0.9111 - loss: 0.1961 - val_accuracy: 0.9114 - val_loss: 0.2079
# Epoch 4/50
# 71/71 - 0s - 6ms/step - accuracy: 0.9224 - loss: 0.1746 - val_accuracy: 0.9197 - val_loss: 0.1841
# Epoch 5/50
# 71/71 - 0s - 6ms/step - accuracy: 0.9295 - loss: 0.1609 - val_accuracy: 0.9279 - val_loss: 0.1728
# Epoch 6/50
# 71/71 - 1s - 8ms/step - accuracy: 0.9365 - loss: 0.1477 - val_accuracy: 0.9305 - val_loss: 0.1642
# Epoch 7/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9403 - loss: 0.1390 - val_accuracy: 0.9361 - val_loss: 0.1514
# Epoch 8/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9428 - loss: 0.1345 - val_accuracy: 0.9408 - val_loss: 0.1425
# Epoch 9/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9479 - loss: 0.1258 - val_accuracy: 0.9428 - val_loss: 0.1371
# Epoch 10/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9496 - loss: 0.1205 - val_accuracy: 0.9413 - val_loss: 0.1358
# Epoch 11/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9507 - loss: 0.1160 - val_accuracy: 0.9428 - val_loss: 0.1318
# Epoch 12/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9534 - loss: 0.1115 - val_accuracy: 0.9439 - val_loss: 0.1295
# Epoch 13/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9557 - loss: 0.1097 - val_accuracy: 0.9434 - val_loss: 0.1346
# Epoch 14/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9581 - loss: 0.1051 - val_accuracy: 0.9475 - val_loss: 0.1225
# Epoch 15/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9577 - loss: 0.1004 - val_accuracy: 0.9516 - val_loss: 0.1178
# Epoch 16/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9604 - loss: 0.0986 - val_accuracy: 0.9516 - val_loss: 0.1182
# Epoch 17/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9617 - loss: 0.0961 - val_accuracy: 0.9501 - val_loss: 0.1139
# Epoch 18/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9638 - loss: 0.0913 - val_accuracy: 0.9495 - val_loss: 0.1181
# Epoch 19/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9631 - loss: 0.0890 - val_accuracy: 0.9480 - val_loss: 0.1208
# Epoch 20/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9655 - loss: 0.0873 - val_accuracy: 0.9470 - val_loss: 0.1263
# Epoch 21/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9661 - loss: 0.0835 - val_accuracy: 0.9501 - val_loss: 0.1155
# Epoch 22/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9672 - loss: 0.0816 - val_accuracy: 0.9526 - val_loss: 0.1080
# Epoch 23/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9678 - loss: 0.0809 - val_accuracy: 0.9495 - val_loss: 0.1167
# Epoch 24/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9680 - loss: 0.0783 - val_accuracy: 0.9583 - val_loss: 0.1074
# Epoch 25/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9678 - loss: 0.0759 - val_accuracy: 0.9557 - val_loss: 0.1053
# Epoch 26/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9687 - loss: 0.0769 - val_accuracy: 0.9521 - val_loss: 0.1133
# Epoch 27/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9701 - loss: 0.0723 - val_accuracy: 0.9598 - val_loss: 0.1004
# Epoch 28/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9700 - loss: 0.0734 - val_accuracy: 0.9619 - val_loss: 0.0999
# Epoch 29/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9732 - loss: 0.0705 - val_accuracy: 0.9604 - val_loss: 0.1022
# Epoch 30/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9727 - loss: 0.0666 - val_accuracy: 0.9609 - val_loss: 0.1016
# Epoch 31/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9740 - loss: 0.0660 - val_accuracy: 0.9588 - val_loss: 0.1030
# Epoch 32/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9733 - loss: 0.0653 - val_accuracy: 0.9604 - val_loss: 0.0993
# Epoch 33/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9758 - loss: 0.0632 - val_accuracy: 0.9588 - val_loss: 0.0997
# Epoch 34/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9764 - loss: 0.0616 - val_accuracy: 0.9598 - val_loss: 0.0967
# Epoch 35/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9763 - loss: 0.0610 - val_accuracy: 0.9578 - val_loss: 0.1032
# Epoch 36/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9759 - loss: 0.0596 - val_accuracy: 0.9629 - val_loss: 0.0974
# Epoch 37/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9755 - loss: 0.0591 - val_accuracy: 0.9619 - val_loss: 0.0942
# Epoch 38/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9781 - loss: 0.0575 - val_accuracy: 0.9604 - val_loss: 0.0967
# Epoch 39/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9788 - loss: 0.0554 - val_accuracy: 0.9614 - val_loss: 0.0970
# Epoch 40/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9779 - loss: 0.0551 - val_accuracy: 0.9629 - val_loss: 0.0934
# Epoch 41/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9780 - loss: 0.0567 - val_accuracy: 0.9650 - val_loss: 0.0928
# Epoch 42/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9786 - loss: 0.0549 - val_accuracy: 0.9640 - val_loss: 0.0835
# Epoch 43/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9792 - loss: 0.0515 - val_accuracy: 0.9624 - val_loss: 0.0981
# Epoch 44/50
# 71/71 - 0s - 6ms/step - accuracy: 0.9779 - loss: 0.0545 - val_accuracy: 0.9650 - val_loss: 0.0900
# Epoch 45/50
# 71/71 - 1s - 10ms/step - accuracy: 0.9801 - loss: 0.0501 - val_accuracy: 0.9583 - val_loss: 0.1003
# Epoch 46/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9785 - loss: 0.0534 - val_accuracy: 0.9645 - val_loss: 0.0900
# Epoch 47/50
# 71/71 - 1s - 9ms/step - accuracy: 0.9808 - loss: 0.0510 - val_accuracy: 0.9614 - val_loss: 0.0962
# Epoch 48/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9790 - loss: 0.0519 - val_accuracy: 0.9629 - val_loss: 0.0983
# Epoch 49/50
# 71/71 - 0s - 6ms/step - accuracy: 0.9808 - loss: 0.0483 - val_accuracy: 0.9624 - val_loss: 0.0967
# 05_hidden_units candidate 3/6: [64, 32]
# Epoch 1/50
# 71/71 - 1s - 18ms/step - accuracy: 0.8266 - loss: 0.3664 - val_accuracy: 0.8867 - val_loss: 0.2524
# Epoch 2/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9003 - loss: 0.2210 - val_accuracy: 0.9222 - val_loss: 0.1892
# Epoch 3/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9177 - loss: 0.1858 - val_accuracy: 0.9320 - val_loss: 0.1620
# Epoch 4/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9283 - loss: 0.1636 - val_accuracy: 0.9403 - val_loss: 0.1505
# Epoch 5/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9347 - loss: 0.1484 - val_accuracy: 0.9377 - val_loss: 0.1487
# Epoch 6/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9411 - loss: 0.1373 - val_accuracy: 0.9449 - val_loss: 0.1352
# Epoch 7/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9456 - loss: 0.1299 - val_accuracy: 0.9444 - val_loss: 0.1279
# Epoch 8/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9465 - loss: 0.1218 - val_accuracy: 0.9495 - val_loss: 0.1238
# Epoch 9/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9455 - loss: 0.1219 - val_accuracy: 0.9521 - val_loss: 0.1180
# Epoch 10/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9512 - loss: 0.1126 - val_accuracy: 0.9526 - val_loss: 0.1160
# Epoch 11/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9566 - loss: 0.1042 - val_accuracy: 0.9521 - val_loss: 0.1121
# Epoch 12/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9567 - loss: 0.1043 - val_accuracy: 0.9557 - val_loss: 0.1111
# Epoch 13/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9613 - loss: 0.0953 - val_accuracy: 0.9531 - val_loss: 0.1123
# Epoch 14/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9613 - loss: 0.0919 - val_accuracy: 0.9583 - val_loss: 0.1062
# Epoch 15/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9624 - loss: 0.0897 - val_accuracy: 0.9578 - val_loss: 0.1034
# Epoch 16/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9649 - loss: 0.0826 - val_accuracy: 0.9588 - val_loss: 0.1080
# Epoch 17/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9631 - loss: 0.0852 - val_accuracy: 0.9562 - val_loss: 0.1056
# Epoch 18/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9670 - loss: 0.0794 - val_accuracy: 0.9593 - val_loss: 0.1059
# Epoch 19/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9675 - loss: 0.0771 - val_accuracy: 0.9614 - val_loss: 0.0977
# Epoch 20/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9703 - loss: 0.0749 - val_accuracy: 0.9609 - val_loss: 0.0972
# Epoch 21/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9700 - loss: 0.0742 - val_accuracy: 0.9619 - val_loss: 0.0972
# Epoch 22/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9709 - loss: 0.0716 - val_accuracy: 0.9634 - val_loss: 0.0964
# Epoch 23/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9705 - loss: 0.0737 - val_accuracy: 0.9614 - val_loss: 0.0992
# Epoch 24/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9706 - loss: 0.0710 - val_accuracy: 0.9598 - val_loss: 0.1022
# Epoch 25/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9752 - loss: 0.0666 - val_accuracy: 0.9609 - val_loss: 0.1019
# Epoch 26/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9726 - loss: 0.0674 - val_accuracy: 0.9614 - val_loss: 0.0935
# Epoch 27/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9740 - loss: 0.0600 - val_accuracy: 0.9634 - val_loss: 0.0951
# Epoch 28/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9740 - loss: 0.0613 - val_accuracy: 0.9629 - val_loss: 0.0891
# Epoch 29/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9740 - loss: 0.0647 - val_accuracy: 0.9609 - val_loss: 0.0978
# Epoch 30/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9757 - loss: 0.0619 - val_accuracy: 0.9650 - val_loss: 0.0931
# Epoch 31/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9758 - loss: 0.0576 - val_accuracy: 0.9650 - val_loss: 0.0902
# Epoch 32/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9775 - loss: 0.0559 - val_accuracy: 0.9624 - val_loss: 0.0923
# Epoch 33/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9780 - loss: 0.0534 - val_accuracy: 0.9624 - val_loss: 0.0945
# Epoch 34/50
# 71/71 - 0s - 3ms/step - accuracy: 0.9780 - loss: 0.0556 - val_accuracy: 0.9650 - val_loss: 0.0926
# Epoch 35/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9792 - loss: 0.0521 - val_accuracy: 0.9634 - val_loss: 0.0919
# 05_hidden_units candidate 4/6: [128, 64]
# Epoch 1/50
# 71/71 - 2s - 26ms/step - accuracy: 0.8567 - loss: 0.3052 - val_accuracy: 0.9145 - val_loss: 0.2125
# Epoch 2/50
# 71/71 - 0s - 6ms/step - accuracy: 0.9147 - loss: 0.1870 - val_accuracy: 0.9295 - val_loss: 0.1793
# Epoch 3/50
# 71/71 - 1s - 7ms/step - accuracy: 0.9299 - loss: 0.1608 - val_accuracy: 0.9346 - val_loss: 0.1610
# Epoch 4/50
# 71/71 - 1s - 7ms/step - accuracy: 0.9374 - loss: 0.1430 - val_accuracy: 0.9444 - val_loss: 0.1405
# Epoch 5/50
# 71/71 - 0s - 6ms/step - accuracy: 0.9450 - loss: 0.1317 - val_accuracy: 0.9475 - val_loss: 0.1358
# Epoch 6/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9481 - loss: 0.1221 - val_accuracy: 0.9480 - val_loss: 0.1290
# Epoch 7/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9515 - loss: 0.1129 - val_accuracy: 0.9480 - val_loss: 0.1327
# Epoch 8/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9520 - loss: 0.1142 - val_accuracy: 0.9511 - val_loss: 0.1253
# Epoch 9/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9579 - loss: 0.1001 - val_accuracy: 0.9567 - val_loss: 0.1130
# Epoch 10/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9604 - loss: 0.0960 - val_accuracy: 0.9542 - val_loss: 0.1190
# Epoch 11/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9607 - loss: 0.0941 - val_accuracy: 0.9598 - val_loss: 0.1088
# Epoch 12/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9625 - loss: 0.0897 - val_accuracy: 0.9604 - val_loss: 0.1068
# Epoch 13/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9629 - loss: 0.0865 - val_accuracy: 0.9624 - val_loss: 0.1038
# Epoch 14/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9679 - loss: 0.0791 - val_accuracy: 0.9624 - val_loss: 0.0972
# Epoch 15/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9663 - loss: 0.0800 - val_accuracy: 0.9557 - val_loss: 0.1124
# Epoch 16/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9696 - loss: 0.0719 - val_accuracy: 0.9593 - val_loss: 0.1056
# Epoch 17/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9709 - loss: 0.0700 - val_accuracy: 0.9629 - val_loss: 0.0990
# Epoch 18/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9711 - loss: 0.0714 - val_accuracy: 0.9578 - val_loss: 0.1086
# Epoch 19/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9748 - loss: 0.0613 - val_accuracy: 0.9660 - val_loss: 0.0994
# Epoch 20/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9745 - loss: 0.0631 - val_accuracy: 0.9660 - val_loss: 0.0883
# Epoch 21/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9754 - loss: 0.0607 - val_accuracy: 0.9681 - val_loss: 0.0921
# Epoch 22/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9764 - loss: 0.0606 - val_accuracy: 0.9691 - val_loss: 0.0924
# Epoch 23/50
# 71/71 - 1s - 8ms/step - accuracy: 0.9776 - loss: 0.0545 - val_accuracy: 0.9686 - val_loss: 0.0945
# Epoch 24/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9784 - loss: 0.0555 - val_accuracy: 0.9562 - val_loss: 0.1276
# Epoch 25/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9758 - loss: 0.0562 - val_accuracy: 0.9629 - val_loss: 0.0973
# Epoch 26/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9791 - loss: 0.0515 - val_accuracy: 0.9681 - val_loss: 0.0882
# Epoch 27/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9787 - loss: 0.0498 - val_accuracy: 0.9609 - val_loss: 0.1176
# Epoch 28/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9802 - loss: 0.0472 - val_accuracy: 0.9681 - val_loss: 0.0885
# Epoch 29/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9796 - loss: 0.0485 - val_accuracy: 0.9665 - val_loss: 0.0915
# Epoch 30/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9823 - loss: 0.0434 - val_accuracy: 0.9670 - val_loss: 0.0930
# Epoch 31/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9836 - loss: 0.0422 - val_accuracy: 0.9696 - val_loss: 0.0859
# Epoch 32/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9839 - loss: 0.0446 - val_accuracy: 0.9645 - val_loss: 0.1013
# Epoch 33/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9839 - loss: 0.0419 - val_accuracy: 0.9722 - val_loss: 0.0928
# Epoch 34/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9832 - loss: 0.0415 - val_accuracy: 0.9640 - val_loss: 0.1004
# Epoch 35/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9847 - loss: 0.0375 - val_accuracy: 0.9753 - val_loss: 0.0809
# Epoch 36/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9857 - loss: 0.0381 - val_accuracy: 0.9748 - val_loss: 0.0852
# Epoch 37/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9853 - loss: 0.0372 - val_accuracy: 0.9727 - val_loss: 0.0860
# Epoch 38/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9861 - loss: 0.0350 - val_accuracy: 0.9732 - val_loss: 0.0838
# Epoch 39/50
# 71/71 - 0s - 6ms/step - accuracy: 0.9860 - loss: 0.0349 - val_accuracy: 0.9701 - val_loss: 0.0941
# Epoch 40/50
# 71/71 - 0s - 6ms/step - accuracy: 0.9874 - loss: 0.0346 - val_accuracy: 0.9743 - val_loss: 0.0868
# Epoch 41/50
# 71/71 - 0s - 7ms/step - accuracy: 0.9866 - loss: 0.0341 - val_accuracy: 0.9748 - val_loss: 0.0861
# Epoch 42/50
# 71/71 - 0s - 6ms/step - accuracy: 0.9876 - loss: 0.0340 - val_accuracy: 0.9701 - val_loss: 0.0995
# 05_hidden_units candidate 5/6: [256, 128]
# Epoch 1/50
# 71/71 - 2s - 30ms/step - accuracy: 0.8693 - loss: 0.2818 - val_accuracy: 0.9197 - val_loss: 0.1962
# Epoch 2/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9213 - loss: 0.1851 - val_accuracy: 0.9248 - val_loss: 0.1820
# Epoch 3/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9310 - loss: 0.1606 - val_accuracy: 0.9325 - val_loss: 0.1648
# Epoch 4/50
# 71/71 - 0s - 6ms/step - accuracy: 0.9407 - loss: 0.1421 - val_accuracy: 0.9403 - val_loss: 0.1524
# Epoch 5/50
# 71/71 - 0s - 6ms/step - accuracy: 0.9457 - loss: 0.1280 - val_accuracy: 0.9434 - val_loss: 0.1398
# Epoch 6/50
# 71/71 - 0s - 6ms/step - accuracy: 0.9486 - loss: 0.1198 - val_accuracy: 0.9444 - val_loss: 0.1453
# Epoch 7/50
# 71/71 - 0s - 6ms/step - accuracy: 0.9549 - loss: 0.1071 - val_accuracy: 0.9516 - val_loss: 0.1206
# Epoch 8/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9563 - loss: 0.1015 - val_accuracy: 0.9516 - val_loss: 0.1269
# Epoch 9/50
# 71/71 - 0s - 6ms/step - accuracy: 0.9599 - loss: 0.0933 - val_accuracy: 0.9501 - val_loss: 0.1385
# Epoch 10/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9674 - loss: 0.0839 - val_accuracy: 0.9562 - val_loss: 0.1211
# Epoch 11/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9688 - loss: 0.0786 - val_accuracy: 0.9604 - val_loss: 0.1120
# Epoch 12/50
# 71/71 - 0s - 6ms/step - accuracy: 0.9702 - loss: 0.0747 - val_accuracy: 0.9609 - val_loss: 0.1065
# Epoch 13/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9728 - loss: 0.0704 - val_accuracy: 0.9578 - val_loss: 0.1187
# Epoch 14/50
# 71/71 - 0s - 6ms/step - accuracy: 0.9736 - loss: 0.0669 - val_accuracy: 0.9583 - val_loss: 0.1201
# Epoch 15/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9751 - loss: 0.0624 - val_accuracy: 0.9655 - val_loss: 0.0957
# Epoch 16/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9759 - loss: 0.0583 - val_accuracy: 0.9614 - val_loss: 0.1048
# Epoch 17/50
# 71/71 - 1s - 9ms/step - accuracy: 0.9769 - loss: 0.0573 - val_accuracy: 0.9650 - val_loss: 0.0989
# Epoch 18/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9778 - loss: 0.0517 - val_accuracy: 0.9650 - val_loss: 0.0941
# Epoch 19/50
# 71/71 - 0s - 6ms/step - accuracy: 0.9807 - loss: 0.0493 - val_accuracy: 0.9701 - val_loss: 0.0957
# Epoch 20/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9817 - loss: 0.0484 - val_accuracy: 0.9645 - val_loss: 0.0949
# Epoch 21/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9798 - loss: 0.0468 - val_accuracy: 0.9640 - val_loss: 0.0906
# Epoch 22/50
# 71/71 - 0s - 6ms/step - accuracy: 0.9794 - loss: 0.0470 - val_accuracy: 0.9650 - val_loss: 0.1011
# Epoch 23/50
# 71/71 - 0s - 6ms/step - accuracy: 0.9833 - loss: 0.0414 - val_accuracy: 0.9691 - val_loss: 0.0941
# Epoch 24/50
# 71/71 - 0s - 6ms/step - accuracy: 0.9832 - loss: 0.0427 - val_accuracy: 0.9701 - val_loss: 0.0826
# Epoch 25/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9861 - loss: 0.0345 - val_accuracy: 0.9691 - val_loss: 0.1058
# Epoch 26/50
# 71/71 - 0s - 7ms/step - accuracy: 0.9859 - loss: 0.0372 - val_accuracy: 0.9706 - val_loss: 0.0949
# Epoch 27/50
# 71/71 - 1s - 10ms/step - accuracy: 0.9860 - loss: 0.0358 - val_accuracy: 0.9701 - val_loss: 0.0906
# Epoch 28/50
# 71/71 - 1s - 9ms/step - accuracy: 0.9870 - loss: 0.0324 - val_accuracy: 0.9681 - val_loss: 0.0909
# Epoch 29/50
# 71/71 - 1s - 20ms/step - accuracy: 0.9870 - loss: 0.0322 - val_accuracy: 0.9701 - val_loss: 0.0923
# Epoch 30/50
# 71/71 - 1s - 10ms/step - accuracy: 0.9868 - loss: 0.0323 - val_accuracy: 0.9686 - val_loss: 0.0880
# Epoch 31/50
# 71/71 - 1s - 8ms/step - accuracy: 0.9879 - loss: 0.0291 - val_accuracy: 0.9717 - val_loss: 0.0886
# 05_hidden_units candidate 6/6: [256, 128, 64]
# Epoch 1/50
# 71/71 - 2s - 21ms/step - accuracy: 0.8712 - loss: 0.2818 - val_accuracy: 0.8888 - val_loss: 0.2526
# Epoch 2/50
# 71/71 - 0s - 7ms/step - accuracy: 0.9233 - loss: 0.1775 - val_accuracy: 0.9135 - val_loss: 0.2016
# Epoch 3/50
# 71/71 - 0s - 6ms/step - accuracy: 0.9361 - loss: 0.1463 - val_accuracy: 0.9361 - val_loss: 0.1539
# Epoch 4/50
# 71/71 - 0s - 6ms/step - accuracy: 0.9450 - loss: 0.1288 - val_accuracy: 0.9295 - val_loss: 0.1768
# Epoch 5/50
# 71/71 - 0s - 6ms/step - accuracy: 0.9528 - loss: 0.1137 - val_accuracy: 0.9434 - val_loss: 0.1452
# Epoch 6/50
# 71/71 - 0s - 6ms/step - accuracy: 0.9573 - loss: 0.1026 - val_accuracy: 0.9470 - val_loss: 0.1371
# Epoch 7/50
# 71/71 - 0s - 6ms/step - accuracy: 0.9624 - loss: 0.0927 - val_accuracy: 0.9480 - val_loss: 0.1415
# Epoch 8/50
# 71/71 - 0s - 6ms/step - accuracy: 0.9634 - loss: 0.0861 - val_accuracy: 0.9593 - val_loss: 0.1048
# Epoch 9/50
# 71/71 - 0s - 6ms/step - accuracy: 0.9690 - loss: 0.0771 - val_accuracy: 0.9557 - val_loss: 0.1168
# Epoch 10/50
# 71/71 - 0s - 6ms/step - accuracy: 0.9704 - loss: 0.0740 - val_accuracy: 0.9624 - val_loss: 0.1011
# Epoch 11/50
# 71/71 - 0s - 6ms/step - accuracy: 0.9748 - loss: 0.0651 - val_accuracy: 0.9634 - val_loss: 0.1103
# Epoch 12/50
# 71/71 - 0s - 6ms/step - accuracy: 0.9733 - loss: 0.0623 - val_accuracy: 0.9670 - val_loss: 0.0969
# Epoch 13/50
# 71/71 - 0s - 6ms/step - accuracy: 0.9765 - loss: 0.0584 - val_accuracy: 0.9645 - val_loss: 0.1014
# Epoch 14/50
# 71/71 - 0s - 6ms/step - accuracy: 0.9784 - loss: 0.0555 - val_accuracy: 0.9598 - val_loss: 0.1165
# Epoch 15/50
# 71/71 - 0s - 6ms/step - accuracy: 0.9786 - loss: 0.0538 - val_accuracy: 0.9650 - val_loss: 0.0937
# Epoch 16/50
# 71/71 - 0s - 6ms/step - accuracy: 0.9787 - loss: 0.0529 - val_accuracy: 0.9681 - val_loss: 0.0893
# Epoch 17/50
# 71/71 - 0s - 6ms/step - accuracy: 0.9832 - loss: 0.0442 - val_accuracy: 0.9609 - val_loss: 0.1071
# Epoch 18/50
# 71/71 - 0s - 6ms/step - accuracy: 0.9834 - loss: 0.0437 - val_accuracy: 0.9670 - val_loss: 0.0938
# Epoch 19/50
# 71/71 - 1s - 8ms/step - accuracy: 0.9823 - loss: 0.0439 - val_accuracy: 0.9665 - val_loss: 0.1074
# Epoch 20/50
# 71/71 - 1s - 10ms/step - accuracy: 0.9855 - loss: 0.0378 - val_accuracy: 0.9722 - val_loss: 0.0855
# Epoch 21/50
# 71/71 - 1s - 18ms/step - accuracy: 0.9848 - loss: 0.0388 - val_accuracy: 0.9670 - val_loss: 0.0991
# Epoch 22/50
# 71/71 - 1s - 18ms/step - accuracy: 0.9847 - loss: 0.0375 - val_accuracy: 0.9706 - val_loss: 0.1052
# Epoch 23/50
# 71/71 - 1s - 7ms/step - accuracy: 0.9859 - loss: 0.0376 - val_accuracy: 0.9650 - val_loss: 0.1083
# Epoch 24/50
# 71/71 - 0s - 6ms/step - accuracy: 0.9869 - loss: 0.0352 - val_accuracy: 0.9670 - val_loss: 0.1093
# Epoch 25/50
# 71/71 - 0s - 6ms/step - accuracy: 0.9859 - loss: 0.0346 - val_accuracy: 0.9686 - val_loss: 0.0955
# Epoch 26/50
# 71/71 - 0s - 6ms/step - accuracy: 0.9880 - loss: 0.0318 - val_accuracy: 0.9640 - val_loss: 0.1218
# Epoch 27/50
# 71/71 - 0s - 6ms/step - accuracy: 0.9884 - loss: 0.0302 - val_accuracy: 0.9681 - val_loss: 0.1128
#              stage       candidate    hidden_units activation optimizer  \
# 3  05_hidden_units       [128, 64]       [128, 64]        elu   rmsprop
# 5  05_hidden_units  [256, 128, 64]  [256, 128, 64]        elu   rmsprop
# 4  05_hidden_units      [256, 128]      [256, 128]        elu   rmsprop
# 1  05_hidden_units           [128]           [128]        elu   rmsprop
# 0  05_hidden_units            [64]            [64]        elu   rmsprop
# 2  05_hidden_units        [64, 32]        [64, 32]        elu   rmsprop
#
#    dropout  learning_rate  batch_size                 loss  threshold  ...  \
# 3      0.1          0.001         128  binary_crossentropy        0.5  ...
# 5      0.1          0.001         128  binary_crossentropy        0.5  ...
# 4      0.1          0.001         128  binary_crossentropy        0.5  ...
# 1      0.1          0.001         128  binary_crossentropy        0.5  ...
# 0      0.1          0.001         128  binary_crossentropy        0.5  ...
# 2      0.1          0.001         128  binary_crossentropy        0.5  ...
#
#          seed validation_macro_f1  validation_binary_f1_synthetic  \
# 3  1857800633            0.971293                        0.981995
# 5  1288574074            0.967762                        0.979715
# 4   491369526            0.965282                        0.978261
# 1   357696166            0.958537                        0.973525
# 0  2072030854            0.958501                        0.973545
# 2  1583851532            0.957352                        0.972769
#
#    validation_accuracy  validation_precision_synthetic  \
# 3             0.975283                        0.989418
# 5             0.972194                        0.988628
# 4             0.970134                        0.984906
# 1             0.963955                        0.989239
# 0             0.963955                        0.988488
# 2             0.962925                        0.988470
#
#    validation_recall_synthetic  best_validation_loss  best_epoch  \
# 3                     0.974684              0.080935          35
# 5                     0.970961              0.085515          20
# 4                     0.971705              0.082617          24
# 1                     0.958302              0.083510          42
# 0                     0.959047              0.084025          49
# 2                     0.957558              0.089136          28
#
#    epochs_trained  runtime_seconds
# 3              42        15.546826
# 5              27        15.109954
# 4              31        16.463444
# 1              49        16.777171
# 0              50        14.862677
# 2              35         9.965709
#
# [6 rows x 22 columns]
# Saved selected config: /content/drive/MyDrive/Colab Notebooks/Education/INM701/outputs/mlp/configs/05_selected_config.json

# %% [markdown]
# ## 6. Checks

# %%
# Purpose: Runs this notebook step and prints or saves the resulting intermediate output for review.
display(pd.DataFrame([("varies_only", "hidden_units"), ("validation_macro_f1_primary", True), ("test_metrics_computed", False)], columns=["check", "value"]))
# Out:
#                          check         value
# 0                  varies_only  hidden_units
# 1  validation_macro_f1_primary          True
# 2        test_metrics_computed         False
