# %% [markdown]
# # 03 MLP Optimizer Trial
#
# Controlled hyperparameter screening. Change only `optimizer`; all inherited settings remain fixed. Learning rate stays fixed, so optimizer-specific LR optima are not claimed.

# %% [markdown]
# ## 1. Package Setup

# %%
# Purpose: Package installs are documented but not run automatically during this static refactor.
# %pip install tensorflow scikit-learn pandas numpy matplotlib seaborn joblib soundfile librosa

# %% [markdown]
# ## 2. Load Cache and Previous Config

# %%
import os
from pathlib import Path

# Purpose: Mounts Google Drive when this notebook is running in Google Colab.
# Why this exists: the project files, cached MFCC features, manifests, models, figures,
# and metric outputs live in Google Drive during Colab runs. The /content/drive path
# only represents the real MyDrive files after drive.mount("/content/drive") succeeds.
# Important: the project root should be the folder that contains Data, Model Variants,
# and outputs. For this project, that expected Colab folder is the INM701 folder below.
COLAB_DRIVE_MOUNT_POINT = Path("/content/drive")
EXPECTED_COLAB_PROJECT_ROOT = Path("/content/drive/MyDrive/Colab Notebooks/Education/INM701")

try:
    from google.colab import drive

    drive.mount(str(COLAB_DRIVE_MOUNT_POINT))
    print("Google Colab detected. Google Drive mounted.")

    current_project_root = os.environ.get("INTRO_AI_PROJECT_ROOT")
    current_data_dir_exists = bool(current_project_root) and (Path(current_project_root) / "Data").exists()
    expected_data_dir_exists = (EXPECTED_COLAB_PROJECT_ROOT / "Data").exists()

    # Purpose: Keep a valid user-provided project root, but repair stale runtime state
    # if a previous cell pointed INTRO_AI_PROJECT_ROOT somewhere that does not contain Data.
    if current_data_dir_exists:
        print("INTRO_AI_PROJECT_ROOT already points to a folder with Data, so it was kept.")
    elif expected_data_dir_exists:
        os.environ["INTRO_AI_PROJECT_ROOT"] = str(EXPECTED_COLAB_PROJECT_ROOT)
        print("INTRO_AI_PROJECT_ROOT set to the expected INM701 project folder.")
    elif not current_project_root:
        os.environ["INTRO_AI_PROJECT_ROOT"] = str(EXPECTED_COLAB_PROJECT_ROOT)
        print("INTRO_AI_PROJECT_ROOT was not set, so it now points to the expected INM701 folder.")
    else:
        print("INTRO_AI_PROJECT_ROOT was kept, but Data was not found there or in the expected INM701 folder.")
except Exception as exc:
    print("Google Colab Drive mount skipped. This is expected outside Colab.")
    print("Mount skip reason:", exc)

active_project_root = os.environ.get("INTRO_AI_PROJECT_ROOT", "not set")
print("INTRO_AI_PROJECT_ROOT:", active_project_root)
if active_project_root != "not set":
    active_project_root = Path(active_project_root)
    print("Project root exists:", active_project_root.exists())
    print("Expected Data folder:", active_project_root / "Data")
    print("Data folder exists:", (active_project_root / "Data").exists())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Google Colab detected. Google Drive mounted.
# INTRO_AI_PROJECT_ROOT set to the expected INM701 project folder.
# INTRO_AI_PROJECT_ROOT: /content/drive/MyDrive/Colab Notebooks/Education/INM701
# Project root exists: True
# Expected Data folder: /content/drive/MyDrive/Colab Notebooks/Education/INM701/Data
# Data folder exists: True

# %%
# Purpose: Later notebooks load the one MLP-ready cache made by notebook 00. They do not
# rescan folders, regenerate splits, extract MFCCs, fit scalers, or recalculate class weights.
import hashlib
import json
import os
import random
import time
from itertools import product
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score, precision_score, recall_score
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.models import Sequential

try:
    from IPython.display import display
except Exception:
    display = print

RANDOM_STATE = 42
MAX_EPOCHS = 50
EARLY_STOP_PATIENCE = 7
EARLY_STOP_MIN_DELTA = 1e-4
THRESHOLD = 0.5
CLASS_NAMES = {0: "bona_fide", 1: "synthetic"}
CONFIRMATION_SEEDS = [42, 123, 2026]


def resolve_project_root():
    # Purpose: default path.
    explicit = os.environ.get("INTRO_AI_PROJECT_ROOT")
    if explicit:
        return Path(explicit).expanduser().resolve()
    cwd = Path.cwd().resolve()
    # Purpose: Runs each candidate configuration under the same data split for a fair validation comparison.
    for candidate in [cwd, *cwd.parents]:
        if (candidate / "Model Variants").exists():
            return candidate
        if (candidate / "Training" / "Model Variants").exists():
            return candidate / "Training"
    return Path("/content/drive/MyDrive/Colab Notebooks/Education/INM701")


# Purpose: Centralizes filesystem paths so dataset inputs, caches, figures, models, and metric tables are easy
# Purpose: to trace.
PROJECT_ROOT = resolve_project_root()
OUTPUT_DIR = PROJECT_ROOT / "outputs" / "mlp"
CACHE_DIR = OUTPUT_DIR / "cache"
MANIFESTS_DIR = OUTPUT_DIR / "manifests"
CONFIGS_DIR = OUTPUT_DIR / "configs"
TABLES_DIR = OUTPUT_DIR / "tables"
HISTORIES_DIR = OUTPUT_DIR / "histories"
METRICS_DIR = OUTPUT_DIR / "metrics"
FIGURES_DIR = OUTPUT_DIR / "figures"
MODELS_DIR = OUTPUT_DIR / "models"
PILOT_LEGACY_DIR = OUTPUT_DIR / "pilot_legacy"
# Purpose: Creates each output directory before later cells try to save tables, figures, or models.
for directory in [OUTPUT_DIR, CACHE_DIR, MANIFESTS_DIR, CONFIGS_DIR, TABLES_DIR, HISTORIES_DIR, METRICS_DIR, FIGURES_DIR, MODELS_DIR, PILOT_LEGACY_DIR]:
    directory.mkdir(parents=True, exist_ok=True)


def require_file(path):
    # Purpose: Stops the notebook early with a clear message when a required upstream artifact is missing.
    path = Path(path)
    if not path.exists():
        raise FileNotFoundError(f"Required file not found: {path}")
    return path


def load_json(path):
    # Purpose: Keeps the load_json helper isolated so later notebook cells can call it consistently.
    with open(require_file(path), "r", encoding="utf-8") as f:
        return json.load(f)


def save_json(payload, path):
    # Purpose: Keeps the save_json helper isolated so later notebook cells can call it consistently.
    with open(path, "w", encoding="utf-8") as f:
        json.dump(payload, f, indent=2)




def normalise_handoff_config(config):
    # Purpose: Normalises a config loaded from a JSON string or CSV row before it is reused
    # by the next notebook in the MLP chain. This keeps rebuilt handoff files compatible
    # with configs produced by a full training run.
    normalised = dict(config)
    hidden_units = normalised.get("hidden_units", [])
    if isinstance(hidden_units, str):
        hidden_units = json.loads(hidden_units)
    normalised["hidden_units"] = [int(value) for value in hidden_units]
    normalised["activation"] = str(normalised["activation"])
    normalised["optimizer"] = str(normalised["optimizer"])
    normalised["dropout"] = float(normalised["dropout"])
    normalised["learning_rate"] = float(normalised["learning_rate"])
    normalised["batch_size"] = int(normalised["batch_size"])
    normalised["loss"] = normalised.get("loss", "binary_crossentropy")
    normalised["threshold"] = float(normalised.get("threshold", THRESHOLD))
    return normalised


def first_existing_results_path(candidate_paths):
    # Purpose: Supports the normal result filename and any documented alias without changing
    # where the notebook saves new results. The first existing CSV is used for rebuilding.
    paths = [Path(path) for path in candidate_paths]
    for path in paths:
        if path.exists():
            return path
    return paths[0]


def rebuild_selected_config_from_results(results_path, selected_path, selected_by_stage):
    # Purpose: Rebuilds a missing selected_config JSON from an existing validation-results
    # CSV. This avoids rerunning training just to recreate the JSON handoff file.
    results_path = Path(results_path)
    selected_path = Path(selected_path)
    if not results_path.exists():
        print("Cannot rebuild selected config because result CSV is missing:", results_path)
        return None

    results_df = pd.read_csv(results_path)
    required_columns = {"config_json", "validation_macro_f1", "best_validation_loss"}
    missing_columns = required_columns - set(results_df.columns)
    if missing_columns:
        raise RuntimeError(f"Cannot rebuild {selected_path.name}; missing columns in {results_path.name}: {sorted(missing_columns)}")
    if results_df.empty:
        raise RuntimeError(f"Cannot rebuild {selected_path.name}; result CSV is empty: {results_path}")

    best_row = results_df.sort_values(["validation_macro_f1", "best_validation_loss"], ascending=[False, True]).iloc[0]
    selected = normalise_handoff_config(json.loads(best_row["config_json"]))
    selected.update({
        "selected_by_stage": selected_by_stage,
        "selection_metric": "validation_macro_f1",
        "validation_macro_f1": float(best_row["validation_macro_f1"]),
        "best_validation_loss": float(best_row["best_validation_loss"]),
        "rebuilt_from_results_csv": str(results_path),
    })
    save_json(selected, selected_path)
    print("Rebuilt selected config from existing results:", selected_path)
    return selected


def ensure_selected_config_from_results(selected_path, results_path, selected_by_stage):
    # Purpose: Repairs a missing previous-stage config before this notebook tries to load it.
    # If neither the JSON nor the CSV exists, the later require_file/load_json call will still
    # stop with a clear missing-artifact error.
    selected_path = Path(selected_path)
    results_path = Path(results_path)
    if selected_path.exists():
        return load_json(selected_path)
    if results_path.exists():
        return rebuild_selected_config_from_results(results_path, selected_path, selected_by_stage)
    print("Selected config missing:", selected_path)
    print("Result CSV also missing, so config cannot be rebuilt:", results_path)
    return None


def load_class_weights():
    # Purpose: Keeps the load_class_weights helper isolated so later notebook cells can call it consistently.
    payload = load_json(CONFIGS_DIR / "class_weights.json")
    weights = payload.get("class_weights", payload)
    return {int(label): float(weight) for label, weight in weights.items()}


for required in [
    CACHE_DIR / "X_train.npy",
    CACHE_DIR / "y_train.npy",
    CACHE_DIR / "train_metadata.csv",
    CACHE_DIR / "X_validation.npy",
    CACHE_DIR / "y_validation.npy",
    CACHE_DIR / "validation_metadata.csv",
    CACHE_DIR / "feature_config.json",
    CONFIGS_DIR / "class_weights.json",
]:
    require_file(required)

X_train = np.load(CACHE_DIR / "X_train.npy")
y_train = np.load(CACHE_DIR / "y_train.npy")
train_metadata = pd.read_csv(CACHE_DIR / "train_metadata.csv")
X_validation = np.load(CACHE_DIR / "X_validation.npy")
y_validation = np.load(CACHE_DIR / "y_validation.npy")
validation_metadata = pd.read_csv(CACHE_DIR / "validation_metadata.csv")
feature_config = load_json(CACHE_DIR / "feature_config.json")
CLASS_WEIGHTS = load_class_weights()

if len(X_train) != len(y_train) or len(X_train) != len(train_metadata):
    raise RuntimeError("Training cache arrays, labels and metadata are not row-aligned.")
if len(X_validation) != len(y_validation) or len(X_validation) != len(validation_metadata):
    raise RuntimeError("Validation cache arrays, labels and metadata are not row-aligned.")

print("Loaded MLP cache:", CACHE_DIR)
print("X_train shape:", X_train.shape)
print("X_validation shape:", X_validation.shape)

# Purpose: Rebuild the previous selected config from its result CSV if the JSON handoff file is missing.
ensure_selected_config_from_results(CONFIGS_DIR / "02_selected_config.json", TABLES_DIR / "02_activation_results.csv", "02_activation")
base_config = load_json(CONFIGS_DIR / "02_selected_config.json")
print("Loaded previous config:", "02_selected_config.json")
# Out:
# Loaded MLP cache: /content/drive/MyDrive/Colab Notebooks/Education/INM701/outputs/mlp/cache
# X_train shape: (9060, 80)
# X_validation shape: (1942, 80)
# Loaded previous config: 02_selected_config.json

# %% [markdown]
# ## 3. Keras Utilities

# %%
# Purpose: Shared beginner-readable Keras utilities for validation-only model selection.
def normalise_config(config):
    # Purpose: Keeps the normalise_config helper isolated so later notebook cells can call it consistently.
    normalised = dict(config)
    normalised["hidden_units"] = [int(value) for value in normalised["hidden_units"]]
    normalised["activation"] = str(normalised["activation"])
    normalised["optimizer"] = str(normalised["optimizer"])
    normalised["dropout"] = float(normalised["dropout"])
    normalised["learning_rate"] = float(normalised["learning_rate"])
    normalised["batch_size"] = int(normalised["batch_size"])
    normalised["loss"] = normalised.get("loss", "binary_crossentropy")
    normalised["threshold"] = float(normalised.get("threshold", THRESHOLD))
    return normalised


def config_json(config):
    # Purpose: Keeps the config_json helper isolated so later notebook cells can call it consistently.
    return json.dumps(normalise_config(config), sort_keys=True)


def config_key(config):
    # Purpose: Keeps the config_key helper isolated so later notebook cells can call it consistently.
    return hashlib.sha256(config_json(config).encode("utf-8")).hexdigest()


def seed_from_config(config, base_seed=RANDOM_STATE):
    # Purpose: Keeps the seed_from_config helper isolated so later notebook cells can call it consistently.
    digest = hashlib.sha256(f"{base_seed}:{config_json(config)}".encode("utf-8")).hexdigest()
    return int(digest[:8], 16) % (2**31 - 1)


def set_global_seed(seed):
    # Purpose: Keeps the set_global_seed helper isolated so later notebook cells can call it consistently.
    random.seed(int(seed))
    np.random.seed(int(seed))
    tf.keras.utils.set_random_seed(int(seed))
    os.environ["PYTHONHASHSEED"] = str(int(seed))


def make_optimizer(config):
    # Purpose: Keeps the make_optimizer helper isolated so later notebook cells can call it consistently.
    name = str(config["optimizer"]).lower()
    lr = float(config["learning_rate"])
    if name == "adam":
        return tf.keras.optimizers.Adam(learning_rate=lr)
    if name == "rmsprop":
        return tf.keras.optimizers.RMSprop(learning_rate=lr)
    if name in ["sgd", "sgd_momentum"]:
        return tf.keras.optimizers.SGD(learning_rate=lr, momentum=0.9)
    raise ValueError(f"Unsupported optimizer: {config['optimizer']}")


def build_mlp_model(config, input_dim):
    # Purpose: Constructs the MLP architecture for the current experiment configuration.
    config = normalise_config(config)
    model = Sequential()
    model.add(Input(shape=(input_dim,)))
    # Purpose: Iterates over this collection to build the next table, feature set, or experiment result
    # Purpose: consistently.
    for units in config["hidden_units"]:
        model.add(Dense(units, activation=config["activation"]))
        if config["dropout"] > 0:
            model.add(Dropout(config["dropout"]))
    model.add(Dense(1, activation="sigmoid"))
    model.compile(loss=config["loss"], optimizer=make_optimizer(config), metrics=["accuracy"])
    return model


def train_and_evaluate_config(config, run_seed, run_name, verbose=0):
    # Purpose: consistently.
    config = normalise_config(config)
    tf.keras.backend.clear_session()
    set_global_seed(run_seed)
    model = build_mlp_model(config, X_train.shape[1])
    callbacks = [
        tf.keras.callbacks.EarlyStopping(
            monitor="val_loss",
            patience=EARLY_STOP_PATIENCE,
            min_delta=EARLY_STOP_MIN_DELTA,
            restore_best_weights=True,
        )
    ]
    start = time.perf_counter()
    history = model.fit(
        X_train,
        y_train,
        validation_data=(X_validation, y_validation),
        epochs=MAX_EPOCHS,
        batch_size=config["batch_size"],
        class_weight=CLASS_WEIGHTS,
        callbacks=callbacks,
        verbose=verbose,
    )
    runtime = time.perf_counter() - start
    probability = model.predict(X_validation, batch_size=config["batch_size"], verbose=0).ravel()
    pred = (probability >= config["threshold"]).astype(int)
    row = {
        "configuration": config,
        "config_json": config_json(config),
        "config_key": config_key(config),
        "seed": int(run_seed),
        "validation_macro_f1": float(f1_score(y_validation, pred, average="macro", zero_division=0)),
        "validation_binary_f1_synthetic": float(f1_score(y_validation, pred, pos_label=1, zero_division=0)),
        "validation_accuracy": float(accuracy_score(y_validation, pred)),
        "validation_precision_synthetic": float(precision_score(y_validation, pred, pos_label=1, zero_division=0)),
        "validation_recall_synthetic": float(recall_score(y_validation, pred, pos_label=1, zero_division=0)),
        "best_validation_loss": float(np.min(history.history["val_loss"])),
        "best_epoch": int(np.argmin(history.history["val_loss"]) + 1),
        "epochs_trained": int(len(history.history["loss"])),
        "runtime_seconds": float(runtime),
        "run_name": run_name,
    }
    history_df = pd.DataFrame(history.history)
    history_df.insert(0, "epoch", np.arange(1, len(history_df) + 1))
    return row, history_df


def flat_result(row, extra=None):
    # Purpose: Keeps the flat_result helper isolated so later notebook cells can call it consistently.
    extra = extra or {}
    config = normalise_config(row["configuration"])
    flat = dict(extra)
    flat.update({
        "hidden_units": json.dumps(config["hidden_units"]),
        "activation": config["activation"],
        "optimizer": config["optimizer"],
        "dropout": config["dropout"],
        "learning_rate": config["learning_rate"],
        "batch_size": config["batch_size"],
        "loss": config["loss"],
        "threshold": config["threshold"],
        "config_json": row["config_json"],
        "config_key": row["config_key"],
        "seed": row["seed"],
        "validation_macro_f1": row["validation_macro_f1"],
        "validation_binary_f1_synthetic": row["validation_binary_f1_synthetic"],
        "validation_accuracy": row["validation_accuracy"],
        "validation_precision_synthetic": row["validation_precision_synthetic"],
        "validation_recall_synthetic": row["validation_recall_synthetic"],
        "best_validation_loss": row["best_validation_loss"],
        "best_epoch": row["best_epoch"],
        "epochs_trained": row["epochs_trained"],
        "runtime_seconds": row["runtime_seconds"],
    })
    return flat


def select_best(rows):
    # Purpose: Keeps the select_best helper isolated so later notebook cells can call it consistently.
    return max(rows, key=lambda row: (row["validation_macro_f1"], -row["best_validation_loss"]))


def run_controlled_trial(stage_name, varied_key, candidate_configs, results_path, histories_path, selected_path):
    # Purpose: Keeps the run_controlled_trial helper isolated so later notebook cells can call it consistently.
    rows = []
    histories = {}
    # Purpose: Iterates over this collection to build the next table, feature set, or experiment result
    # Purpose: consistently.
    for number, config in enumerate(candidate_configs, start=1):
        config = normalise_config(config)
        value = config[varied_key]
        print(f"{stage_name} candidate {number}/{len(candidate_configs)}:", value)
        row, history_df = train_and_evaluate_config(config, seed_from_config(config), f"{stage_name}_{number:02d}", verbose=2)
        rows.append(row)
        histories[str(value)] = history_df.to_dict(orient="records")
        # Purpose: Saves the generated artifacts so later notebooks, reports, or reruns can inspect the same
        # Purpose: outputs.
        pd.DataFrame([flat_result(item, {"stage": stage_name, "candidate": str(item["configuration"][varied_key])}) for item in rows]).to_csv(results_path, index=False)
        save_json(histories, histories_path)
    best = select_best(rows)
    selected = normalise_config(best["configuration"])
    selected.update({
        "selected_by_stage": stage_name,
        "selection_metric": "validation_macro_f1",
        "validation_macro_f1": best["validation_macro_f1"],
        "best_validation_loss": best["best_validation_loss"],
    })
    save_json(selected, selected_path)
    display(pd.read_csv(results_path).sort_values("validation_macro_f1", ascending=False))
    print("Saved selected config:", selected_path)

# %% [markdown]
# ## 4. Candidate Configurations

# %%
# Purpose: 4. Candidate Configurations.
VARIED_KEY = "optimizer"
candidate_values = ["adam", "rmsprop", "sgd_momentum"]
candidate_configs = []
# Purpose: Runs the controlled trial once for each candidate value of the tested hyperparameter.
for value in candidate_values:
    config = dict(base_config)
    config[VARIED_KEY] = value
    candidate_configs.append(normalise_config(config))
display(pd.DataFrame(candidate_configs))
# Out:
#   hidden_units activation     optimizer  dropout  learning_rate  batch_size  \
# 0    [128, 64]        elu          adam      0.2          0.001         128
# 1    [128, 64]        elu       rmsprop      0.2          0.001         128
# 2    [128, 64]        elu  sgd_momentum      0.2          0.001         128
#
#                   loss  threshold selected_by_stage     selection_metric  \
# 0  binary_crossentropy        0.5     02_activation  validation_macro_f1
# 1  binary_crossentropy        0.5     02_activation  validation_macro_f1
# 2  binary_crossentropy        0.5     02_activation  validation_macro_f1
#
#    validation_macro_f1  best_validation_loss
# 0             0.966686              0.077194
# 1             0.966686              0.077194
# 2             0.966686              0.077194

# %% [markdown]
# ## 5. Run or Load Results

# %%
# Purpose: Runs the trial when enabled, otherwise repairs or displays the selected config
# handoff from existing validation results without retraining.
RUN_OPTIMIZER_TRIAL = True
results_path = TABLES_DIR / "03_optimizer_results.csv"
histories_path = HISTORIES_DIR / "03_optimizer_histories.json"
selected_path = CONFIGS_DIR / "03_selected_config.json"
rebuild_results_path = first_existing_results_path([TABLES_DIR / "03_optimizer_results.csv"])

if RUN_OPTIMIZER_TRIAL:
    run_controlled_trial("03_optimizer", VARIED_KEY, candidate_configs, results_path, histories_path, selected_path)
elif selected_path.exists():
    selected_config = load_json(selected_path)
    print("Loaded selected config:", selected_path)
    if rebuild_results_path.exists():
        display(pd.read_csv(rebuild_results_path).sort_values(["validation_macro_f1", "best_validation_loss"], ascending=[False, True]))
    else:
        display(pd.DataFrame([selected_config]))
elif rebuild_results_path.exists():
    rebuild_selected_config_from_results(rebuild_results_path, selected_path, "03_optimizer")
    display(pd.read_csv(rebuild_results_path).sort_values(["validation_macro_f1", "best_validation_loss"], ascending=[False, True]))
else:
    print("RUN_OPTIMIZER_TRIAL is False. [RESULT TO BE INSERTED AFTER FINAL RUN]")
    print("Missing selected config:", selected_path)
    print("Missing result CSV:", rebuild_results_path)
# Out:
# 03_optimizer candidate 1/3: adam
# Epoch 1/50
# 71/71 - 5s - 72ms/step - accuracy: 0.8266 - loss: 0.3538 - val_accuracy: 0.8986 - val_loss: 0.2324
# Epoch 2/50
# 71/71 - 1s - 13ms/step - accuracy: 0.9056 - loss: 0.2149 - val_accuracy: 0.9269 - val_loss: 0.1774
# Epoch 3/50
# 71/71 - 1s - 19ms/step - accuracy: 0.9191 - loss: 0.1820 - val_accuracy: 0.9346 - val_loss: 0.1579
# Epoch 4/50
# 71/71 - 1s - 21ms/step - accuracy: 0.9301 - loss: 0.1582 - val_accuracy: 0.9408 - val_loss: 0.1439
# Epoch 5/50
# 71/71 - 3s - 43ms/step - accuracy: 0.9350 - loss: 0.1500 - val_accuracy: 0.9444 - val_loss: 0.1347
# Epoch 6/50
# 71/71 - 2s - 24ms/step - accuracy: 0.9418 - loss: 0.1368 - val_accuracy: 0.9480 - val_loss: 0.1324
# Epoch 7/50
# 71/71 - 3s - 40ms/step - accuracy: 0.9477 - loss: 0.1221 - val_accuracy: 0.9501 - val_loss: 0.1237
# Epoch 8/50
# 71/71 - 1s - 14ms/step - accuracy: 0.9513 - loss: 0.1164 - val_accuracy: 0.9557 - val_loss: 0.1132
# Epoch 9/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9522 - loss: 0.1121 - val_accuracy: 0.9542 - val_loss: 0.1130
# Epoch 10/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9565 - loss: 0.1040 - val_accuracy: 0.9537 - val_loss: 0.1096
# Epoch 11/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9581 - loss: 0.1024 - val_accuracy: 0.9557 - val_loss: 0.1072
# Epoch 12/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9587 - loss: 0.0952 - val_accuracy: 0.9567 - val_loss: 0.1068
# Epoch 13/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9599 - loss: 0.0958 - val_accuracy: 0.9604 - val_loss: 0.1012
# Epoch 14/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9650 - loss: 0.0840 - val_accuracy: 0.9593 - val_loss: 0.0994
# Epoch 15/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9643 - loss: 0.0834 - val_accuracy: 0.9619 - val_loss: 0.0963
# Epoch 16/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9668 - loss: 0.0809 - val_accuracy: 0.9624 - val_loss: 0.0930
# Epoch 17/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9678 - loss: 0.0785 - val_accuracy: 0.9634 - val_loss: 0.0953
# Epoch 18/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9702 - loss: 0.0744 - val_accuracy: 0.9619 - val_loss: 0.0950
# Epoch 19/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9710 - loss: 0.0717 - val_accuracy: 0.9665 - val_loss: 0.0917
# Epoch 20/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9702 - loss: 0.0728 - val_accuracy: 0.9660 - val_loss: 0.0931
# Epoch 21/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9726 - loss: 0.0681 - val_accuracy: 0.9645 - val_loss: 0.0929
# Epoch 22/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9737 - loss: 0.0659 - val_accuracy: 0.9660 - val_loss: 0.0887
# Epoch 23/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9737 - loss: 0.0664 - val_accuracy: 0.9645 - val_loss: 0.0890
# Epoch 24/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9736 - loss: 0.0614 - val_accuracy: 0.9686 - val_loss: 0.0843
# Epoch 25/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9765 - loss: 0.0600 - val_accuracy: 0.9676 - val_loss: 0.0933
# Epoch 26/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9764 - loss: 0.0598 - val_accuracy: 0.9670 - val_loss: 0.0911
# Epoch 27/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9779 - loss: 0.0542 - val_accuracy: 0.9665 - val_loss: 0.0864
# Epoch 28/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9760 - loss: 0.0576 - val_accuracy: 0.9670 - val_loss: 0.0927
# Epoch 29/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9795 - loss: 0.0547 - val_accuracy: 0.9660 - val_loss: 0.0836
# Epoch 30/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9790 - loss: 0.0495 - val_accuracy: 0.9624 - val_loss: 0.0936
# Epoch 31/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9760 - loss: 0.0577 - val_accuracy: 0.9722 - val_loss: 0.0821
# Epoch 32/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9801 - loss: 0.0501 - val_accuracy: 0.9722 - val_loss: 0.0838
# Epoch 33/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9777 - loss: 0.0534 - val_accuracy: 0.9691 - val_loss: 0.0844
# Epoch 34/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9801 - loss: 0.0478 - val_accuracy: 0.9686 - val_loss: 0.0883
# Epoch 35/50
# 71/71 - 1s - 7ms/step - accuracy: 0.9797 - loss: 0.0500 - val_accuracy: 0.9686 - val_loss: 0.0860
# Epoch 36/50
# 71/71 - 1s - 8ms/step - accuracy: 0.9797 - loss: 0.0495 - val_accuracy: 0.9681 - val_loss: 0.0911
# Epoch 37/50
# 71/71 - 1s - 8ms/step - accuracy: 0.9807 - loss: 0.0467 - val_accuracy: 0.9712 - val_loss: 0.0851
# Epoch 38/50
# 71/71 - 1s - 7ms/step - accuracy: 0.9795 - loss: 0.0482 - val_accuracy: 0.9748 - val_loss: 0.0809
# Epoch 39/50
# 71/71 - 0s - 7ms/step - accuracy: 0.9834 - loss: 0.0432 - val_accuracy: 0.9727 - val_loss: 0.0771
# Epoch 40/50
# 71/71 - 1s - 7ms/step - accuracy: 0.9821 - loss: 0.0435 - val_accuracy: 0.9717 - val_loss: 0.0846
# Epoch 41/50
# 71/71 - 1s - 9ms/step - accuracy: 0.9815 - loss: 0.0482 - val_accuracy: 0.9676 - val_loss: 0.0940
# Epoch 42/50
# 71/71 - 1s - 7ms/step - accuracy: 0.9844 - loss: 0.0416 - val_accuracy: 0.9737 - val_loss: 0.0837
# Epoch 43/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9823 - loss: 0.0413 - val_accuracy: 0.9676 - val_loss: 0.0902
# Epoch 44/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9837 - loss: 0.0383 - val_accuracy: 0.9712 - val_loss: 0.0845
# Epoch 45/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9862 - loss: 0.0367 - val_accuracy: 0.9737 - val_loss: 0.0804
# Epoch 46/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9834 - loss: 0.0400 - val_accuracy: 0.9691 - val_loss: 0.0842
# 03_optimizer candidate 2/3: rmsprop
# Epoch 1/50
# 71/71 - 1s - 19ms/step - accuracy: 0.8354 - loss: 0.3353 - val_accuracy: 0.8821 - val_loss: 0.2640
# Epoch 2/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9036 - loss: 0.2177 - val_accuracy: 0.9037 - val_loss: 0.2245
# Epoch 3/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9183 - loss: 0.1844 - val_accuracy: 0.9228 - val_loss: 0.1683
# Epoch 4/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9255 - loss: 0.1698 - val_accuracy: 0.9253 - val_loss: 0.1691
# Epoch 5/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9300 - loss: 0.1581 - val_accuracy: 0.9387 - val_loss: 0.1403
# Epoch 6/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9393 - loss: 0.1401 - val_accuracy: 0.9475 - val_loss: 0.1284
# Epoch 7/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9442 - loss: 0.1307 - val_accuracy: 0.9490 - val_loss: 0.1257
# Epoch 8/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9453 - loss: 0.1255 - val_accuracy: 0.9552 - val_loss: 0.1135
# Epoch 9/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9489 - loss: 0.1207 - val_accuracy: 0.9542 - val_loss: 0.1111
# Epoch 10/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9513 - loss: 0.1133 - val_accuracy: 0.9567 - val_loss: 0.1024
# Epoch 11/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9568 - loss: 0.1048 - val_accuracy: 0.9547 - val_loss: 0.1053
# Epoch 12/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9571 - loss: 0.1015 - val_accuracy: 0.9573 - val_loss: 0.1014
# Epoch 13/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9605 - loss: 0.0919 - val_accuracy: 0.9593 - val_loss: 0.0919
# Epoch 14/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9592 - loss: 0.0963 - val_accuracy: 0.9619 - val_loss: 0.0952
# Epoch 15/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9618 - loss: 0.0884 - val_accuracy: 0.9634 - val_loss: 0.0880
# Epoch 16/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9668 - loss: 0.0835 - val_accuracy: 0.9619 - val_loss: 0.0926
# Epoch 17/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9639 - loss: 0.0852 - val_accuracy: 0.9676 - val_loss: 0.0835
# Epoch 18/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9663 - loss: 0.0825 - val_accuracy: 0.9665 - val_loss: 0.0817
# Epoch 19/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9650 - loss: 0.0808 - val_accuracy: 0.9650 - val_loss: 0.0839
# Epoch 20/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9702 - loss: 0.0729 - val_accuracy: 0.9655 - val_loss: 0.0764
# Epoch 21/50
# 71/71 - 1s - 12ms/step - accuracy: 0.9704 - loss: 0.0738 - val_accuracy: 0.9670 - val_loss: 0.0751
# Epoch 22/50
# 71/71 - 1s - 8ms/step - accuracy: 0.9716 - loss: 0.0720 - val_accuracy: 0.9686 - val_loss: 0.0753
# Epoch 23/50
# 71/71 - 0s - 7ms/step - accuracy: 0.9735 - loss: 0.0665 - val_accuracy: 0.9691 - val_loss: 0.0782
# Epoch 24/50
# 71/71 - 1s - 10ms/step - accuracy: 0.9735 - loss: 0.0650 - val_accuracy: 0.9691 - val_loss: 0.0750
# Epoch 25/50
# 71/71 - 1s - 8ms/step - accuracy: 0.9731 - loss: 0.0650 - val_accuracy: 0.9650 - val_loss: 0.0765
# Epoch 26/50
# 71/71 - 1s - 8ms/step - accuracy: 0.9725 - loss: 0.0645 - val_accuracy: 0.9717 - val_loss: 0.0714
# Epoch 27/50
# 71/71 - 1s - 9ms/step - accuracy: 0.9749 - loss: 0.0623 - val_accuracy: 0.9670 - val_loss: 0.0716
# Epoch 28/50
# 71/71 - 0s - 6ms/step - accuracy: 0.9743 - loss: 0.0611 - val_accuracy: 0.9712 - val_loss: 0.0730
# Epoch 29/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9763 - loss: 0.0578 - val_accuracy: 0.9712 - val_loss: 0.0738
# Epoch 30/50
# 71/71 - 1s - 9ms/step - accuracy: 0.9762 - loss: 0.0596 - val_accuracy: 0.9717 - val_loss: 0.0717
# Epoch 31/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9768 - loss: 0.0572 - val_accuracy: 0.9743 - val_loss: 0.0680
# Epoch 32/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9783 - loss: 0.0558 - val_accuracy: 0.9706 - val_loss: 0.0714
# Epoch 33/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9781 - loss: 0.0539 - val_accuracy: 0.9743 - val_loss: 0.0702
# Epoch 34/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9785 - loss: 0.0538 - val_accuracy: 0.9737 - val_loss: 0.0712
# Epoch 35/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9792 - loss: 0.0496 - val_accuracy: 0.9768 - val_loss: 0.0644
# Epoch 36/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9810 - loss: 0.0511 - val_accuracy: 0.9737 - val_loss: 0.0691
# Epoch 37/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9790 - loss: 0.0508 - val_accuracy: 0.9737 - val_loss: 0.0657
# Epoch 38/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9811 - loss: 0.0498 - val_accuracy: 0.9717 - val_loss: 0.0744
# Epoch 39/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9788 - loss: 0.0516 - val_accuracy: 0.9743 - val_loss: 0.0717
# Epoch 40/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9819 - loss: 0.0444 - val_accuracy: 0.9773 - val_loss: 0.0673
# Epoch 41/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9811 - loss: 0.0458 - val_accuracy: 0.9748 - val_loss: 0.0669
# Epoch 42/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9822 - loss: 0.0444 - val_accuracy: 0.9758 - val_loss: 0.0644
# 03_optimizer candidate 3/3: sgd_momentum
# Epoch 1/50
# 71/71 - 1s - 18ms/step - accuracy: 0.6266 - loss: 0.6635 - val_accuracy: 0.7791 - val_loss: 0.4827
# Epoch 2/50
# 71/71 - 0s - 5ms/step - accuracy: 0.7795 - loss: 0.4542 - val_accuracy: 0.8321 - val_loss: 0.4067
# Epoch 3/50
# 71/71 - 0s - 5ms/step - accuracy: 0.8136 - loss: 0.3954 - val_accuracy: 0.8517 - val_loss: 0.3642
# Epoch 4/50
# 71/71 - 0s - 5ms/step - accuracy: 0.8285 - loss: 0.3636 - val_accuracy: 0.8599 - val_loss: 0.3364
# Epoch 5/50
# 71/71 - 0s - 5ms/step - accuracy: 0.8492 - loss: 0.3349 - val_accuracy: 0.8671 - val_loss: 0.3141
# Epoch 6/50
# 71/71 - 0s - 5ms/step - accuracy: 0.8546 - loss: 0.3161 - val_accuracy: 0.8702 - val_loss: 0.2973
# Epoch 7/50
# 71/71 - 0s - 5ms/step - accuracy: 0.8577 - loss: 0.3012 - val_accuracy: 0.8769 - val_loss: 0.2799
# Epoch 8/50
# 71/71 - 0s - 5ms/step - accuracy: 0.8716 - loss: 0.2867 - val_accuracy: 0.8774 - val_loss: 0.2705
# Epoch 9/50
# 71/71 - 0s - 5ms/step - accuracy: 0.8781 - loss: 0.2735 - val_accuracy: 0.8805 - val_loss: 0.2611
# Epoch 10/50
# 71/71 - 0s - 5ms/step - accuracy: 0.8758 - loss: 0.2697 - val_accuracy: 0.8867 - val_loss: 0.2532
# Epoch 11/50
# 71/71 - 1s - 8ms/step - accuracy: 0.8804 - loss: 0.2619 - val_accuracy: 0.8913 - val_loss: 0.2440
# Epoch 12/50
# 71/71 - 1s - 9ms/step - accuracy: 0.8863 - loss: 0.2541 - val_accuracy: 0.8908 - val_loss: 0.2385
# Epoch 13/50
# 71/71 - 0s - 7ms/step - accuracy: 0.8842 - loss: 0.2534 - val_accuracy: 0.8960 - val_loss: 0.2343
# Epoch 14/50
# 71/71 - 1s - 7ms/step - accuracy: 0.8922 - loss: 0.2455 - val_accuracy: 0.9006 - val_loss: 0.2261
# Epoch 15/50
# 71/71 - 1s - 8ms/step - accuracy: 0.8961 - loss: 0.2338 - val_accuracy: 0.9011 - val_loss: 0.2232
# Epoch 16/50
# 71/71 - 1s - 11ms/step - accuracy: 0.8991 - loss: 0.2306 - val_accuracy: 0.9053 - val_loss: 0.2187
# Epoch 17/50
# 71/71 - 0s - 7ms/step - accuracy: 0.8974 - loss: 0.2297 - val_accuracy: 0.9078 - val_loss: 0.2144
# Epoch 18/50
# 71/71 - 0s - 7ms/step - accuracy: 0.9009 - loss: 0.2225 - val_accuracy: 0.9099 - val_loss: 0.2109
# Epoch 19/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9019 - loss: 0.2171 - val_accuracy: 0.9094 - val_loss: 0.2075
# Epoch 20/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9031 - loss: 0.2159 - val_accuracy: 0.9104 - val_loss: 0.2046
# Epoch 21/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9033 - loss: 0.2140 - val_accuracy: 0.9125 - val_loss: 0.2006
# Epoch 22/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9065 - loss: 0.2118 - val_accuracy: 0.9135 - val_loss: 0.1985
# Epoch 23/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9106 - loss: 0.2036 - val_accuracy: 0.9166 - val_loss: 0.1945
# Epoch 24/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9107 - loss: 0.2044 - val_accuracy: 0.9176 - val_loss: 0.1924
# Epoch 25/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9106 - loss: 0.2050 - val_accuracy: 0.9156 - val_loss: 0.1919
# Epoch 26/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9107 - loss: 0.2020 - val_accuracy: 0.9181 - val_loss: 0.1887
# Epoch 27/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9129 - loss: 0.1972 - val_accuracy: 0.9202 - val_loss: 0.1873
# Epoch 28/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9107 - loss: 0.1951 - val_accuracy: 0.9207 - val_loss: 0.1836
# Epoch 29/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9132 - loss: 0.1960 - val_accuracy: 0.9217 - val_loss: 0.1817
# Epoch 30/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9182 - loss: 0.1859 - val_accuracy: 0.9233 - val_loss: 0.1790
# Epoch 31/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9193 - loss: 0.1856 - val_accuracy: 0.9233 - val_loss: 0.1792
# Epoch 32/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9152 - loss: 0.1886 - val_accuracy: 0.9233 - val_loss: 0.1777
# Epoch 33/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9171 - loss: 0.1878 - val_accuracy: 0.9253 - val_loss: 0.1746
# Epoch 34/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9213 - loss: 0.1826 - val_accuracy: 0.9253 - val_loss: 0.1721
# Epoch 35/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9184 - loss: 0.1832 - val_accuracy: 0.9264 - val_loss: 0.1719
# Epoch 36/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9198 - loss: 0.1798 - val_accuracy: 0.9258 - val_loss: 0.1719
# Epoch 37/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9233 - loss: 0.1783 - val_accuracy: 0.9264 - val_loss: 0.1676
# Epoch 38/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9224 - loss: 0.1764 - val_accuracy: 0.9274 - val_loss: 0.1694
# Epoch 39/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9212 - loss: 0.1795 - val_accuracy: 0.9269 - val_loss: 0.1675
# Epoch 40/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9240 - loss: 0.1719 - val_accuracy: 0.9279 - val_loss: 0.1652
# Epoch 41/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9220 - loss: 0.1731 - val_accuracy: 0.9279 - val_loss: 0.1648
# Epoch 42/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9236 - loss: 0.1701 - val_accuracy: 0.9310 - val_loss: 0.1618
# Epoch 43/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9278 - loss: 0.1686 - val_accuracy: 0.9341 - val_loss: 0.1603
# Epoch 44/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9246 - loss: 0.1701 - val_accuracy: 0.9315 - val_loss: 0.1625
# Epoch 45/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9259 - loss: 0.1704 - val_accuracy: 0.9336 - val_loss: 0.1611
# Epoch 46/50
# 71/71 - 0s - 6ms/step - accuracy: 0.9248 - loss: 0.1675 - val_accuracy: 0.9336 - val_loss: 0.1581
# Epoch 47/50
# 71/71 - 1s - 8ms/step - accuracy: 0.9255 - loss: 0.1675 - val_accuracy: 0.9331 - val_loss: 0.1587
# Epoch 48/50
# 71/71 - 1s - 7ms/step - accuracy: 0.9305 - loss: 0.1607 - val_accuracy: 0.9320 - val_loss: 0.1576
# Epoch 49/50
# 71/71 - 1s - 11ms/step - accuracy: 0.9299 - loss: 0.1619 - val_accuracy: 0.9341 - val_loss: 0.1573
# Epoch 50/50
# 71/71 - 1s - 17ms/step - accuracy: 0.9320 - loss: 0.1592 - val_accuracy: 0.9346 - val_loss: 0.1542
#           stage     candidate hidden_units activation     optimizer  dropout  \
# 1  03_optimizer       rmsprop    [128, 64]        elu       rmsprop      0.2
# 0  03_optimizer          adam    [128, 64]        elu          adam      0.2
# 2  03_optimizer  sgd_momentum    [128, 64]        elu  sgd_momentum      0.2
#
#    learning_rate  batch_size                 loss  threshold  ...        seed  \
# 1          0.001         128  binary_crossentropy        0.5  ...  2090981247
# 0          0.001         128  binary_crossentropy        0.5  ...   617433146
# 2          0.001         128  binary_crossentropy        0.5  ...  1320627335
#
#   validation_macro_f1  validation_binary_f1_synthetic  validation_accuracy  \
# 1            0.973099                        0.983114             0.976828
# 0            0.968457                        0.980038             0.972709
# 2            0.926774                        0.950718             0.934604
#
#    validation_precision_synthetic  validation_recall_synthetic  \
# 1                        0.990923                     0.975428
# 0                        0.991616                     0.968727
# 2                        0.992707                     0.912137
#
#    best_validation_loss  best_epoch  epochs_trained  runtime_seconds
# 1              0.064414          42              42        17.140474
# 0              0.077113          39              46        32.224538
# 2              0.154163          50              50        21.590923
#
# [3 rows x 22 columns]
# Saved selected config: /content/drive/MyDrive/Colab Notebooks/Education/INM701/outputs/mlp/configs/03_selected_config.json

# %% [markdown]
# ## 6. Checks

# %%
# Purpose: Runs this notebook step and prints or saves the resulting intermediate output for review.
display(pd.DataFrame([("varies_only", "optimizer"), ("validation_macro_f1_primary", True), ("test_metrics_computed", False)], columns=["check", "value"]))
# Out:
#                          check      value
# 0                  varies_only  optimizer
# 1  validation_macro_f1_primary       True
# 2        test_metrics_computed      False
