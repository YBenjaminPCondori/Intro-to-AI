# %% [markdown]
# # 06 MLP Learning Rate and Batch Size Trial
#
# Two controlled sub-stages: learning rate first while batch size is fixed, then batch size using the selected learning rate.

# %% [markdown]
# ## 1. Package Setup

# %%
# Purpose: Package installs are documented but not run automatically during this static refactor.
# %pip install tensorflow scikit-learn pandas numpy matplotlib seaborn joblib soundfile librosa

# %% [markdown]
# ## 2. Load Cache and Architecture Config

# %%
import os
from pathlib import Path

# Purpose: Mounts Google Drive when this notebook is running in Google Colab.
# Why this exists: the project files, cached MFCC features, manifests, models, figures,
# and metric outputs live in Google Drive during Colab runs. The /content/drive path
# only represents the real MyDrive files after drive.mount("/content/drive") succeeds.
# Important: the project root should be the folder that contains Data, Model Variants,
# and outputs. For this project, that expected Colab folder is the INM701 folder below.
COLAB_DRIVE_MOUNT_POINT = Path("/content/drive")
EXPECTED_COLAB_PROJECT_ROOT = Path("/content/drive/MyDrive/Colab Notebooks/Education/INM701")

try:
    from google.colab import drive

    drive.mount(str(COLAB_DRIVE_MOUNT_POINT))
    print("Google Colab detected. Google Drive mounted.")

    current_project_root = os.environ.get("INTRO_AI_PROJECT_ROOT")
    current_data_dir_exists = bool(current_project_root) and (Path(current_project_root) / "Data").exists()
    expected_data_dir_exists = (EXPECTED_COLAB_PROJECT_ROOT / "Data").exists()

    # Purpose: Keep a valid user-provided project root, but repair stale runtime state
    # if a previous cell pointed INTRO_AI_PROJECT_ROOT somewhere that does not contain Data.
    if current_data_dir_exists:
        print("INTRO_AI_PROJECT_ROOT already points to a folder with Data, so it was kept.")
    elif expected_data_dir_exists:
        os.environ["INTRO_AI_PROJECT_ROOT"] = str(EXPECTED_COLAB_PROJECT_ROOT)
        print("INTRO_AI_PROJECT_ROOT set to the expected INM701 project folder.")
    elif not current_project_root:
        os.environ["INTRO_AI_PROJECT_ROOT"] = str(EXPECTED_COLAB_PROJECT_ROOT)
        print("INTRO_AI_PROJECT_ROOT was not set, so it now points to the expected INM701 folder.")
    else:
        print("INTRO_AI_PROJECT_ROOT was kept, but Data was not found there or in the expected INM701 folder.")
except Exception as exc:
    print("Google Colab Drive mount skipped. This is expected outside Colab.")
    print("Mount skip reason:", exc)

active_project_root = os.environ.get("INTRO_AI_PROJECT_ROOT", "not set")
print("INTRO_AI_PROJECT_ROOT:", active_project_root)
if active_project_root != "not set":
    active_project_root = Path(active_project_root)
    print("Project root exists:", active_project_root.exists())
    print("Expected Data folder:", active_project_root / "Data")
    print("Data folder exists:", (active_project_root / "Data").exists())
# Out:
# Mounted at /content/drive
# Google Colab detected. Google Drive mounted.
# INTRO_AI_PROJECT_ROOT set to the expected INM701 project folder.
# INTRO_AI_PROJECT_ROOT: /content/drive/MyDrive/Colab Notebooks/Education/INM701
# Project root exists: True
# Expected Data folder: /content/drive/MyDrive/Colab Notebooks/Education/INM701/Data
# Data folder exists: True

# %%
# Purpose: Later notebooks load the one MLP-ready cache made by notebook 00. They do not
# rescan folders, regenerate splits, extract MFCCs, fit scalers, or recalculate class weights.
import hashlib
import json
import os
import random
import time
from itertools import product
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score, precision_score, recall_score
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.models import Sequential

try:
    from IPython.display import display
except Exception:
    display = print

RANDOM_STATE = 42
MAX_EPOCHS = 50
EARLY_STOP_PATIENCE = 7
EARLY_STOP_MIN_DELTA = 1e-4
THRESHOLD = 0.5
CLASS_NAMES = {0: "bona_fide", 1: "synthetic"}
CONFIRMATION_SEEDS = [42, 123, 2026]


def resolve_project_root():
    # Purpose: default path.
    explicit = os.environ.get("INTRO_AI_PROJECT_ROOT")
    if explicit:
        return Path(explicit).expanduser().resolve()
    cwd = Path.cwd().resolve()
    # Purpose: Runs each candidate configuration under the same data split for a fair validation comparison.
    for candidate in [cwd, *cwd.parents]:
        if (candidate / "Model Variants").exists():
            return candidate
        if (candidate / "Training" / "Model Variants").exists():
            return candidate / "Training"
    return Path("/content/drive/MyDrive/Colab Notebooks/Education/INM701")


# Purpose: Centralizes filesystem paths so dataset inputs, caches, figures, models, and metric tables are easy
# Purpose: to trace.
PROJECT_ROOT = resolve_project_root()
OUTPUT_DIR = PROJECT_ROOT / "outputs" / "mlp"
CACHE_DIR = OUTPUT_DIR / "cache"
MANIFESTS_DIR = OUTPUT_DIR / "manifests"
CONFIGS_DIR = OUTPUT_DIR / "configs"
TABLES_DIR = OUTPUT_DIR / "tables"
HISTORIES_DIR = OUTPUT_DIR / "histories"
METRICS_DIR = OUTPUT_DIR / "metrics"
FIGURES_DIR = OUTPUT_DIR / "figures"
MODELS_DIR = OUTPUT_DIR / "models"
PILOT_LEGACY_DIR = OUTPUT_DIR / "pilot_legacy"
# Purpose: Creates each output directory before later cells try to save tables, figures, or models.
for directory in [OUTPUT_DIR, CACHE_DIR, MANIFESTS_DIR, CONFIGS_DIR, TABLES_DIR, HISTORIES_DIR, METRICS_DIR, FIGURES_DIR, MODELS_DIR, PILOT_LEGACY_DIR]:
    directory.mkdir(parents=True, exist_ok=True)


def require_file(path):
    # Purpose: Stops the notebook early with a clear message when a required upstream artifact is missing.
    path = Path(path)
    if not path.exists():
        raise FileNotFoundError(f"Required file not found: {path}")
    return path


def load_json(path):
    # Purpose: Keeps the load_json helper isolated so later notebook cells can call it consistently.
    with open(require_file(path), "r", encoding="utf-8") as f:
        return json.load(f)


def save_json(payload, path):
    # Purpose: Keeps the save_json helper isolated so later notebook cells can call it consistently.
    with open(path, "w", encoding="utf-8") as f:
        json.dump(payload, f, indent=2)




def normalise_handoff_config(config):
    # Purpose: Normalises a config loaded from a JSON string or CSV row before it is reused
    # by the next notebook in the MLP chain. This keeps rebuilt handoff files compatible
    # with configs produced by a full training run.
    normalised = dict(config)
    hidden_units = normalised.get("hidden_units", [])
    if isinstance(hidden_units, str):
        hidden_units = json.loads(hidden_units)
    normalised["hidden_units"] = [int(value) for value in hidden_units]
    normalised["activation"] = str(normalised["activation"])
    normalised["optimizer"] = str(normalised["optimizer"])
    normalised["dropout"] = float(normalised["dropout"])
    normalised["learning_rate"] = float(normalised["learning_rate"])
    normalised["batch_size"] = int(normalised["batch_size"])
    normalised["loss"] = normalised.get("loss", "binary_crossentropy")
    normalised["threshold"] = float(normalised.get("threshold", THRESHOLD))
    return normalised


def first_existing_results_path(candidate_paths):
    # Purpose: Supports the normal result filename and any documented alias without changing
    # where the notebook saves new results. The first existing CSV is used for rebuilding.
    paths = [Path(path) for path in candidate_paths]
    for path in paths:
        if path.exists():
            return path
    return paths[0]


def rebuild_selected_config_from_results(results_path, selected_path, selected_by_stage):
    # Purpose: Rebuilds a missing selected_config JSON from an existing validation-results
    # CSV. This avoids rerunning training just to recreate the JSON handoff file.
    results_path = Path(results_path)
    selected_path = Path(selected_path)
    if not results_path.exists():
        print("Cannot rebuild selected config because result CSV is missing:", results_path)
        return None

    results_df = pd.read_csv(results_path)
    required_columns = {"config_json", "validation_macro_f1", "best_validation_loss"}
    missing_columns = required_columns - set(results_df.columns)
    if missing_columns:
        raise RuntimeError(f"Cannot rebuild {selected_path.name}; missing columns in {results_path.name}: {sorted(missing_columns)}")
    if results_df.empty:
        raise RuntimeError(f"Cannot rebuild {selected_path.name}; result CSV is empty: {results_path}")

    best_row = results_df.sort_values(["validation_macro_f1", "best_validation_loss"], ascending=[False, True]).iloc[0]
    selected = normalise_handoff_config(json.loads(best_row["config_json"]))
    selected.update({
        "selected_by_stage": selected_by_stage,
        "selection_metric": "validation_macro_f1",
        "validation_macro_f1": float(best_row["validation_macro_f1"]),
        "best_validation_loss": float(best_row["best_validation_loss"]),
        "rebuilt_from_results_csv": str(results_path),
    })
    save_json(selected, selected_path)
    print("Rebuilt selected config from existing results:", selected_path)
    return selected


def ensure_selected_config_from_results(selected_path, results_path, selected_by_stage):
    # Purpose: Repairs a missing previous-stage config before this notebook tries to load it.
    # If neither the JSON nor the CSV exists, the later require_file/load_json call will still
    # stop with a clear missing-artifact error.
    selected_path = Path(selected_path)
    results_path = Path(results_path)
    if selected_path.exists():
        return load_json(selected_path)
    if results_path.exists():
        return rebuild_selected_config_from_results(results_path, selected_path, selected_by_stage)
    print("Selected config missing:", selected_path)
    print("Result CSV also missing, so config cannot be rebuilt:", results_path)
    return None


def load_class_weights():
    # Purpose: Keeps the load_class_weights helper isolated so later notebook cells can call it consistently.
    payload = load_json(CONFIGS_DIR / "class_weights.json")
    weights = payload.get("class_weights", payload)
    return {int(label): float(weight) for label, weight in weights.items()}


for required in [
    CACHE_DIR / "X_train.npy",
    CACHE_DIR / "y_train.npy",
    CACHE_DIR / "train_metadata.csv",
    CACHE_DIR / "X_validation.npy",
    CACHE_DIR / "y_validation.npy",
    CACHE_DIR / "validation_metadata.csv",
    CACHE_DIR / "feature_config.json",
    CONFIGS_DIR / "class_weights.json",
]:
    require_file(required)

X_train = np.load(CACHE_DIR / "X_train.npy")
y_train = np.load(CACHE_DIR / "y_train.npy")
train_metadata = pd.read_csv(CACHE_DIR / "train_metadata.csv")
X_validation = np.load(CACHE_DIR / "X_validation.npy")
y_validation = np.load(CACHE_DIR / "y_validation.npy")
validation_metadata = pd.read_csv(CACHE_DIR / "validation_metadata.csv")
feature_config = load_json(CACHE_DIR / "feature_config.json")
CLASS_WEIGHTS = load_class_weights()

if len(X_train) != len(y_train) or len(X_train) != len(train_metadata):
    raise RuntimeError("Training cache arrays, labels and metadata are not row-aligned.")
if len(X_validation) != len(y_validation) or len(X_validation) != len(validation_metadata):
    raise RuntimeError("Validation cache arrays, labels and metadata are not row-aligned.")

print("Loaded MLP cache:", CACHE_DIR)
print("X_train shape:", X_train.shape)
print("X_validation shape:", X_validation.shape)

# Purpose: Rebuild the previous selected config from its result CSV if the JSON handoff file is missing.
ensure_selected_config_from_results(
    CONFIGS_DIR / "05_selected_config.json",
    first_existing_results_path([TABLES_DIR / "05_architecture_results.csv", TABLES_DIR / "05_hidden_units_results.csv"]),
    "05_hidden_units",
)
base_config = load_json(CONFIGS_DIR / "05_selected_config.json")
# Out:
# Loaded MLP cache: /content/drive/MyDrive/Colab Notebooks/Education/INM701/outputs/mlp/cache
# X_train shape: (9060, 80)
# X_validation shape: (1942, 80)

# %% [markdown]
# ## 3. Keras Utilities

# %%
# Purpose: Shared beginner-readable Keras utilities for validation-only model selection.
def normalise_config(config):
    # Purpose: Keeps the normalise_config helper isolated so later notebook cells can call it consistently.
    normalised = dict(config)
    normalised["hidden_units"] = [int(value) for value in normalised["hidden_units"]]
    normalised["activation"] = str(normalised["activation"])
    normalised["optimizer"] = str(normalised["optimizer"])
    normalised["dropout"] = float(normalised["dropout"])
    normalised["learning_rate"] = float(normalised["learning_rate"])
    normalised["batch_size"] = int(normalised["batch_size"])
    normalised["loss"] = normalised.get("loss", "binary_crossentropy")
    normalised["threshold"] = float(normalised.get("threshold", THRESHOLD))
    return normalised


def config_json(config):
    # Purpose: Keeps the config_json helper isolated so later notebook cells can call it consistently.
    return json.dumps(normalise_config(config), sort_keys=True)


def config_key(config):
    # Purpose: Keeps the config_key helper isolated so later notebook cells can call it consistently.
    return hashlib.sha256(config_json(config).encode("utf-8")).hexdigest()


def seed_from_config(config, base_seed=RANDOM_STATE):
    # Purpose: Keeps the seed_from_config helper isolated so later notebook cells can call it consistently.
    digest = hashlib.sha256(f"{base_seed}:{config_json(config)}".encode("utf-8")).hexdigest()
    return int(digest[:8], 16) % (2**31 - 1)


def set_global_seed(seed):
    # Purpose: Keeps the set_global_seed helper isolated so later notebook cells can call it consistently.
    random.seed(int(seed))
    np.random.seed(int(seed))
    tf.keras.utils.set_random_seed(int(seed))
    os.environ["PYTHONHASHSEED"] = str(int(seed))


def make_optimizer(config):
    # Purpose: Keeps the make_optimizer helper isolated so later notebook cells can call it consistently.
    name = str(config["optimizer"]).lower()
    lr = float(config["learning_rate"])
    if name == "adam":
        return tf.keras.optimizers.Adam(learning_rate=lr)
    if name == "rmsprop":
        return tf.keras.optimizers.RMSprop(learning_rate=lr)
    if name in ["sgd", "sgd_momentum"]:
        return tf.keras.optimizers.SGD(learning_rate=lr, momentum=0.9)
    raise ValueError(f"Unsupported optimizer: {config['optimizer']}")


def build_mlp_model(config, input_dim):
    # Purpose: Constructs the MLP architecture for the current experiment configuration.
    config = normalise_config(config)
    model = Sequential()
    model.add(Input(shape=(input_dim,)))
    # Purpose: Iterates over this collection to build the next table, feature set, or experiment result
    # Purpose: consistently.
    for units in config["hidden_units"]:
        model.add(Dense(units, activation=config["activation"]))
        if config["dropout"] > 0:
            model.add(Dropout(config["dropout"]))
    model.add(Dense(1, activation="sigmoid"))
    model.compile(loss=config["loss"], optimizer=make_optimizer(config), metrics=["accuracy"])
    return model


def train_and_evaluate_config(config, run_seed, run_name, verbose=0):
    # Purpose: consistently.
    config = normalise_config(config)
    tf.keras.backend.clear_session()
    set_global_seed(run_seed)
    model = build_mlp_model(config, X_train.shape[1])
    callbacks = [
        tf.keras.callbacks.EarlyStopping(
            monitor="val_loss",
            patience=EARLY_STOP_PATIENCE,
            min_delta=EARLY_STOP_MIN_DELTA,
            restore_best_weights=True,
        )
    ]
    start = time.perf_counter()
    history = model.fit(
        X_train,
        y_train,
        validation_data=(X_validation, y_validation),
        epochs=MAX_EPOCHS,
        batch_size=config["batch_size"],
        class_weight=CLASS_WEIGHTS,
        callbacks=callbacks,
        verbose=verbose,
    )
    runtime = time.perf_counter() - start
    probability = model.predict(X_validation, batch_size=config["batch_size"], verbose=0).ravel()
    pred = (probability >= config["threshold"]).astype(int)
    row = {
        "configuration": config,
        "config_json": config_json(config),
        "config_key": config_key(config),
        "seed": int(run_seed),
        "validation_macro_f1": float(f1_score(y_validation, pred, average="macro", zero_division=0)),
        "validation_binary_f1_synthetic": float(f1_score(y_validation, pred, pos_label=1, zero_division=0)),
        "validation_accuracy": float(accuracy_score(y_validation, pred)),
        "validation_precision_synthetic": float(precision_score(y_validation, pred, pos_label=1, zero_division=0)),
        "validation_recall_synthetic": float(recall_score(y_validation, pred, pos_label=1, zero_division=0)),
        "best_validation_loss": float(np.min(history.history["val_loss"])),
        "best_epoch": int(np.argmin(history.history["val_loss"]) + 1),
        "epochs_trained": int(len(history.history["loss"])),
        "runtime_seconds": float(runtime),
        "run_name": run_name,
    }
    history_df = pd.DataFrame(history.history)
    history_df.insert(0, "epoch", np.arange(1, len(history_df) + 1))
    return row, history_df


def flat_result(row, extra=None):
    # Purpose: Keeps the flat_result helper isolated so later notebook cells can call it consistently.
    extra = extra or {}
    config = normalise_config(row["configuration"])
    flat = dict(extra)
    flat.update({
        "hidden_units": json.dumps(config["hidden_units"]),
        "activation": config["activation"],
        "optimizer": config["optimizer"],
        "dropout": config["dropout"],
        "learning_rate": config["learning_rate"],
        "batch_size": config["batch_size"],
        "loss": config["loss"],
        "threshold": config["threshold"],
        "config_json": row["config_json"],
        "config_key": row["config_key"],
        "seed": row["seed"],
        "validation_macro_f1": row["validation_macro_f1"],
        "validation_binary_f1_synthetic": row["validation_binary_f1_synthetic"],
        "validation_accuracy": row["validation_accuracy"],
        "validation_precision_synthetic": row["validation_precision_synthetic"],
        "validation_recall_synthetic": row["validation_recall_synthetic"],
        "best_validation_loss": row["best_validation_loss"],
        "best_epoch": row["best_epoch"],
        "epochs_trained": row["epochs_trained"],
        "runtime_seconds": row["runtime_seconds"],
    })
    return flat


def select_best(rows):
    # Purpose: Keeps the select_best helper isolated so later notebook cells can call it consistently.
    return max(rows, key=lambda row: (row["validation_macro_f1"], -row["best_validation_loss"]))

# %% [markdown]
# ## 4. Run or Load Two-Stage Trial

# %%
# Purpose: Runs the two-stage learning-rate and batch-size trial when enabled. If the
# selected JSON handoff is missing but the batch-size results already exist, rebuild it
# from validation evidence without retraining.
RUN_LR_BATCH_TRIAL = True
learning_rate_candidates = [0.0003, 0.001, 0.003]
batch_size_candidates = [64, 128, 256]
lr_results_path = TABLES_DIR / "06_learning_rate_results.csv"
batch_results_path = TABLES_DIR / "06_batch_size_results.csv"
lr_histories_path = HISTORIES_DIR / "06_learning_rate_histories.json"
batch_histories_path = HISTORIES_DIR / "06_batch_size_histories.json"
selected_path = CONFIGS_DIR / "06_selected_config.json"

if RUN_LR_BATCH_TRIAL:
    lr_rows = []
    lr_histories = {}
    # Purpose: Tries each learning-rate candidate while holding the previous selected config fixed.
    for lr in learning_rate_candidates:
        config = dict(base_config)
        config["learning_rate"] = lr
        row, history_df = train_and_evaluate_config(config, seed_from_config(config), f"06_lr_{lr}", verbose=2)
        lr_rows.append(row)
        lr_histories[str(lr)] = history_df.to_dict(orient="records")
    pd.DataFrame([flat_result(row, {"stage": "06_learning_rate", "candidate": row["configuration"]["learning_rate"]}) for row in lr_rows]).to_csv(lr_results_path, index=False)
    save_json(lr_histories, lr_histories_path)
    lr_best = select_best(lr_rows)

    batch_rows = []
    batch_histories = {}
    # Purpose: Tries each batch size after selecting the best learning rate from the first stage.
    for batch_size in batch_size_candidates:
        config = dict(lr_best["configuration"])
        config["batch_size"] = batch_size
        row, history_df = train_and_evaluate_config(config, seed_from_config(config), f"06_batch_{batch_size}", verbose=2)
        batch_rows.append(row)
        batch_histories[str(batch_size)] = history_df.to_dict(orient="records")
    pd.DataFrame([flat_result(row, {"stage": "06_batch_size", "candidate": row["configuration"]["batch_size"]}) for row in batch_rows]).to_csv(batch_results_path, index=False)
    save_json(batch_histories, batch_histories_path)

    best = select_best(batch_rows)
    selected = normalise_config(best["configuration"])
    selected.update({"selected_by_stage": "06_learning_rate_batch_size", "selection_metric": "validation_macro_f1", "validation_macro_f1": best["validation_macro_f1"], "best_validation_loss": best["best_validation_loss"]})
    save_json(selected, selected_path)
elif selected_path.exists():
    selected_config = load_json(selected_path)
    print("Loaded selected config:", selected_path)
    if lr_results_path.exists():
        display(pd.read_csv(lr_results_path).sort_values(["validation_macro_f1", "best_validation_loss"], ascending=[False, True]))
    if batch_results_path.exists():
        display(pd.read_csv(batch_results_path).sort_values(["validation_macro_f1", "best_validation_loss"], ascending=[False, True]))
    if not lr_results_path.exists() and not batch_results_path.exists():
        display(pd.DataFrame([selected_config]))
elif batch_results_path.exists():
    rebuild_selected_config_from_results(batch_results_path, selected_path, "06_learning_rate_batch_size")
    if lr_results_path.exists():
        display(pd.read_csv(lr_results_path).sort_values(["validation_macro_f1", "best_validation_loss"], ascending=[False, True]))
    display(pd.read_csv(batch_results_path).sort_values(["validation_macro_f1", "best_validation_loss"], ascending=[False, True]))
else:
    print("RUN_LR_BATCH_TRIAL is False. [RESULT TO BE INSERTED AFTER FINAL RUN]")
    print("Missing selected config:", selected_path)
    print("Missing batch-size result CSV:", batch_results_path)
# Out:
# Epoch 1/50
# 71/71 - 2s - 31ms/step - accuracy: 0.7969 - loss: 0.4209 - val_accuracy: 0.8538 - val_loss: 0.3400
# Epoch 2/50
# 71/71 - 1s - 7ms/step - accuracy: 0.8762 - loss: 0.2755 - val_accuracy: 0.8826 - val_loss: 0.2560
# Epoch 3/50
# 71/71 - 1s - 8ms/step - accuracy: 0.8985 - loss: 0.2258 - val_accuracy: 0.9068 - val_loss: 0.2175
# Epoch 4/50
# 71/71 - 0s - 6ms/step - accuracy: 0.9116 - loss: 0.1983 - val_accuracy: 0.9156 - val_loss: 0.1944
# Epoch 5/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9220 - loss: 0.1795 - val_accuracy: 0.9289 - val_loss: 0.1773
# Epoch 6/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9290 - loss: 0.1666 - val_accuracy: 0.9289 - val_loss: 0.1741
# Epoch 7/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9332 - loss: 0.1569 - val_accuracy: 0.9341 - val_loss: 0.1594
# Epoch 8/50
# 71/71 - 1s - 9ms/step - accuracy: 0.9352 - loss: 0.1486 - val_accuracy: 0.9346 - val_loss: 0.1545
# Epoch 9/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9380 - loss: 0.1411 - val_accuracy: 0.9387 - val_loss: 0.1461
# Epoch 10/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9408 - loss: 0.1336 - val_accuracy: 0.9398 - val_loss: 0.1437
# Epoch 11/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9460 - loss: 0.1259 - val_accuracy: 0.9387 - val_loss: 0.1402
# Epoch 12/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9459 - loss: 0.1280 - val_accuracy: 0.9434 - val_loss: 0.1402
# Epoch 13/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9471 - loss: 0.1199 - val_accuracy: 0.9485 - val_loss: 0.1292
# Epoch 14/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9502 - loss: 0.1177 - val_accuracy: 0.9495 - val_loss: 0.1265
# Epoch 15/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9513 - loss: 0.1116 - val_accuracy: 0.9516 - val_loss: 0.1240
# Epoch 16/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9538 - loss: 0.1105 - val_accuracy: 0.9516 - val_loss: 0.1216
# Epoch 17/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9551 - loss: 0.1076 - val_accuracy: 0.9531 - val_loss: 0.1237
# Epoch 18/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9553 - loss: 0.1039 - val_accuracy: 0.9531 - val_loss: 0.1227
# Epoch 19/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9567 - loss: 0.1033 - val_accuracy: 0.9542 - val_loss: 0.1208
# Epoch 20/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9596 - loss: 0.0995 - val_accuracy: 0.9537 - val_loss: 0.1204
# Epoch 21/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9575 - loss: 0.0975 - val_accuracy: 0.9542 - val_loss: 0.1206
# Epoch 22/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9581 - loss: 0.0980 - val_accuracy: 0.9562 - val_loss: 0.1152
# Epoch 23/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9604 - loss: 0.0922 - val_accuracy: 0.9562 - val_loss: 0.1158
# Epoch 24/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9596 - loss: 0.0909 - val_accuracy: 0.9562 - val_loss: 0.1157
# Epoch 25/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9617 - loss: 0.0905 - val_accuracy: 0.9578 - val_loss: 0.1121
# Epoch 26/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9645 - loss: 0.0870 - val_accuracy: 0.9588 - val_loss: 0.1107
# Epoch 27/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9643 - loss: 0.0887 - val_accuracy: 0.9562 - val_loss: 0.1157
# Epoch 28/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9652 - loss: 0.0832 - val_accuracy: 0.9562 - val_loss: 0.1183
# Epoch 29/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9662 - loss: 0.0819 - val_accuracy: 0.9593 - val_loss: 0.1049
# Epoch 30/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9649 - loss: 0.0821 - val_accuracy: 0.9593 - val_loss: 0.1039
# Epoch 31/50
# 71/71 - 1s - 8ms/step - accuracy: 0.9675 - loss: 0.0796 - val_accuracy: 0.9562 - val_loss: 0.1087
# Epoch 32/50
# 71/71 - 0s - 6ms/step - accuracy: 0.9677 - loss: 0.0800 - val_accuracy: 0.9578 - val_loss: 0.1119
# Epoch 33/50
# 71/71 - 0s - 6ms/step - accuracy: 0.9678 - loss: 0.0777 - val_accuracy: 0.9578 - val_loss: 0.1055
# Epoch 34/50
# 71/71 - 0s - 7ms/step - accuracy: 0.9699 - loss: 0.0728 - val_accuracy: 0.9598 - val_loss: 0.1016
# Epoch 35/50
# 71/71 - 1s - 10ms/step - accuracy: 0.9696 - loss: 0.0746 - val_accuracy: 0.9562 - val_loss: 0.1043
# Epoch 36/50
# 71/71 - 1s - 9ms/step - accuracy: 0.9710 - loss: 0.0719 - val_accuracy: 0.9583 - val_loss: 0.1046
# Epoch 37/50
# 71/71 - 1s - 8ms/step - accuracy: 0.9700 - loss: 0.0722 - val_accuracy: 0.9552 - val_loss: 0.1082
# Epoch 38/50
# 71/71 - 1s - 9ms/step - accuracy: 0.9724 - loss: 0.0686 - val_accuracy: 0.9598 - val_loss: 0.0992
# Epoch 39/50
# 71/71 - 1s - 8ms/step - accuracy: 0.9720 - loss: 0.0696 - val_accuracy: 0.9604 - val_loss: 0.0999
# Epoch 40/50
# 71/71 - 0s - 7ms/step - accuracy: 0.9714 - loss: 0.0682 - val_accuracy: 0.9604 - val_loss: 0.1012
# Epoch 41/50
# 71/71 - 0s - 7ms/step - accuracy: 0.9702 - loss: 0.0692 - val_accuracy: 0.9562 - val_loss: 0.1060
# Epoch 42/50
# 71/71 - 1s - 9ms/step - accuracy: 0.9730 - loss: 0.0653 - val_accuracy: 0.9588 - val_loss: 0.0974
# Epoch 43/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9745 - loss: 0.0654 - val_accuracy: 0.9588 - val_loss: 0.0994
# Epoch 44/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9760 - loss: 0.0632 - val_accuracy: 0.9583 - val_loss: 0.1024
# Epoch 45/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9733 - loss: 0.0648 - val_accuracy: 0.9614 - val_loss: 0.0954
# Epoch 46/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9763 - loss: 0.0606 - val_accuracy: 0.9609 - val_loss: 0.0984
# Epoch 47/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9743 - loss: 0.0626 - val_accuracy: 0.9588 - val_loss: 0.1040
# Epoch 48/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9753 - loss: 0.0622 - val_accuracy: 0.9640 - val_loss: 0.0960
# Epoch 49/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9763 - loss: 0.0570 - val_accuracy: 0.9593 - val_loss: 0.0963
# Epoch 50/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9747 - loss: 0.0595 - val_accuracy: 0.9614 - val_loss: 0.0932
# Epoch 1/50
# 71/71 - 1s - 19ms/step - accuracy: 0.8528 - loss: 0.3156 - val_accuracy: 0.8924 - val_loss: 0.2421
# Epoch 2/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9120 - loss: 0.1993 - val_accuracy: 0.9207 - val_loss: 0.1911
# Epoch 3/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9283 - loss: 0.1682 - val_accuracy: 0.9320 - val_loss: 0.1620
# Epoch 4/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9330 - loss: 0.1490 - val_accuracy: 0.9320 - val_loss: 0.1583
# Epoch 5/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9448 - loss: 0.1321 - val_accuracy: 0.9480 - val_loss: 0.1306
# Epoch 6/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9436 - loss: 0.1323 - val_accuracy: 0.9485 - val_loss: 0.1257
# Epoch 7/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9488 - loss: 0.1175 - val_accuracy: 0.9480 - val_loss: 0.1257
# Epoch 8/50
# 71/71 - 1s - 9ms/step - accuracy: 0.9521 - loss: 0.1116 - val_accuracy: 0.9521 - val_loss: 0.1172
# Epoch 9/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9553 - loss: 0.1021 - val_accuracy: 0.9562 - val_loss: 0.1130
# Epoch 10/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9596 - loss: 0.0961 - val_accuracy: 0.9640 - val_loss: 0.0943
# Epoch 11/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9603 - loss: 0.0927 - val_accuracy: 0.9614 - val_loss: 0.1008
# Epoch 12/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9626 - loss: 0.0877 - val_accuracy: 0.9614 - val_loss: 0.0935
# Epoch 13/50
# 71/71 - 0s - 6ms/step - accuracy: 0.9641 - loss: 0.0854 - val_accuracy: 0.9598 - val_loss: 0.1073
# Epoch 14/50
# 71/71 - 1s - 8ms/step - accuracy: 0.9662 - loss: 0.0813 - val_accuracy: 0.9665 - val_loss: 0.0855
# Epoch 15/50
# 71/71 - 1s - 7ms/step - accuracy: 0.9684 - loss: 0.0761 - val_accuracy: 0.9676 - val_loss: 0.0840
# Epoch 16/50
# 71/71 - 1s - 8ms/step - accuracy: 0.9698 - loss: 0.0720 - val_accuracy: 0.9593 - val_loss: 0.1012
# Epoch 17/50
# 71/71 - 1s - 8ms/step - accuracy: 0.9723 - loss: 0.0687 - val_accuracy: 0.9670 - val_loss: 0.0788
# Epoch 18/50
# 71/71 - 1s - 7ms/step - accuracy: 0.9734 - loss: 0.0679 - val_accuracy: 0.9629 - val_loss: 0.0841
# Epoch 19/50
# 71/71 - 0s - 7ms/step - accuracy: 0.9731 - loss: 0.0662 - val_accuracy: 0.9743 - val_loss: 0.0756
# Epoch 20/50
# 71/71 - 1s - 9ms/step - accuracy: 0.9755 - loss: 0.0603 - val_accuracy: 0.9701 - val_loss: 0.0841
# Epoch 21/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9753 - loss: 0.0622 - val_accuracy: 0.9727 - val_loss: 0.0775
# Epoch 22/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9777 - loss: 0.0548 - val_accuracy: 0.9712 - val_loss: 0.0758
# Epoch 23/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9774 - loss: 0.0575 - val_accuracy: 0.9588 - val_loss: 0.1037
# Epoch 24/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9786 - loss: 0.0549 - val_accuracy: 0.9681 - val_loss: 0.0834
# Epoch 25/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9780 - loss: 0.0530 - val_accuracy: 0.9717 - val_loss: 0.0773
# Epoch 26/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9785 - loss: 0.0527 - val_accuracy: 0.9717 - val_loss: 0.0819
# Epoch 1/50
# 71/71 - 1s - 19ms/step - accuracy: 0.8809 - loss: 0.2713 - val_accuracy: 0.9243 - val_loss: 0.1763
# Epoch 2/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9276 - loss: 0.1662 - val_accuracy: 0.9217 - val_loss: 0.1858
# Epoch 3/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9401 - loss: 0.1370 - val_accuracy: 0.9495 - val_loss: 0.1147
# Epoch 4/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9531 - loss: 0.1116 - val_accuracy: 0.9562 - val_loss: 0.1124
# Epoch 5/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9581 - loss: 0.1017 - val_accuracy: 0.9578 - val_loss: 0.1090
# Epoch 6/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9610 - loss: 0.0928 - val_accuracy: 0.9475 - val_loss: 0.1363
# Epoch 7/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9652 - loss: 0.0852 - val_accuracy: 0.9588 - val_loss: 0.1140
# Epoch 8/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9661 - loss: 0.0788 - val_accuracy: 0.9619 - val_loss: 0.1112
# Epoch 9/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9712 - loss: 0.0704 - val_accuracy: 0.9640 - val_loss: 0.1041
# Epoch 10/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9744 - loss: 0.0642 - val_accuracy: 0.9655 - val_loss: 0.1016
# Epoch 11/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9762 - loss: 0.0602 - val_accuracy: 0.9681 - val_loss: 0.0900
# Epoch 12/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9772 - loss: 0.0557 - val_accuracy: 0.9629 - val_loss: 0.1166
# Epoch 13/50
# 71/71 - 1s - 9ms/step - accuracy: 0.9804 - loss: 0.0546 - val_accuracy: 0.9655 - val_loss: 0.0989
# Epoch 14/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9819 - loss: 0.0496 - val_accuracy: 0.9629 - val_loss: 0.1287
# Epoch 15/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9811 - loss: 0.0471 - val_accuracy: 0.9604 - val_loss: 0.1164
# Epoch 16/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9840 - loss: 0.0412 - val_accuracy: 0.9691 - val_loss: 0.0975
# Epoch 17/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9826 - loss: 0.0412 - val_accuracy: 0.9670 - val_loss: 0.1005
# Epoch 18/50
# 71/71 - 0s - 6ms/step - accuracy: 0.9832 - loss: 0.0424 - val_accuracy: 0.9598 - val_loss: 0.1197
# Epoch 1/50
# 142/142 - 3s - 18ms/step - accuracy: 0.8746 - loss: 0.2690 - val_accuracy: 0.9130 - val_loss: 0.2079
# Epoch 2/50
# 142/142 - 1s - 6ms/step - accuracy: 0.9224 - loss: 0.1768 - val_accuracy: 0.9351 - val_loss: 0.1693
# Epoch 3/50
# 142/142 - 1s - 6ms/step - accuracy: 0.9359 - loss: 0.1470 - val_accuracy: 0.9418 - val_loss: 0.1544
# Epoch 4/50
# 142/142 - 0s - 3ms/step - accuracy: 0.9459 - loss: 0.1321 - val_accuracy: 0.9428 - val_loss: 0.1508
# Epoch 5/50
# 142/142 - 0s - 3ms/step - accuracy: 0.9491 - loss: 0.1207 - val_accuracy: 0.9418 - val_loss: 0.1571
# Epoch 6/50
# 142/142 - 0s - 3ms/step - accuracy: 0.9554 - loss: 0.1082 - val_accuracy: 0.9501 - val_loss: 0.1305
# Epoch 7/50
# 142/142 - 0s - 3ms/step - accuracy: 0.9586 - loss: 0.0966 - val_accuracy: 0.9490 - val_loss: 0.1300
# Epoch 8/50
# 142/142 - 0s - 3ms/step - accuracy: 0.9635 - loss: 0.0898 - val_accuracy: 0.9609 - val_loss: 0.1096
# Epoch 9/50
# 142/142 - 0s - 3ms/step - accuracy: 0.9643 - loss: 0.0873 - val_accuracy: 0.9609 - val_loss: 0.1030
# Epoch 10/50
# 142/142 - 0s - 4ms/step - accuracy: 0.9710 - loss: 0.0761 - val_accuracy: 0.9588 - val_loss: 0.1083
# Epoch 11/50
# 142/142 - 1s - 4ms/step - accuracy: 0.9708 - loss: 0.0740 - val_accuracy: 0.9598 - val_loss: 0.1140
# Epoch 12/50
# 142/142 - 0s - 3ms/step - accuracy: 0.9712 - loss: 0.0720 - val_accuracy: 0.9624 - val_loss: 0.1089
# Epoch 13/50
# 142/142 - 1s - 4ms/step - accuracy: 0.9727 - loss: 0.0664 - val_accuracy: 0.9604 - val_loss: 0.1128
# Epoch 14/50
# 142/142 - 0s - 3ms/step - accuracy: 0.9740 - loss: 0.0636 - val_accuracy: 0.9655 - val_loss: 0.1021
# Epoch 15/50
# 142/142 - 0s - 3ms/step - accuracy: 0.9764 - loss: 0.0579 - val_accuracy: 0.9650 - val_loss: 0.0979
# Epoch 16/50
# 142/142 - 0s - 3ms/step - accuracy: 0.9775 - loss: 0.0558 - val_accuracy: 0.9706 - val_loss: 0.0921
# Epoch 17/50
# 142/142 - 0s - 3ms/step - accuracy: 0.9784 - loss: 0.0533 - val_accuracy: 0.9686 - val_loss: 0.0902
# Epoch 18/50
# 142/142 - 0s - 3ms/step - accuracy: 0.9792 - loss: 0.0519 - val_accuracy: 0.9686 - val_loss: 0.0970
# Epoch 19/50
# 142/142 - 1s - 4ms/step - accuracy: 0.9798 - loss: 0.0510 - val_accuracy: 0.9686 - val_loss: 0.0885
# Epoch 20/50
# 142/142 - 0s - 3ms/step - accuracy: 0.9818 - loss: 0.0440 - val_accuracy: 0.9717 - val_loss: 0.0880
# Epoch 21/50
# 142/142 - 1s - 5ms/step - accuracy: 0.9823 - loss: 0.0442 - val_accuracy: 0.9717 - val_loss: 0.0925
# Epoch 22/50
# 142/142 - 0s - 3ms/step - accuracy: 0.9822 - loss: 0.0434 - val_accuracy: 0.9686 - val_loss: 0.0955
# Epoch 23/50
# 142/142 - 1s - 4ms/step - accuracy: 0.9845 - loss: 0.0406 - val_accuracy: 0.9722 - val_loss: 0.0876
# Epoch 24/50
# 142/142 - 1s - 5ms/step - accuracy: 0.9845 - loss: 0.0405 - val_accuracy: 0.9676 - val_loss: 0.1080
# Epoch 25/50
# 142/142 - 1s - 5ms/step - accuracy: 0.9853 - loss: 0.0378 - val_accuracy: 0.9665 - val_loss: 0.1013
# Epoch 26/50
# 142/142 - 1s - 6ms/step - accuracy: 0.9861 - loss: 0.0371 - val_accuracy: 0.9676 - val_loss: 0.1011
# Epoch 27/50
# 142/142 - 1s - 6ms/step - accuracy: 0.9855 - loss: 0.0375 - val_accuracy: 0.9717 - val_loss: 0.0973
# Epoch 28/50
# 142/142 - 1s - 5ms/step - accuracy: 0.9845 - loss: 0.0388 - val_accuracy: 0.9691 - val_loss: 0.0899
# Epoch 29/50
# 142/142 - 1s - 7ms/step - accuracy: 0.9859 - loss: 0.0341 - val_accuracy: 0.9696 - val_loss: 0.0915
# Epoch 30/50
# 142/142 - 0s - 3ms/step - accuracy: 0.9880 - loss: 0.0315 - val_accuracy: 0.9686 - val_loss: 0.0974
# Epoch 1/50
# 71/71 - 1s - 18ms/step - accuracy: 0.8528 - loss: 0.3156 - val_accuracy: 0.8924 - val_loss: 0.2421
# Epoch 2/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9120 - loss: 0.1993 - val_accuracy: 0.9207 - val_loss: 0.1911
# Epoch 3/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9283 - loss: 0.1682 - val_accuracy: 0.9320 - val_loss: 0.1620
# Epoch 4/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9330 - loss: 0.1490 - val_accuracy: 0.9320 - val_loss: 0.1583
# Epoch 5/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9448 - loss: 0.1321 - val_accuracy: 0.9480 - val_loss: 0.1306
# Epoch 6/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9436 - loss: 0.1323 - val_accuracy: 0.9485 - val_loss: 0.1257
# Epoch 7/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9488 - loss: 0.1175 - val_accuracy: 0.9480 - val_loss: 0.1257
# Epoch 8/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9521 - loss: 0.1116 - val_accuracy: 0.9521 - val_loss: 0.1172
# Epoch 9/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9553 - loss: 0.1021 - val_accuracy: 0.9562 - val_loss: 0.1130
# Epoch 10/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9596 - loss: 0.0961 - val_accuracy: 0.9640 - val_loss: 0.0943
# Epoch 11/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9603 - loss: 0.0927 - val_accuracy: 0.9614 - val_loss: 0.1008
# Epoch 12/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9626 - loss: 0.0877 - val_accuracy: 0.9614 - val_loss: 0.0935
# Epoch 13/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9641 - loss: 0.0854 - val_accuracy: 0.9598 - val_loss: 0.1073
# Epoch 14/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9662 - loss: 0.0813 - val_accuracy: 0.9665 - val_loss: 0.0855
# Epoch 15/50
# 71/71 - 1s - 9ms/step - accuracy: 0.9684 - loss: 0.0761 - val_accuracy: 0.9676 - val_loss: 0.0840
# Epoch 16/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9698 - loss: 0.0720 - val_accuracy: 0.9593 - val_loss: 0.1012
# Epoch 17/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9723 - loss: 0.0687 - val_accuracy: 0.9670 - val_loss: 0.0788
# Epoch 18/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9734 - loss: 0.0679 - val_accuracy: 0.9629 - val_loss: 0.0841
# Epoch 19/50
# 71/71 - 1s - 9ms/step - accuracy: 0.9731 - loss: 0.0662 - val_accuracy: 0.9743 - val_loss: 0.0756
# Epoch 20/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9755 - loss: 0.0603 - val_accuracy: 0.9701 - val_loss: 0.0841
# Epoch 21/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9753 - loss: 0.0622 - val_accuracy: 0.9727 - val_loss: 0.0775
# Epoch 22/50
# 71/71 - 0s - 7ms/step - accuracy: 0.9777 - loss: 0.0548 - val_accuracy: 0.9712 - val_loss: 0.0758
# Epoch 23/50
# 71/71 - 1s - 8ms/step - accuracy: 0.9774 - loss: 0.0575 - val_accuracy: 0.9588 - val_loss: 0.1037
# Epoch 24/50
# 71/71 - 0s - 6ms/step - accuracy: 0.9786 - loss: 0.0549 - val_accuracy: 0.9681 - val_loss: 0.0834
# Epoch 25/50
# 71/71 - 1s - 10ms/step - accuracy: 0.9780 - loss: 0.0530 - val_accuracy: 0.9717 - val_loss: 0.0773
# Epoch 26/50
# 71/71 - 1s - 8ms/step - accuracy: 0.9785 - loss: 0.0527 - val_accuracy: 0.9717 - val_loss: 0.0819
# Epoch 1/50
# 36/36 - 1s - 40ms/step - accuracy: 0.8211 - loss: 0.3701 - val_accuracy: 0.8671 - val_loss: 0.2828
# Epoch 2/50
# 36/36 - 1s - 14ms/step - accuracy: 0.8978 - loss: 0.2282 - val_accuracy: 0.9053 - val_loss: 0.2081
# Epoch 3/50
# 36/36 - 0s - 9ms/step - accuracy: 0.9170 - loss: 0.1893 - val_accuracy: 0.9114 - val_loss: 0.2000
# Epoch 4/50
# 36/36 - 0s - 7ms/step - accuracy: 0.9267 - loss: 0.1688 - val_accuracy: 0.9156 - val_loss: 0.1876
# Epoch 5/50
# 36/36 - 1s - 17ms/step - accuracy: 0.9322 - loss: 0.1523 - val_accuracy: 0.9289 - val_loss: 0.1672
# Epoch 6/50
# 36/36 - 0s - 7ms/step - accuracy: 0.9361 - loss: 0.1466 - val_accuracy: 0.9310 - val_loss: 0.1721
# Epoch 7/50
# 36/36 - 1s - 17ms/step - accuracy: 0.9417 - loss: 0.1353 - val_accuracy: 0.9269 - val_loss: 0.1734
# Epoch 8/50
# 36/36 - 0s - 7ms/step - accuracy: 0.9453 - loss: 0.1257 - val_accuracy: 0.9423 - val_loss: 0.1393
# Epoch 9/50
# 36/36 - 0s - 9ms/step - accuracy: 0.9454 - loss: 0.1237 - val_accuracy: 0.9351 - val_loss: 0.1567
# Epoch 10/50
# 36/36 - 0s - 6ms/step - accuracy: 0.9501 - loss: 0.1137 - val_accuracy: 0.9310 - val_loss: 0.1664
# Epoch 11/50
# 36/36 - 0s - 7ms/step - accuracy: 0.9546 - loss: 0.1092 - val_accuracy: 0.9361 - val_loss: 0.1518
# Epoch 12/50
# 36/36 - 0s - 7ms/step - accuracy: 0.9567 - loss: 0.1044 - val_accuracy: 0.9408 - val_loss: 0.1488
# Epoch 13/50
# 36/36 - 0s - 9ms/step - accuracy: 0.9591 - loss: 0.1020 - val_accuracy: 0.9490 - val_loss: 0.1264
# Epoch 14/50
# 36/36 - 0s - 7ms/step - accuracy: 0.9574 - loss: 0.0976 - val_accuracy: 0.9526 - val_loss: 0.1199
# Epoch 15/50
# 36/36 - 0s - 7ms/step - accuracy: 0.9591 - loss: 0.0942 - val_accuracy: 0.9398 - val_loss: 0.1506
# Epoch 16/50
# 36/36 - 0s - 7ms/step - accuracy: 0.9632 - loss: 0.0902 - val_accuracy: 0.9506 - val_loss: 0.1233
# Epoch 17/50
# 36/36 - 0s - 7ms/step - accuracy: 0.9652 - loss: 0.0879 - val_accuracy: 0.9490 - val_loss: 0.1295
# Epoch 18/50
# 36/36 - 0s - 7ms/step - accuracy: 0.9649 - loss: 0.0836 - val_accuracy: 0.9516 - val_loss: 0.1213
# Epoch 19/50
# 36/36 - 0s - 7ms/step - accuracy: 0.9670 - loss: 0.0794 - val_accuracy: 0.9567 - val_loss: 0.1138
# Epoch 20/50
# 36/36 - 0s - 7ms/step - accuracy: 0.9684 - loss: 0.0776 - val_accuracy: 0.9593 - val_loss: 0.1044
# Epoch 21/50
# 36/36 - 0s - 7ms/step - accuracy: 0.9695 - loss: 0.0758 - val_accuracy: 0.9624 - val_loss: 0.0956
# Epoch 22/50
# 36/36 - 0s - 7ms/step - accuracy: 0.9696 - loss: 0.0736 - val_accuracy: 0.9521 - val_loss: 0.1200
# Epoch 23/50
# 36/36 - 0s - 7ms/step - accuracy: 0.9696 - loss: 0.0723 - val_accuracy: 0.9552 - val_loss: 0.1157
# Epoch 24/50
# 36/36 - 0s - 7ms/step - accuracy: 0.9699 - loss: 0.0726 - val_accuracy: 0.9562 - val_loss: 0.1054
# Epoch 25/50
# 36/36 - 0s - 7ms/step - accuracy: 0.9735 - loss: 0.0669 - val_accuracy: 0.9614 - val_loss: 0.0963
# Epoch 26/50
# 36/36 - 0s - 7ms/step - accuracy: 0.9734 - loss: 0.0655 - val_accuracy: 0.9604 - val_loss: 0.0971
# Epoch 27/50
# 36/36 - 0s - 7ms/step - accuracy: 0.9734 - loss: 0.0646 - val_accuracy: 0.9665 - val_loss: 0.0885
# Epoch 28/50
# 36/36 - 0s - 7ms/step - accuracy: 0.9749 - loss: 0.0626 - val_accuracy: 0.9640 - val_loss: 0.0968
# Epoch 29/50
# 36/36 - 0s - 7ms/step - accuracy: 0.9743 - loss: 0.0592 - val_accuracy: 0.9609 - val_loss: 0.0985
# Epoch 30/50
# 36/36 - 0s - 7ms/step - accuracy: 0.9760 - loss: 0.0588 - val_accuracy: 0.9665 - val_loss: 0.0920
# Epoch 31/50
# 36/36 - 0s - 7ms/step - accuracy: 0.9785 - loss: 0.0558 - val_accuracy: 0.9629 - val_loss: 0.0934
# Epoch 32/50
# 36/36 - 0s - 8ms/step - accuracy: 0.9764 - loss: 0.0578 - val_accuracy: 0.9650 - val_loss: 0.0973
# Epoch 33/50
# 36/36 - 0s - 10ms/step - accuracy: 0.9767 - loss: 0.0576 - val_accuracy: 0.9650 - val_loss: 0.0871
# Epoch 34/50
# 36/36 - 1s - 18ms/step - accuracy: 0.9792 - loss: 0.0512 - val_accuracy: 0.9655 - val_loss: 0.0921
# Epoch 35/50
# 36/36 - 1s - 17ms/step - accuracy: 0.9774 - loss: 0.0539 - val_accuracy: 0.9655 - val_loss: 0.0859
# Epoch 36/50
# 36/36 - 1s - 18ms/step - accuracy: 0.9804 - loss: 0.0515 - val_accuracy: 0.9640 - val_loss: 0.0995
# Epoch 37/50
# 36/36 - 0s - 12ms/step - accuracy: 0.9801 - loss: 0.0478 - val_accuracy: 0.9629 - val_loss: 0.1000
# Epoch 38/50
# 36/36 - 1s - 20ms/step - accuracy: 0.9806 - loss: 0.0486 - val_accuracy: 0.9686 - val_loss: 0.0767
# Epoch 39/50
# 36/36 - 0s - 12ms/step - accuracy: 0.9807 - loss: 0.0482 - val_accuracy: 0.9681 - val_loss: 0.0810
# Epoch 40/50
# 36/36 - 0s - 9ms/step - accuracy: 0.9810 - loss: 0.0462 - val_accuracy: 0.9665 - val_loss: 0.0893
# Epoch 41/50
# 36/36 - 0s - 7ms/step - accuracy: 0.9807 - loss: 0.0473 - val_accuracy: 0.9665 - val_loss: 0.0926
# Epoch 42/50
# 36/36 - 0s - 7ms/step - accuracy: 0.9826 - loss: 0.0426 - val_accuracy: 0.9676 - val_loss: 0.0903
# Epoch 43/50
# 36/36 - 0s - 7ms/step - accuracy: 0.9820 - loss: 0.0436 - val_accuracy: 0.9691 - val_loss: 0.0788
# Epoch 44/50
# 36/36 - 0s - 7ms/step - accuracy: 0.9838 - loss: 0.0422 - val_accuracy: 0.9717 - val_loss: 0.0757
# Epoch 45/50
# 36/36 - 0s - 7ms/step - accuracy: 0.9843 - loss: 0.0392 - val_accuracy: 0.9691 - val_loss: 0.0823
# Epoch 46/50
# 36/36 - 0s - 7ms/step - accuracy: 0.9837 - loss: 0.0404 - val_accuracy: 0.9691 - val_loss: 0.0936
# Epoch 47/50
# 36/36 - 0s - 7ms/step - accuracy: 0.9840 - loss: 0.0398 - val_accuracy: 0.9737 - val_loss: 0.0755
# Epoch 48/50
# 36/36 - 0s - 8ms/step - accuracy: 0.9830 - loss: 0.0413 - val_accuracy: 0.9722 - val_loss: 0.0776
# Epoch 49/50
# 36/36 - 0s - 8ms/step - accuracy: 0.9868 - loss: 0.0353 - val_accuracy: 0.9701 - val_loss: 0.0839
# Epoch 50/50
# 36/36 - 0s - 7ms/step - accuracy: 0.9851 - loss: 0.0374 - val_accuracy: 0.9691 - val_loss: 0.0855

# %% [markdown]
# ## 5. Checks

# %%
# Purpose: Runs this notebook step and prints or saves the resulting intermediate output for review.
display(pd.DataFrame([("learning_rate_stage", "learning_rate_only"), ("batch_stage", "batch_size_only_after_selected_lr"), ("test_metrics_computed", False)], columns=["check", "value"]))
# Out:
#                    check                              value
# 0    learning_rate_stage                 learning_rate_only
# 1            batch_stage  batch_size_only_after_selected_lr
# 2  test_metrics_computed                              False
