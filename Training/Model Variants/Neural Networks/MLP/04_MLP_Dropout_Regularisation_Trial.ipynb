# %% [markdown]
# # 04 MLP Dropout Regularisation Trial
#
# Controlled hyperparameter screening. Change only `dropout`; all inherited settings remain fixed. No L2 is added unless a later human decision changes the methodology.

# %% [markdown]
# ## 1. Package Setup

# %%
# Purpose: Package installs are documented but not run automatically during this static refactor.
# %pip install tensorflow scikit-learn pandas numpy matplotlib seaborn joblib soundfile librosa

# %% [markdown]
# ## 2. Load Cache and Previous Config

# %%
import os
from pathlib import Path

# Purpose: Mounts Google Drive when this notebook is running in Google Colab.
# Why this exists: the project files, cached MFCC features, manifests, models, figures,
# and metric outputs live in Google Drive during Colab runs. The /content/drive path
# only represents the real MyDrive files after drive.mount("/content/drive") succeeds.
# Important: the project root should be the folder that contains Data, Model Variants,
# and outputs. For this project, that expected Colab folder is the INM701 folder below.
COLAB_DRIVE_MOUNT_POINT = Path("/content/drive")
EXPECTED_COLAB_PROJECT_ROOT = Path("/content/drive/MyDrive/Colab Notebooks/Education/INM701")

try:
    from google.colab import drive

    drive.mount(str(COLAB_DRIVE_MOUNT_POINT))
    print("Google Colab detected. Google Drive mounted.")

    current_project_root = os.environ.get("INTRO_AI_PROJECT_ROOT")
    current_data_dir_exists = bool(current_project_root) and (Path(current_project_root) / "Data").exists()
    expected_data_dir_exists = (EXPECTED_COLAB_PROJECT_ROOT / "Data").exists()

    # Purpose: Keep a valid user-provided project root, but repair stale runtime state
    # if a previous cell pointed INTRO_AI_PROJECT_ROOT somewhere that does not contain Data.
    if current_data_dir_exists:
        print("INTRO_AI_PROJECT_ROOT already points to a folder with Data, so it was kept.")
    elif expected_data_dir_exists:
        os.environ["INTRO_AI_PROJECT_ROOT"] = str(EXPECTED_COLAB_PROJECT_ROOT)
        print("INTRO_AI_PROJECT_ROOT set to the expected INM701 project folder.")
    elif not current_project_root:
        os.environ["INTRO_AI_PROJECT_ROOT"] = str(EXPECTED_COLAB_PROJECT_ROOT)
        print("INTRO_AI_PROJECT_ROOT was not set, so it now points to the expected INM701 folder.")
    else:
        print("INTRO_AI_PROJECT_ROOT was kept, but Data was not found there or in the expected INM701 folder.")
except Exception as exc:
    print("Google Colab Drive mount skipped. This is expected outside Colab.")
    print("Mount skip reason:", exc)

active_project_root = os.environ.get("INTRO_AI_PROJECT_ROOT", "not set")
print("INTRO_AI_PROJECT_ROOT:", active_project_root)
if active_project_root != "not set":
    active_project_root = Path(active_project_root)
    print("Project root exists:", active_project_root.exists())
    print("Expected Data folder:", active_project_root / "Data")
    print("Data folder exists:", (active_project_root / "Data").exists())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Google Colab detected. Google Drive mounted.
# INTRO_AI_PROJECT_ROOT set to the expected INM701 project folder.
# INTRO_AI_PROJECT_ROOT: /content/drive/MyDrive/Colab Notebooks/Education/INM701
# Project root exists: True
# Expected Data folder: /content/drive/MyDrive/Colab Notebooks/Education/INM701/Data
# Data folder exists: True

# %%
# Purpose: Later notebooks load the one MLP-ready cache made by notebook 00. They do not
# rescan folders, regenerate splits, extract MFCCs, fit scalers, or recalculate class weights.
import hashlib
import json
import os
import random
import time
from itertools import product
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score, precision_score, recall_score
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.models import Sequential

try:
    from IPython.display import display
except Exception:
    display = print

RANDOM_STATE = 42
MAX_EPOCHS = 50
EARLY_STOP_PATIENCE = 7
EARLY_STOP_MIN_DELTA = 1e-4
THRESHOLD = 0.5
CLASS_NAMES = {0: "bona_fide", 1: "synthetic"}
CONFIRMATION_SEEDS = [42, 123, 2026]


def resolve_project_root():
    # Purpose: default path.
    explicit = os.environ.get("INTRO_AI_PROJECT_ROOT")
    if explicit:
        return Path(explicit).expanduser().resolve()
    cwd = Path.cwd().resolve()
    # Purpose: Runs each candidate configuration under the same data split for a fair validation comparison.
    for candidate in [cwd, *cwd.parents]:
        if (candidate / "Model Variants").exists():
            return candidate
        if (candidate / "Training" / "Model Variants").exists():
            return candidate / "Training"
    return Path("/content/drive/MyDrive/Colab Notebooks/Education/INM701")


# Purpose: Centralizes filesystem paths so dataset inputs, caches, figures, models, and metric tables are easy
# Purpose: to trace.
PROJECT_ROOT = resolve_project_root()
OUTPUT_DIR = PROJECT_ROOT / "outputs" / "mlp"
CACHE_DIR = OUTPUT_DIR / "cache"
MANIFESTS_DIR = OUTPUT_DIR / "manifests"
CONFIGS_DIR = OUTPUT_DIR / "configs"
TABLES_DIR = OUTPUT_DIR / "tables"
HISTORIES_DIR = OUTPUT_DIR / "histories"
METRICS_DIR = OUTPUT_DIR / "metrics"
FIGURES_DIR = OUTPUT_DIR / "figures"
MODELS_DIR = OUTPUT_DIR / "models"
PILOT_LEGACY_DIR = OUTPUT_DIR / "pilot_legacy"
# Purpose: Creates each output directory before later cells try to save tables, figures, or models.
for directory in [OUTPUT_DIR, CACHE_DIR, MANIFESTS_DIR, CONFIGS_DIR, TABLES_DIR, HISTORIES_DIR, METRICS_DIR, FIGURES_DIR, MODELS_DIR, PILOT_LEGACY_DIR]:
    directory.mkdir(parents=True, exist_ok=True)


def require_file(path):
    # Purpose: Stops the notebook early with a clear message when a required upstream artifact is missing.
    path = Path(path)
    if not path.exists():
        raise FileNotFoundError(f"Required file not found: {path}")
    return path


def load_json(path):
    # Purpose: Keeps the load_json helper isolated so later notebook cells can call it consistently.
    with open(require_file(path), "r", encoding="utf-8") as f:
        return json.load(f)


def save_json(payload, path):
    # Purpose: Keeps the save_json helper isolated so later notebook cells can call it consistently.
    with open(path, "w", encoding="utf-8") as f:
        json.dump(payload, f, indent=2)




def normalise_handoff_config(config):
    # Purpose: Normalises a config loaded from a JSON string or CSV row before it is reused
    # by the next notebook in the MLP chain. This keeps rebuilt handoff files compatible
    # with configs produced by a full training run.
    normalised = dict(config)
    hidden_units = normalised.get("hidden_units", [])
    if isinstance(hidden_units, str):
        hidden_units = json.loads(hidden_units)
    normalised["hidden_units"] = [int(value) for value in hidden_units]
    normalised["activation"] = str(normalised["activation"])
    normalised["optimizer"] = str(normalised["optimizer"])
    normalised["dropout"] = float(normalised["dropout"])
    normalised["learning_rate"] = float(normalised["learning_rate"])
    normalised["batch_size"] = int(normalised["batch_size"])
    normalised["loss"] = normalised.get("loss", "binary_crossentropy")
    normalised["threshold"] = float(normalised.get("threshold", THRESHOLD))
    return normalised


def first_existing_results_path(candidate_paths):
    # Purpose: Supports the normal result filename and any documented alias without changing
    # where the notebook saves new results. The first existing CSV is used for rebuilding.
    paths = [Path(path) for path in candidate_paths]
    for path in paths:
        if path.exists():
            return path
    return paths[0]


def rebuild_selected_config_from_results(results_path, selected_path, selected_by_stage):
    # Purpose: Rebuilds a missing selected_config JSON from an existing validation-results
    # CSV. This avoids rerunning training just to recreate the JSON handoff file.
    results_path = Path(results_path)
    selected_path = Path(selected_path)
    if not results_path.exists():
        print("Cannot rebuild selected config because result CSV is missing:", results_path)
        return None

    results_df = pd.read_csv(results_path)
    required_columns = {"config_json", "validation_macro_f1", "best_validation_loss"}
    missing_columns = required_columns - set(results_df.columns)
    if missing_columns:
        raise RuntimeError(f"Cannot rebuild {selected_path.name}; missing columns in {results_path.name}: {sorted(missing_columns)}")
    if results_df.empty:
        raise RuntimeError(f"Cannot rebuild {selected_path.name}; result CSV is empty: {results_path}")

    best_row = results_df.sort_values(["validation_macro_f1", "best_validation_loss"], ascending=[False, True]).iloc[0]
    selected = normalise_handoff_config(json.loads(best_row["config_json"]))
    selected.update({
        "selected_by_stage": selected_by_stage,
        "selection_metric": "validation_macro_f1",
        "validation_macro_f1": float(best_row["validation_macro_f1"]),
        "best_validation_loss": float(best_row["best_validation_loss"]),
        "rebuilt_from_results_csv": str(results_path),
    })
    save_json(selected, selected_path)
    print("Rebuilt selected config from existing results:", selected_path)
    return selected


def ensure_selected_config_from_results(selected_path, results_path, selected_by_stage):
    # Purpose: Repairs a missing previous-stage config before this notebook tries to load it.
    # If neither the JSON nor the CSV exists, the later require_file/load_json call will still
    # stop with a clear missing-artifact error.
    selected_path = Path(selected_path)
    results_path = Path(results_path)
    if selected_path.exists():
        return load_json(selected_path)
    if results_path.exists():
        return rebuild_selected_config_from_results(results_path, selected_path, selected_by_stage)
    print("Selected config missing:", selected_path)
    print("Result CSV also missing, so config cannot be rebuilt:", results_path)
    return None


def load_class_weights():
    # Purpose: Keeps the load_class_weights helper isolated so later notebook cells can call it consistently.
    payload = load_json(CONFIGS_DIR / "class_weights.json")
    weights = payload.get("class_weights", payload)
    return {int(label): float(weight) for label, weight in weights.items()}


for required in [
    CACHE_DIR / "X_train.npy",
    CACHE_DIR / "y_train.npy",
    CACHE_DIR / "train_metadata.csv",
    CACHE_DIR / "X_validation.npy",
    CACHE_DIR / "y_validation.npy",
    CACHE_DIR / "validation_metadata.csv",
    CACHE_DIR / "feature_config.json",
    CONFIGS_DIR / "class_weights.json",
]:
    require_file(required)

X_train = np.load(CACHE_DIR / "X_train.npy")
y_train = np.load(CACHE_DIR / "y_train.npy")
train_metadata = pd.read_csv(CACHE_DIR / "train_metadata.csv")
X_validation = np.load(CACHE_DIR / "X_validation.npy")
y_validation = np.load(CACHE_DIR / "y_validation.npy")
validation_metadata = pd.read_csv(CACHE_DIR / "validation_metadata.csv")
feature_config = load_json(CACHE_DIR / "feature_config.json")
CLASS_WEIGHTS = load_class_weights()

if len(X_train) != len(y_train) or len(X_train) != len(train_metadata):
    raise RuntimeError("Training cache arrays, labels and metadata are not row-aligned.")
if len(X_validation) != len(y_validation) or len(X_validation) != len(validation_metadata):
    raise RuntimeError("Validation cache arrays, labels and metadata are not row-aligned.")

print("Loaded MLP cache:", CACHE_DIR)
print("X_train shape:", X_train.shape)
print("X_validation shape:", X_validation.shape)

# Purpose: Rebuild the previous selected config from its result CSV if the JSON handoff file is missing.
ensure_selected_config_from_results(CONFIGS_DIR / "03_selected_config.json", TABLES_DIR / "03_optimizer_results.csv", "03_optimizer")
base_config = load_json(CONFIGS_DIR / "03_selected_config.json")
print("Loaded previous config:", "03_selected_config.json")
# Out:
# Loaded MLP cache: /content/drive/MyDrive/Colab Notebooks/Education/INM701/outputs/mlp/cache
# X_train shape: (9060, 80)
# X_validation shape: (1942, 80)
# Loaded previous config: 03_selected_config.json

# %% [markdown]
# ## 3. Keras Utilities

# %%
# Purpose: Shared beginner-readable Keras utilities for validation-only model selection.
def normalise_config(config):
    # Purpose: Keeps the normalise_config helper isolated so later notebook cells can call it consistently.
    normalised = dict(config)
    normalised["hidden_units"] = [int(value) for value in normalised["hidden_units"]]
    normalised["activation"] = str(normalised["activation"])
    normalised["optimizer"] = str(normalised["optimizer"])
    normalised["dropout"] = float(normalised["dropout"])
    normalised["learning_rate"] = float(normalised["learning_rate"])
    normalised["batch_size"] = int(normalised["batch_size"])
    normalised["loss"] = normalised.get("loss", "binary_crossentropy")
    normalised["threshold"] = float(normalised.get("threshold", THRESHOLD))
    return normalised


def config_json(config):
    # Purpose: Keeps the config_json helper isolated so later notebook cells can call it consistently.
    return json.dumps(normalise_config(config), sort_keys=True)


def config_key(config):
    # Purpose: Keeps the config_key helper isolated so later notebook cells can call it consistently.
    return hashlib.sha256(config_json(config).encode("utf-8")).hexdigest()


def seed_from_config(config, base_seed=RANDOM_STATE):
    # Purpose: Keeps the seed_from_config helper isolated so later notebook cells can call it consistently.
    digest = hashlib.sha256(f"{base_seed}:{config_json(config)}".encode("utf-8")).hexdigest()
    return int(digest[:8], 16) % (2**31 - 1)


def set_global_seed(seed):
    # Purpose: Keeps the set_global_seed helper isolated so later notebook cells can call it consistently.
    random.seed(int(seed))
    np.random.seed(int(seed))
    tf.keras.utils.set_random_seed(int(seed))
    os.environ["PYTHONHASHSEED"] = str(int(seed))


def make_optimizer(config):
    # Purpose: Keeps the make_optimizer helper isolated so later notebook cells can call it consistently.
    name = str(config["optimizer"]).lower()
    lr = float(config["learning_rate"])
    if name == "adam":
        return tf.keras.optimizers.Adam(learning_rate=lr)
    if name == "rmsprop":
        return tf.keras.optimizers.RMSprop(learning_rate=lr)
    if name in ["sgd", "sgd_momentum"]:
        return tf.keras.optimizers.SGD(learning_rate=lr, momentum=0.9)
    raise ValueError(f"Unsupported optimizer: {config['optimizer']}")


def build_mlp_model(config, input_dim):
    # Purpose: Constructs the MLP architecture for the current experiment configuration.
    config = normalise_config(config)
    model = Sequential()
    model.add(Input(shape=(input_dim,)))
    # Purpose: Iterates over this collection to build the next table, feature set, or experiment result
    # Purpose: consistently.
    for units in config["hidden_units"]:
        model.add(Dense(units, activation=config["activation"]))
        if config["dropout"] > 0:
            model.add(Dropout(config["dropout"]))
    model.add(Dense(1, activation="sigmoid"))
    model.compile(loss=config["loss"], optimizer=make_optimizer(config), metrics=["accuracy"])
    return model


def train_and_evaluate_config(config, run_seed, run_name, verbose=0):
    # Purpose: consistently.
    config = normalise_config(config)
    tf.keras.backend.clear_session()
    set_global_seed(run_seed)
    model = build_mlp_model(config, X_train.shape[1])
    callbacks = [
        tf.keras.callbacks.EarlyStopping(
            monitor="val_loss",
            patience=EARLY_STOP_PATIENCE,
            min_delta=EARLY_STOP_MIN_DELTA,
            restore_best_weights=True,
        )
    ]
    start = time.perf_counter()
    history = model.fit(
        X_train,
        y_train,
        validation_data=(X_validation, y_validation),
        epochs=MAX_EPOCHS,
        batch_size=config["batch_size"],
        class_weight=CLASS_WEIGHTS,
        callbacks=callbacks,
        verbose=verbose,
    )
    runtime = time.perf_counter() - start
    probability = model.predict(X_validation, batch_size=config["batch_size"], verbose=0).ravel()
    pred = (probability >= config["threshold"]).astype(int)
    row = {
        "configuration": config,
        "config_json": config_json(config),
        "config_key": config_key(config),
        "seed": int(run_seed),
        "validation_macro_f1": float(f1_score(y_validation, pred, average="macro", zero_division=0)),
        "validation_binary_f1_synthetic": float(f1_score(y_validation, pred, pos_label=1, zero_division=0)),
        "validation_accuracy": float(accuracy_score(y_validation, pred)),
        "validation_precision_synthetic": float(precision_score(y_validation, pred, pos_label=1, zero_division=0)),
        "validation_recall_synthetic": float(recall_score(y_validation, pred, pos_label=1, zero_division=0)),
        "best_validation_loss": float(np.min(history.history["val_loss"])),
        "best_epoch": int(np.argmin(history.history["val_loss"]) + 1),
        "epochs_trained": int(len(history.history["loss"])),
        "runtime_seconds": float(runtime),
        "run_name": run_name,
    }
    history_df = pd.DataFrame(history.history)
    history_df.insert(0, "epoch", np.arange(1, len(history_df) + 1))
    return row, history_df


def flat_result(row, extra=None):
    # Purpose: Keeps the flat_result helper isolated so later notebook cells can call it consistently.
    extra = extra or {}
    config = normalise_config(row["configuration"])
    flat = dict(extra)
    flat.update({
        "hidden_units": json.dumps(config["hidden_units"]),
        "activation": config["activation"],
        "optimizer": config["optimizer"],
        "dropout": config["dropout"],
        "learning_rate": config["learning_rate"],
        "batch_size": config["batch_size"],
        "loss": config["loss"],
        "threshold": config["threshold"],
        "config_json": row["config_json"],
        "config_key": row["config_key"],
        "seed": row["seed"],
        "validation_macro_f1": row["validation_macro_f1"],
        "validation_binary_f1_synthetic": row["validation_binary_f1_synthetic"],
        "validation_accuracy": row["validation_accuracy"],
        "validation_precision_synthetic": row["validation_precision_synthetic"],
        "validation_recall_synthetic": row["validation_recall_synthetic"],
        "best_validation_loss": row["best_validation_loss"],
        "best_epoch": row["best_epoch"],
        "epochs_trained": row["epochs_trained"],
        "runtime_seconds": row["runtime_seconds"],
    })
    return flat


def select_best(rows):
    # Purpose: Keeps the select_best helper isolated so later notebook cells can call it consistently.
    return max(rows, key=lambda row: (row["validation_macro_f1"], -row["best_validation_loss"]))


def run_controlled_trial(stage_name, varied_key, candidate_configs, results_path, histories_path, selected_path):
    # Purpose: Keeps the run_controlled_trial helper isolated so later notebook cells can call it consistently.
    rows = []
    histories = {}
    # Purpose: Iterates over this collection to build the next table, feature set, or experiment result
    # Purpose: consistently.
    for number, config in enumerate(candidate_configs, start=1):
        config = normalise_config(config)
        value = config[varied_key]
        print(f"{stage_name} candidate {number}/{len(candidate_configs)}:", value)
        row, history_df = train_and_evaluate_config(config, seed_from_config(config), f"{stage_name}_{number:02d}", verbose=2)
        rows.append(row)
        histories[str(value)] = history_df.to_dict(orient="records")
        # Purpose: Saves the generated artifacts so later notebooks, reports, or reruns can inspect the same
        # Purpose: outputs.
        pd.DataFrame([flat_result(item, {"stage": stage_name, "candidate": str(item["configuration"][varied_key])}) for item in rows]).to_csv(results_path, index=False)
        save_json(histories, histories_path)
    best = select_best(rows)
    selected = normalise_config(best["configuration"])
    selected.update({
        "selected_by_stage": stage_name,
        "selection_metric": "validation_macro_f1",
        "validation_macro_f1": best["validation_macro_f1"],
        "best_validation_loss": best["best_validation_loss"],
    })
    save_json(selected, selected_path)
    display(pd.read_csv(results_path).sort_values("validation_macro_f1", ascending=False))
    print("Saved selected config:", selected_path)

# %% [markdown]
# ## 4. Candidate Configurations

# %%
# Purpose: 4. Candidate Configurations.
VARIED_KEY = "dropout"
candidate_values = [0.0, 0.1, 0.2, 0.3, 0.4]
candidate_configs = []
# Purpose: Runs the controlled trial once for each candidate value of the tested hyperparameter.
for value in candidate_values:
    config = dict(base_config)
    config[VARIED_KEY] = value
    candidate_configs.append(normalise_config(config))
display(pd.DataFrame(candidate_configs))
# Out:
#   hidden_units activation optimizer  dropout  learning_rate  batch_size  \
# 0    [128, 64]        elu   rmsprop      0.0          0.001         128
# 1    [128, 64]        elu   rmsprop      0.1          0.001         128
# 2    [128, 64]        elu   rmsprop      0.2          0.001         128
# 3    [128, 64]        elu   rmsprop      0.3          0.001         128
# 4    [128, 64]        elu   rmsprop      0.4          0.001         128
#
#                   loss  threshold selected_by_stage     selection_metric  \
# 0  binary_crossentropy        0.5      03_optimizer  validation_macro_f1
# 1  binary_crossentropy        0.5      03_optimizer  validation_macro_f1
# 2  binary_crossentropy        0.5      03_optimizer  validation_macro_f1
# 3  binary_crossentropy        0.5      03_optimizer  validation_macro_f1
# 4  binary_crossentropy        0.5      03_optimizer  validation_macro_f1
#
#    validation_macro_f1  best_validation_loss
# 0             0.973099              0.064414
# 1             0.973099              0.064414
# 2             0.973099              0.064414
# 3             0.973099              0.064414
# 4             0.973099              0.064414

# %% [markdown]
# ## 5. Run or Load Results

# %%
# Purpose: Runs the trial when enabled, otherwise repairs or displays the selected config
# handoff from existing validation results without retraining.
RUN_DROPOUT_TRIAL = True
results_path = TABLES_DIR / "04_dropout_results.csv"
histories_path = HISTORIES_DIR / "04_dropout_histories.json"
selected_path = CONFIGS_DIR / "04_selected_config.json"
rebuild_results_path = first_existing_results_path([TABLES_DIR / "04_dropout_results.csv"])

if RUN_DROPOUT_TRIAL:
    run_controlled_trial("04_dropout", VARIED_KEY, candidate_configs, results_path, histories_path, selected_path)
elif selected_path.exists():
    selected_config = load_json(selected_path)
    print("Loaded selected config:", selected_path)
    if rebuild_results_path.exists():
        display(pd.read_csv(rebuild_results_path).sort_values(["validation_macro_f1", "best_validation_loss"], ascending=[False, True]))
    else:
        display(pd.DataFrame([selected_config]))
elif rebuild_results_path.exists():
    rebuild_selected_config_from_results(rebuild_results_path, selected_path, "04_dropout")
    display(pd.read_csv(rebuild_results_path).sort_values(["validation_macro_f1", "best_validation_loss"], ascending=[False, True]))
else:
    print("RUN_DROPOUT_TRIAL is False. [RESULT TO BE INSERTED AFTER FINAL RUN]")
    print("Missing selected config:", selected_path)
    print("Missing result CSV:", rebuild_results_path)
# Out:
# 04_dropout candidate 1/5: 0.0
# Epoch 1/50
# 71/71 - 1s - 15ms/step - accuracy: 0.8695 - loss: 0.2880 - val_accuracy: 0.8944 - val_loss: 0.2468
# Epoch 2/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9268 - loss: 0.1716 - val_accuracy: 0.9125 - val_loss: 0.2108
# Epoch 3/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9400 - loss: 0.1427 - val_accuracy: 0.9202 - val_loss: 0.1856
# Epoch 4/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9464 - loss: 0.1259 - val_accuracy: 0.9279 - val_loss: 0.1646
# Epoch 5/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9522 - loss: 0.1136 - val_accuracy: 0.9372 - val_loss: 0.1498
# Epoch 6/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9561 - loss: 0.1035 - val_accuracy: 0.9444 - val_loss: 0.1405
# Epoch 7/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9604 - loss: 0.0950 - val_accuracy: 0.9475 - val_loss: 0.1347
# Epoch 8/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9630 - loss: 0.0876 - val_accuracy: 0.9495 - val_loss: 0.1307
# Epoch 9/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9671 - loss: 0.0811 - val_accuracy: 0.9506 - val_loss: 0.1274
# Epoch 10/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9699 - loss: 0.0755 - val_accuracy: 0.9526 - val_loss: 0.1244
# Epoch 11/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9727 - loss: 0.0705 - val_accuracy: 0.9537 - val_loss: 0.1221
# Epoch 12/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9745 - loss: 0.0661 - val_accuracy: 0.9552 - val_loss: 0.1203
# Epoch 13/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9757 - loss: 0.0620 - val_accuracy: 0.9562 - val_loss: 0.1189
# Epoch 14/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9778 - loss: 0.0583 - val_accuracy: 0.9578 - val_loss: 0.1180
# Epoch 15/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9792 - loss: 0.0548 - val_accuracy: 0.9588 - val_loss: 0.1176
# Epoch 16/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9809 - loss: 0.0516 - val_accuracy: 0.9567 - val_loss: 0.1182
# Epoch 17/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9816 - loss: 0.0487 - val_accuracy: 0.9562 - val_loss: 0.1192
# Epoch 18/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9831 - loss: 0.0460 - val_accuracy: 0.9567 - val_loss: 0.1202
# Epoch 19/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9839 - loss: 0.0435 - val_accuracy: 0.9562 - val_loss: 0.1222
# Epoch 20/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9842 - loss: 0.0412 - val_accuracy: 0.9567 - val_loss: 0.1245
# Epoch 21/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9851 - loss: 0.0390 - val_accuracy: 0.9557 - val_loss: 0.1274
# Epoch 22/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9860 - loss: 0.0368 - val_accuracy: 0.9547 - val_loss: 0.1362
# 04_dropout candidate 2/5: 0.1
# Epoch 1/50
# 71/71 - 1s - 14ms/step - accuracy: 0.8542 - loss: 0.3170 - val_accuracy: 0.8955 - val_loss: 0.2307
# Epoch 2/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9129 - loss: 0.1994 - val_accuracy: 0.9238 - val_loss: 0.1825
# Epoch 3/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9252 - loss: 0.1727 - val_accuracy: 0.9279 - val_loss: 0.1673
# Epoch 4/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9349 - loss: 0.1533 - val_accuracy: 0.9351 - val_loss: 0.1482
# Epoch 5/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9390 - loss: 0.1447 - val_accuracy: 0.9418 - val_loss: 0.1377
# Epoch 6/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9432 - loss: 0.1312 - val_accuracy: 0.9459 - val_loss: 0.1270
# Epoch 7/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9460 - loss: 0.1235 - val_accuracy: 0.9464 - val_loss: 0.1255
# Epoch 8/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9502 - loss: 0.1210 - val_accuracy: 0.9495 - val_loss: 0.1203
# Epoch 9/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9532 - loss: 0.1130 - val_accuracy: 0.9480 - val_loss: 0.1198
# Epoch 10/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9563 - loss: 0.1079 - val_accuracy: 0.9501 - val_loss: 0.1223
# Epoch 11/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9551 - loss: 0.1041 - val_accuracy: 0.9516 - val_loss: 0.1100
# Epoch 12/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9589 - loss: 0.0958 - val_accuracy: 0.9567 - val_loss: 0.1064
# Epoch 13/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9608 - loss: 0.0912 - val_accuracy: 0.9573 - val_loss: 0.1012
# Epoch 14/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9634 - loss: 0.0863 - val_accuracy: 0.9583 - val_loss: 0.1064
# Epoch 15/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9656 - loss: 0.0834 - val_accuracy: 0.9578 - val_loss: 0.0972
# Epoch 16/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9658 - loss: 0.0797 - val_accuracy: 0.9567 - val_loss: 0.1009
# Epoch 17/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9691 - loss: 0.0774 - val_accuracy: 0.9609 - val_loss: 0.0934
# Epoch 18/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9710 - loss: 0.0723 - val_accuracy: 0.9629 - val_loss: 0.0919
# Epoch 19/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9695 - loss: 0.0732 - val_accuracy: 0.9634 - val_loss: 0.0877
# Epoch 20/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9703 - loss: 0.0682 - val_accuracy: 0.9609 - val_loss: 0.0865
# Epoch 21/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9728 - loss: 0.0647 - val_accuracy: 0.9640 - val_loss: 0.0938
# Epoch 22/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9756 - loss: 0.0626 - val_accuracy: 0.9629 - val_loss: 0.0900
# Epoch 23/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9730 - loss: 0.0639 - val_accuracy: 0.9634 - val_loss: 0.0856
# Epoch 24/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9744 - loss: 0.0640 - val_accuracy: 0.9650 - val_loss: 0.0873
# Epoch 25/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9755 - loss: 0.0584 - val_accuracy: 0.9655 - val_loss: 0.0791
# Epoch 26/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9763 - loss: 0.0586 - val_accuracy: 0.9655 - val_loss: 0.0853
# Epoch 27/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9758 - loss: 0.0575 - val_accuracy: 0.9686 - val_loss: 0.0779
# Epoch 28/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9772 - loss: 0.0551 - val_accuracy: 0.9650 - val_loss: 0.0784
# Epoch 29/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9794 - loss: 0.0521 - val_accuracy: 0.9660 - val_loss: 0.0810
# Epoch 30/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9787 - loss: 0.0503 - val_accuracy: 0.9717 - val_loss: 0.0764
# Epoch 31/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9813 - loss: 0.0494 - val_accuracy: 0.9660 - val_loss: 0.0810
# Epoch 32/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9810 - loss: 0.0488 - val_accuracy: 0.9686 - val_loss: 0.0796
# Epoch 33/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9805 - loss: 0.0463 - val_accuracy: 0.9712 - val_loss: 0.0710
# Epoch 34/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9812 - loss: 0.0467 - val_accuracy: 0.9676 - val_loss: 0.0840
# Epoch 35/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9818 - loss: 0.0458 - val_accuracy: 0.9706 - val_loss: 0.0732
# Epoch 36/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9842 - loss: 0.0421 - val_accuracy: 0.9660 - val_loss: 0.0853
# Epoch 37/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9823 - loss: 0.0432 - val_accuracy: 0.9665 - val_loss: 0.0844
# Epoch 38/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9836 - loss: 0.0413 - val_accuracy: 0.9696 - val_loss: 0.0780
# Epoch 39/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9829 - loss: 0.0413 - val_accuracy: 0.9681 - val_loss: 0.0811
# Epoch 40/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9834 - loss: 0.0393 - val_accuracy: 0.9686 - val_loss: 0.0781
# 04_dropout candidate 3/5: 0.2
# Epoch 1/50
# 71/71 - 1s - 15ms/step - accuracy: 0.8424 - loss: 0.3284 - val_accuracy: 0.8944 - val_loss: 0.2398
# Epoch 2/50
# 71/71 - 0s - 5ms/step - accuracy: 0.8987 - loss: 0.2223 - val_accuracy: 0.9125 - val_loss: 0.2017
# Epoch 3/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9163 - loss: 0.1893 - val_accuracy: 0.9258 - val_loss: 0.1724
# Epoch 4/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9252 - loss: 0.1690 - val_accuracy: 0.9258 - val_loss: 0.1677
# Epoch 5/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9327 - loss: 0.1561 - val_accuracy: 0.9341 - val_loss: 0.1582
# Epoch 6/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9396 - loss: 0.1434 - val_accuracy: 0.9428 - val_loss: 0.1352
# Epoch 7/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9416 - loss: 0.1365 - val_accuracy: 0.9398 - val_loss: 0.1459
# Epoch 8/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9461 - loss: 0.1260 - val_accuracy: 0.9490 - val_loss: 0.1266
# Epoch 9/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9487 - loss: 0.1199 - val_accuracy: 0.9521 - val_loss: 0.1239
# Epoch 10/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9497 - loss: 0.1171 - val_accuracy: 0.9542 - val_loss: 0.1166
# Epoch 11/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9526 - loss: 0.1096 - val_accuracy: 0.9521 - val_loss: 0.1139
# Epoch 12/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9544 - loss: 0.1063 - val_accuracy: 0.9542 - val_loss: 0.1135
# Epoch 13/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9588 - loss: 0.0970 - val_accuracy: 0.9542 - val_loss: 0.1070
# Epoch 14/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9595 - loss: 0.0964 - val_accuracy: 0.9526 - val_loss: 0.1193
# Epoch 15/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9613 - loss: 0.0953 - val_accuracy: 0.9531 - val_loss: 0.1104
# Epoch 16/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9649 - loss: 0.0862 - val_accuracy: 0.9604 - val_loss: 0.0977
# Epoch 17/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9636 - loss: 0.0846 - val_accuracy: 0.9593 - val_loss: 0.0953
# Epoch 18/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9650 - loss: 0.0846 - val_accuracy: 0.9624 - val_loss: 0.0907
# Epoch 19/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9661 - loss: 0.0843 - val_accuracy: 0.9634 - val_loss: 0.0908
# Epoch 20/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9673 - loss: 0.0782 - val_accuracy: 0.9573 - val_loss: 0.0978
# Epoch 21/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9678 - loss: 0.0806 - val_accuracy: 0.9640 - val_loss: 0.0884
# Epoch 22/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9681 - loss: 0.0766 - val_accuracy: 0.9573 - val_loss: 0.0990
# Epoch 23/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9694 - loss: 0.0734 - val_accuracy: 0.9660 - val_loss: 0.0912
# Epoch 24/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9710 - loss: 0.0717 - val_accuracy: 0.9624 - val_loss: 0.0906
# Epoch 25/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9716 - loss: 0.0673 - val_accuracy: 0.9634 - val_loss: 0.0963
# Epoch 26/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9722 - loss: 0.0695 - val_accuracy: 0.9593 - val_loss: 0.0947
# Epoch 27/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9711 - loss: 0.0690 - val_accuracy: 0.9634 - val_loss: 0.0900
# Epoch 28/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9733 - loss: 0.0631 - val_accuracy: 0.9660 - val_loss: 0.0837
# Epoch 29/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9745 - loss: 0.0627 - val_accuracy: 0.9681 - val_loss: 0.0869
# Epoch 30/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9762 - loss: 0.0581 - val_accuracy: 0.9634 - val_loss: 0.0909
# Epoch 31/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9762 - loss: 0.0620 - val_accuracy: 0.9681 - val_loss: 0.0807
# Epoch 32/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9745 - loss: 0.0606 - val_accuracy: 0.9640 - val_loss: 0.0869
# Epoch 33/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9762 - loss: 0.0580 - val_accuracy: 0.9634 - val_loss: 0.0847
# Epoch 34/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9762 - loss: 0.0566 - val_accuracy: 0.9634 - val_loss: 0.0841
# Epoch 35/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9760 - loss: 0.0599 - val_accuracy: 0.9645 - val_loss: 0.0848
# Epoch 36/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9779 - loss: 0.0520 - val_accuracy: 0.9686 - val_loss: 0.0952
# Epoch 37/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9779 - loss: 0.0557 - val_accuracy: 0.9696 - val_loss: 0.0828
# Epoch 38/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9786 - loss: 0.0526 - val_accuracy: 0.9706 - val_loss: 0.0837
# 04_dropout candidate 4/5: 0.3
# Epoch 1/50
# 71/71 - 1s - 14ms/step - accuracy: 0.8216 - loss: 0.3682 - val_accuracy: 0.8805 - val_loss: 0.2628
# Epoch 2/50
# 71/71 - 0s - 4ms/step - accuracy: 0.8885 - loss: 0.2402 - val_accuracy: 0.9150 - val_loss: 0.2037
# Epoch 3/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9047 - loss: 0.2079 - val_accuracy: 0.9248 - val_loss: 0.1864
# Epoch 4/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9136 - loss: 0.1941 - val_accuracy: 0.9289 - val_loss: 0.1726
# Epoch 5/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9238 - loss: 0.1773 - val_accuracy: 0.9331 - val_loss: 0.1688
# Epoch 6/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9281 - loss: 0.1619 - val_accuracy: 0.9377 - val_loss: 0.1533
# Epoch 7/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9344 - loss: 0.1515 - val_accuracy: 0.9408 - val_loss: 0.1445
# Epoch 8/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9359 - loss: 0.1471 - val_accuracy: 0.9413 - val_loss: 0.1441
# Epoch 9/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9432 - loss: 0.1359 - val_accuracy: 0.9459 - val_loss: 0.1341
# Epoch 10/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9411 - loss: 0.1347 - val_accuracy: 0.9454 - val_loss: 0.1356
# Epoch 11/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9489 - loss: 0.1199 - val_accuracy: 0.9531 - val_loss: 0.1245
# Epoch 12/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9488 - loss: 0.1216 - val_accuracy: 0.9547 - val_loss: 0.1156
# Epoch 13/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9526 - loss: 0.1138 - val_accuracy: 0.9537 - val_loss: 0.1185
# Epoch 14/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9519 - loss: 0.1123 - val_accuracy: 0.9557 - val_loss: 0.1069
# Epoch 15/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9534 - loss: 0.1103 - val_accuracy: 0.9547 - val_loss: 0.1185
# Epoch 16/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9557 - loss: 0.1031 - val_accuracy: 0.9516 - val_loss: 0.1180
# Epoch 17/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9568 - loss: 0.1009 - val_accuracy: 0.9578 - val_loss: 0.1081
# Epoch 18/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9563 - loss: 0.0992 - val_accuracy: 0.9567 - val_loss: 0.1080
# Epoch 19/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9609 - loss: 0.0915 - val_accuracy: 0.9583 - val_loss: 0.0999
# Epoch 20/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9586 - loss: 0.0975 - val_accuracy: 0.9593 - val_loss: 0.0996
# Epoch 21/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9615 - loss: 0.0954 - val_accuracy: 0.9598 - val_loss: 0.1048
# Epoch 22/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9625 - loss: 0.0880 - val_accuracy: 0.9609 - val_loss: 0.0962
# Epoch 23/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9641 - loss: 0.0872 - val_accuracy: 0.9604 - val_loss: 0.1032
# Epoch 24/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9639 - loss: 0.0853 - val_accuracy: 0.9650 - val_loss: 0.0915
# Epoch 25/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9659 - loss: 0.0832 - val_accuracy: 0.9655 - val_loss: 0.0901
# Epoch 26/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9669 - loss: 0.0798 - val_accuracy: 0.9676 - val_loss: 0.0845
# Epoch 27/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9678 - loss: 0.0817 - val_accuracy: 0.9619 - val_loss: 0.0950
# Epoch 28/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9666 - loss: 0.0749 - val_accuracy: 0.9686 - val_loss: 0.0913
# Epoch 29/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9701 - loss: 0.0705 - val_accuracy: 0.9629 - val_loss: 0.0921
# Epoch 30/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9706 - loss: 0.0730 - val_accuracy: 0.9681 - val_loss: 0.0830
# Epoch 31/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9711 - loss: 0.0700 - val_accuracy: 0.9681 - val_loss: 0.0853
# Epoch 32/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9703 - loss: 0.0697 - val_accuracy: 0.9665 - val_loss: 0.0893
# Epoch 33/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9715 - loss: 0.0658 - val_accuracy: 0.9701 - val_loss: 0.0795
# Epoch 34/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9709 - loss: 0.0682 - val_accuracy: 0.9691 - val_loss: 0.0800
# Epoch 35/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9724 - loss: 0.0637 - val_accuracy: 0.9701 - val_loss: 0.0816
# Epoch 36/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9733 - loss: 0.0643 - val_accuracy: 0.9655 - val_loss: 0.0876
# Epoch 37/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9749 - loss: 0.0640 - val_accuracy: 0.9660 - val_loss: 0.0825
# Epoch 38/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9770 - loss: 0.0612 - val_accuracy: 0.9712 - val_loss: 0.0862
# Epoch 39/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9733 - loss: 0.0646 - val_accuracy: 0.9717 - val_loss: 0.0811
# Epoch 40/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9745 - loss: 0.0591 - val_accuracy: 0.9712 - val_loss: 0.0799
# 04_dropout candidate 5/5: 0.4
# Epoch 1/50
# 71/71 - 1s - 14ms/step - accuracy: 0.8055 - loss: 0.4065 - val_accuracy: 0.8728 - val_loss: 0.2811
# Epoch 2/50
# 71/71 - 0s - 5ms/step - accuracy: 0.8763 - loss: 0.2672 - val_accuracy: 0.8955 - val_loss: 0.2290
# Epoch 3/50
# 71/71 - 0s - 5ms/step - accuracy: 0.8959 - loss: 0.2337 - val_accuracy: 0.9140 - val_loss: 0.1950
# Epoch 4/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9061 - loss: 0.2062 - val_accuracy: 0.9274 - val_loss: 0.1767
# Epoch 5/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9166 - loss: 0.1887 - val_accuracy: 0.9274 - val_loss: 0.1745
# Epoch 6/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9216 - loss: 0.1799 - val_accuracy: 0.9295 - val_loss: 0.1680
# Epoch 7/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9249 - loss: 0.1690 - val_accuracy: 0.9351 - val_loss: 0.1511
# Epoch 8/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9268 - loss: 0.1655 - val_accuracy: 0.9377 - val_loss: 0.1554
# Epoch 9/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9354 - loss: 0.1510 - val_accuracy: 0.9454 - val_loss: 0.1334
# Epoch 10/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9372 - loss: 0.1452 - val_accuracy: 0.9495 - val_loss: 0.1281
# Epoch 11/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9395 - loss: 0.1401 - val_accuracy: 0.9480 - val_loss: 0.1350
# Epoch 12/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9436 - loss: 0.1351 - val_accuracy: 0.9531 - val_loss: 0.1211
# Epoch 13/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9475 - loss: 0.1298 - val_accuracy: 0.9511 - val_loss: 0.1214
# Epoch 14/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9469 - loss: 0.1246 - val_accuracy: 0.9506 - val_loss: 0.1276
# Epoch 15/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9483 - loss: 0.1212 - val_accuracy: 0.9578 - val_loss: 0.1091
# Epoch 16/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9514 - loss: 0.1169 - val_accuracy: 0.9547 - val_loss: 0.1179
# Epoch 17/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9522 - loss: 0.1134 - val_accuracy: 0.9521 - val_loss: 0.1181
# Epoch 18/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9536 - loss: 0.1068 - val_accuracy: 0.9552 - val_loss: 0.1125
# Epoch 19/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9562 - loss: 0.1049 - val_accuracy: 0.9573 - val_loss: 0.1021
# Epoch 20/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9556 - loss: 0.1064 - val_accuracy: 0.9573 - val_loss: 0.1100
# Epoch 21/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9547 - loss: 0.1081 - val_accuracy: 0.9567 - val_loss: 0.1169
# Epoch 22/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9581 - loss: 0.1029 - val_accuracy: 0.9593 - val_loss: 0.1113
# Epoch 23/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9610 - loss: 0.0986 - val_accuracy: 0.9604 - val_loss: 0.1008
# Epoch 24/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9603 - loss: 0.0949 - val_accuracy: 0.9640 - val_loss: 0.0971
# Epoch 25/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9606 - loss: 0.0952 - val_accuracy: 0.9619 - val_loss: 0.1018
# Epoch 26/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9617 - loss: 0.0964 - val_accuracy: 0.9598 - val_loss: 0.1045
# Epoch 27/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9620 - loss: 0.0946 - val_accuracy: 0.9645 - val_loss: 0.0957
# Epoch 28/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9628 - loss: 0.0894 - val_accuracy: 0.9614 - val_loss: 0.0980
# Epoch 29/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9632 - loss: 0.0899 - val_accuracy: 0.9660 - val_loss: 0.0926
# Epoch 30/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9656 - loss: 0.0806 - val_accuracy: 0.9598 - val_loss: 0.0969
# Epoch 31/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9610 - loss: 0.0887 - val_accuracy: 0.9619 - val_loss: 0.0993
# Epoch 32/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9660 - loss: 0.0834 - val_accuracy: 0.9686 - val_loss: 0.0860
# Epoch 33/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9628 - loss: 0.0883 - val_accuracy: 0.9645 - val_loss: 0.0944
# Epoch 34/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9639 - loss: 0.0843 - val_accuracy: 0.9696 - val_loss: 0.0901
# Epoch 35/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9652 - loss: 0.0884 - val_accuracy: 0.9629 - val_loss: 0.0894
# Epoch 36/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9659 - loss: 0.0812 - val_accuracy: 0.9609 - val_loss: 0.0950
# Epoch 37/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9667 - loss: 0.0845 - val_accuracy: 0.9660 - val_loss: 0.0912
# Epoch 38/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9682 - loss: 0.0821 - val_accuracy: 0.9645 - val_loss: 0.0936
# Epoch 39/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9663 - loss: 0.0793 - val_accuracy: 0.9670 - val_loss: 0.0858
# Epoch 40/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9670 - loss: 0.0797 - val_accuracy: 0.9706 - val_loss: 0.0861
# Epoch 41/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9678 - loss: 0.0769 - val_accuracy: 0.9696 - val_loss: 0.0846
# Epoch 42/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9688 - loss: 0.0760 - val_accuracy: 0.9660 - val_loss: 0.0862
# Epoch 43/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9701 - loss: 0.0733 - val_accuracy: 0.9691 - val_loss: 0.0843
# Epoch 44/50
# 71/71 - 0s - 5ms/step - accuracy: 0.9717 - loss: 0.0720 - val_accuracy: 0.9670 - val_loss: 0.0901
# Epoch 45/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9711 - loss: 0.0707 - val_accuracy: 0.9681 - val_loss: 0.0827
# Epoch 46/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9692 - loss: 0.0745 - val_accuracy: 0.9686 - val_loss: 0.0838
# Epoch 47/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9708 - loss: 0.0733 - val_accuracy: 0.9696 - val_loss: 0.0828
# Epoch 48/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9721 - loss: 0.0729 - val_accuracy: 0.9691 - val_loss: 0.0821
# Epoch 49/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9712 - loss: 0.0717 - val_accuracy: 0.9681 - val_loss: 0.0882
# Epoch 50/50
# 71/71 - 0s - 4ms/step - accuracy: 0.9711 - loss: 0.0687 - val_accuracy: 0.9670 - val_loss: 0.0796
#         stage  candidate hidden_units activation optimizer  dropout  \
# 1  04_dropout        0.1    [128, 64]        elu   rmsprop      0.1
# 3  04_dropout        0.3    [128, 64]        elu   rmsprop      0.3
# 2  04_dropout        0.2    [128, 64]        elu   rmsprop      0.2
# 4  04_dropout        0.4    [128, 64]        elu   rmsprop      0.4
# 0  04_dropout        0.0    [128, 64]        elu   rmsprop      0.0
#
#    learning_rate  batch_size                 loss  threshold  ...        seed  \
# 1          0.001         128  binary_crossentropy        0.5  ...  1881047456
# 3          0.001         128  binary_crossentropy        0.5  ...   544739648
# 2          0.001         128  binary_crossentropy        0.5  ...   364127844
# 4          0.001         128  binary_crossentropy        0.5  ...    89000964
# 0          0.001         128  binary_crossentropy        0.5  ...   800460897
#
#   validation_macro_f1  validation_binary_f1_synthetic  validation_accuracy  \
# 1            0.966449                        0.979026             0.971164
# 3            0.965496                        0.978146             0.970134
# 2            0.963307                        0.976533             0.968074
# 4            0.962025                        0.975831             0.967044
# 0            0.953164                        0.969419             0.958805
#
#    validation_precision_synthetic  validation_recall_synthetic  \
# 1                        0.984928                     0.973194
# 3                        0.990084                     0.966493
# 2                        0.993072                     0.960536
# 4                        0.990038                     0.962025
# 0                        0.996072                     0.944155
#
#    best_validation_loss  best_epoch  epochs_trained  runtime_seconds
# 1              0.070958          33              40        14.080634
# 3              0.079525          33              40        12.873726
# 2              0.080667          31              38        12.503044
# 4              0.079609          50              50        16.615067
# 0              0.117642          15              22         7.017143
#
# [5 rows x 22 columns]
# Saved selected config: /content/drive/MyDrive/Colab Notebooks/Education/INM701/outputs/mlp/configs/04_selected_config.json

# %% [markdown]
# ## 6. Checks

# %%
# Purpose: Runs this notebook step and prints or saves the resulting intermediate output for review.
display(pd.DataFrame([("varies_only", "dropout"), ("validation_macro_f1_primary", True), ("test_metrics_computed", False)], columns=["check", "value"]))
# Out:
#                          check    value
# 0                  varies_only  dropout
# 1  validation_macro_f1_primary     True
# 2        test_metrics_computed    False
