# %% [markdown]
# # Logistic Regression Hyperparameter Trial Comparison
#
# Run this notebook **after** the baseline and individual trial notebooks. It combines their saved validation results. The held-out test set is not used here.

# %%
# Purpose: validation results. The held-out test set is not used here.
from pathlib import Path
import pandas as pd

try:
    from google.colab import drive
    drive.mount("/content/drive")
except Exception:
    pass

if Path("/content/drive/MyDrive/Colab Notebooks/Education/INM701").exists():
    PROJECT_ROOT = Path("/content/drive/MyDrive/Colab Notebooks/Education/INM701")
else:
    PROJECT_ROOT = Path.cwd()
# Out:
# Mounted at /content/drive

# %%
# Purpose: validation results. The held-out test set is not used here.
# Purpose: Centralizes filesystem paths so dataset inputs, caches, figures, models, and metric tables are easy
# Purpose: to trace.
TABLES_DIR = PROJECT_ROOT / "outputs" / "logistic_regression" / "tables"
EXPECTED_FILES = ['logistic_regression_baseline.csv', 'logistic_regression_c_trial.csv', 'logistic_regression_penalty_trial.csv', 'logistic_regression_solver_trial.csv', 'logistic_regression_class_weight_trial.csv']

frames = []
missing = []
# Purpose: Iterates over this collection to build the next table, feature set, or experiment result
# Purpose: consistently.
for filename in EXPECTED_FILES:
    path = TABLES_DIR / filename
    if path.exists():
        frame = pd.read_csv(path)
        frame["source_file"] = filename
        frames.append(frame)
    else:
        missing.append(filename)

if missing:
    print("Missing result files (run those notebooks first):")
    # Purpose: Iterates over this collection to build the next table, feature set, or experiment result
    # Purpose: consistently.
    for item in missing:
        print(" -", item)

if not frames:
    raise FileNotFoundError("No trial result CSV files were found.")

all_trials_df = pd.concat(frames, ignore_index=True, sort=False)
all_trials_df = all_trials_df.sort_values("f1", ascending=False).reset_index(drop=True)
display(all_trials_df)

comparison_path = TABLES_DIR / "logistic_regression_all_individual_trials.csv"
# Purpose: Saves the generated artifacts so later notebooks, reports, or reruns can inspect the same outputs.
all_trials_df.to_csv(comparison_path, index=False)
print("Saved combined comparison:", comparison_path)
print("Highest validation F1 row:")
display(all_trials_df.head(1))
# Out:
# Missing result files (run those notebooks first):
#  - logistic_regression_baseline.csv
#                   model trial_parameter trial_value                variant  \
# 0   Logistic Regression               C       100.0                C=100.0
# 1   Logistic Regression               C        10.0                 C=10.0
# 2   Logistic Regression    class_weight         NaN      class_weight=None
# 3   Logistic Regression         penalty          l1             penalty=l1
# 4   Logistic Regression          solver       lbfgs           solver=lbfgs
# 5   Logistic Regression          solver        saga            solver=saga
# 6   Logistic Regression          solver   liblinear       solver=liblinear
# 7   Logistic Regression               C         1.0                  C=1.0
# 8   Logistic Regression    class_weight    balanced  class_weight=balanced
# 9   Logistic Regression         penalty          l2             penalty=l2
# 10  Logistic Regression               C         0.1                  C=0.1
# 11  Logistic Regression               C        0.01                 C=0.01
#
#     accuracy  precision    recall        f1       C penalty     solver  \
# 0   0.940268   0.991981  0.921072  0.955212  100.00      l2  liblinear
# 1   0.938723   0.990385  0.920328  0.954072   10.00      l2  liblinear
# 2   0.936663   0.967075  0.940432  0.953567    1.00      l2  liblinear
# 3   0.935118   0.991122  0.914371  0.951201    1.00      l1  liblinear
# 4   0.928424   0.988636  0.906925  0.946019    1.00      l2      lbfgs
# 5   0.927394   0.988618  0.905436  0.945200    1.00      l2       saga
# 6   0.925850   0.988590  0.903202  0.943969    1.00      l2  liblinear
# 7   0.925850   0.988590  0.903202  0.943969    1.00      l2  liblinear
# 8   0.925850   0.988590  0.903202  0.943969    1.00      l2  liblinear
# 9   0.925850   0.988590  0.903202  0.943969    1.00      l2  liblinear
# 10  0.908857   0.986644  0.880119  0.930342    0.10      l2  liblinear
# 11  0.878991   0.980903  0.841400  0.905812    0.01      l2  liblinear
#
#    class_weight                                 source_file
# 0      balanced             logistic_regression_c_trial.csv
# 1      balanced             logistic_regression_c_trial.csv
# 2           NaN  logistic_regression_class_weight_trial.csv
# 3      balanced       logistic_regression_penalty_trial.csv
# 4      balanced        logistic_regression_solver_trial.csv
# 5      balanced        logistic_regression_solver_trial.csv
# 6      balanced        logistic_regression_solver_trial.csv
# 7      balanced             logistic_regression_c_trial.csv
# 8      balanced  logistic_regression_class_weight_trial.csv
# 9      balanced       logistic_regression_penalty_trial.csv
# 10     balanced             logistic_regression_c_trial.csv
# 11     balanced             logistic_regression_c_trial.csv
# Saved combined comparison: /content/drive/MyDrive/Colab Notebooks/Education/INM701/outputs/logistic_regression/tables/logistic_regression_all_individual_trials.csv
# Highest validation F1 row:
#                  model trial_parameter trial_value  variant  accuracy  \
# 0  Logistic Regression               C       100.0  C=100.0  0.940268
#
#    precision    recall        f1      C penalty     solver class_weight  \
# 0   0.991981  0.921072  0.955212  100.0      l2  liblinear     balanced
#
#                        source_file
# 0  logistic_regression_c_trial.csv
